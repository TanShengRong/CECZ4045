# %% [markdown]
# # Sentence Segmentation
# We want to break down our documents into sentences and parse them for tokens. Further analysis is to be performed on the three datasets' segmentation results to compare them.

# %%
import nltk.data
import os
FOOD_REV_DIR = './../tokenizer/food_reviews_scraping'
CV_PAPER_DIR = './../tokenizer/Deep Learning and Computer Vision papers'
GAME_DIR = './../tokenizer/darren_documents'


# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# ### 1.1 Testing Sentence Segmentation with NLTK's PunktSentenceTokenizer
# NLTK provides a sentence tokenizer that has been pretrained using an English corpus. The tokenizer uses an unsupervised algorithm to build a model for abbreviation words, collocations, and words that start sentences. The library provides unique sentence tokenizers for different languages.

# %%
text = "Wow there you go.Fastest car in the city. In Singapore."
sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
print('\n-----\n'.join(sent_detector.tokenize(text.strip())))
# Out:
# Wow there you go.Fastest car in the city.
# -----
# In Singapore.

# %% [markdown]
# Here, we see that the sentence tokenizer is actually relatively unreliable when it comes to parsing the EOL token. We have 2 sentences combined into one when we remove a spacing.

# %%
for file in os.listdir(FOOD_REV_DIR):
    with open(os.path.join(FOOD_REV_DIR,file),'r') as f:
        text = f.readlines()[0]
        print("Original text of:",file)
        print(text)
        print("\nSentence Segmented Text: ")
        for line in sent_detector.tokenize(text.strip()):
            print(line)
            print('\n-------\n')
        break
# Out:
# Original text of: document9.txt
# Not to be confused with Dim Sum Haus at Jalan Besar, Dim Sum House is a relatively new store at Yio Chu Kang Road.The humble-looking eatery serves items reasonably priced around the $4 to $5 range.Of course ’affordable’ dim sum is subjective as there are always other places such as Kuai San Dian Xin 块三点心. (Also read: 10 Off-Peak Dining Deals For Affordable Dim Sum) That same ulu stretch of Yio Chu Kang Road seems to be bustling with activities.If you need your coffee and cakes, relatively recent café additions include Urban Table, Amber Ember and Two Bakery – all within a short walking distance. The location used to be occupied by another Chinese eatery, which unfortunately did not survive the low footfall of this area.Let’s have better faith for Dim Sum House. What caught my attention were the adorable animal buns which usually require effort to craft. While the names are not clearly stated on the menu, there is the “Porcupine” Red Bean Paste Bun ($4.50) and “Chick” Lotus Paste Bun ($4.50). Though the yellow-chick bao appearance may remind some of Crystal Jade’s version. “Aiyo, why so cute.” (Took me awhile to ‘play’ around with it and snapped tons of photos before I reluctantly popped it into my mouth.) The buns were steamed soft and fluffy, generously stuffed with red bean or lotus paste filing.I liked that their paste filling was not so cloyingly sweet, which made it very much enjoyable. There was also the Deep-Fried Dumplings with Mushroom ($4), molded into the shape of a carrot then embedded with a stem of coriander leaf. Plus points for the presentation and creativity.It had a chewy sweet rice cake exterior, filled with savoury mushroom bits. While their menu is not that extensive, you can still find regular dim sum suspects such as Siew Mai ($4.50), Har Kau ($4.50), Pan-fried Carrot Cake ($4.50), BBQ Pork Cheong Fun ($4.80), Century Egg Congee ($4.80) and Lotus Leaf Glutinous Rice ($4.50). I would say most of them tasted quite decent and above average, with most hits and minor misses. Worthy of mention would be the Pan-fried Shredded Yam with Golden Pumpkin ($4). I liked how they sandwiched soft pumpkin fillings using firm yam layer for the differential in bite texture, before being pan-fried till golden brown for the crispy exterior. Their Shanghai Xiao Long Bao ($8.80) was also memorable, with thin dumpling skin encasing marinated minced pork swimming in a pool of “zhup” (gravy). *Slurps* I found their premises quite small for a dim sum place; it has only space for 4 tables on upper storey and 3 more on the ground floor. So be warned of the waiting time due to limited capacity.They do offer reservations on weekday, but strictly for walk-ins on weekends and public holiday.  Dim Sum House
#
#
# Sentence Segmented Text:
# Not to be confused with Dim Sum Haus at Jalan Besar, Dim Sum House is a relatively new store at Yio Chu Kang Road.The humble-looking eatery serves items reasonably priced around the $4 to $5 range.Of course ’affordable’ dim sum is subjective as there are always other places such as Kuai San Dian Xin 块三点心.
#
# -------
#
# (Also read: 10 Off-Peak Dining Deals For Affordable Dim Sum) That same ulu stretch of Yio Chu Kang Road seems to be bustling with activities.If you need your coffee and cakes, relatively recent café additions include Urban Table, Amber Ember and Two Bakery – all within a short walking distance.
#
# -------
#
# The location used to be occupied by another Chinese eatery, which unfortunately did not survive the low footfall of this area.Let’s have better faith for Dim Sum House.
#
# -------
#
# What caught my attention were the adorable animal buns which usually require effort to craft.
#
# -------
#
# While the names are not clearly stated on the menu, there is the “Porcupine” Red Bean Paste Bun ($4.50) and “Chick” Lotus Paste Bun ($4.50).
#
# -------
#
# Though the yellow-chick bao appearance may remind some of Crystal Jade’s version.
#
# -------
#
# “Aiyo, why so cute.” (Took me awhile to ‘play’ around with it and snapped tons of photos before I reluctantly popped it into my mouth.)
#
# -------
#
# The buns were steamed soft and fluffy, generously stuffed with red bean or lotus paste filing.I liked that their paste filling was not so cloyingly sweet, which made it very much enjoyable.
#
# -------
#
# There was also the Deep-Fried Dumplings with Mushroom ($4), molded into the shape of a carrot then embedded with a stem of coriander leaf.
#
# -------
#
# Plus points for the presentation and creativity.It had a chewy sweet rice cake exterior, filled with savoury mushroom bits.
#
# -------
#
# While their menu is not that extensive, you can still find regular dim sum suspects such as Siew Mai ($4.50), Har Kau ($4.50), Pan-fried Carrot Cake ($4.50), BBQ Pork Cheong Fun ($4.80), Century Egg Congee ($4.80) and Lotus Leaf Glutinous Rice ($4.50).
#
# -------
#
# I would say most of them tasted quite decent and above average, with most hits and minor misses.
#
# -------
#
# Worthy of mention would be the Pan-fried Shredded Yam with Golden Pumpkin ($4).
#
# -------
#
# I liked how they sandwiched soft pumpkin fillings using firm yam layer for the differential in bite texture, before being pan-fried till golden brown for the crispy exterior.
#
# -------
#
# Their Shanghai Xiao Long Bao ($8.80) was also memorable, with thin dumpling skin encasing marinated minced pork swimming in a pool of “zhup” (gravy).
#
# -------
#
# *Slurps* I found their premises quite small for a dim sum place; it has only space for 4 tables on upper storey and 3 more on the ground floor.
#
# -------
#
# So be warned of the waiting time due to limited capacity.They do offer reservations on weekday, but strictly for walk-ins on weekends and public holiday.
#
# -------
#
# Dim Sum House
#
# -------

# %% [markdown]
# Here, the same issue becomes much more obvious. We see that the parser is unable to separate sentences if the use of "." is not followed by a space.

# %% [markdown]
# ### 1.2 Using Stanza by Stanford NLP on Food Reviews Scraping Dataset

# %%
import stanza

# stanza.download('en', processors='tokenize')
nlp = stanza.Pipeline(lang='en', processors='tokenize')
doc = nlp(text)
for i, sentence in enumerate(doc.sentences):
    print('\n-----\n')
    print(*[f'id: {token.id}\ttext: {token.text}' for token in sentence.tokens], sep='\n')
# Out:
# 2020-10-30 23:40:23 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ewt     |
# =======================
#
# 2020-10-30 23:40:23 INFO: Use device: cpu
# 2020-10-30 23:40:23 INFO: Loading: tokenize
# 2020-10-30 23:40:23 INFO: Done loading processors!
# -----
#
# id: (1,)	text: Not
# id: (2,)	text: to
# id: (3,)	text: be
# id: (4,)	text: confused
# id: (5,)	text: with
# id: (6,)	text: Dim
# id: (7,)	text: Sum
# id: (8,)	text: Haus
# id: (9,)	text: at
# id: (10,)	text: Jalan
# id: (11,)	text: Besar
# id: (12,)	text: ,
# id: (13,)	text: Dim
# id: (14,)	text: Sum
# id: (15,)	text: House
# id: (16,)	text: is
# id: (17,)	text: a
# id: (18,)	text: relatively
# id: (19,)	text: new
# id: (20,)	text: store
# id: (21,)	text: at
# id: (22,)	text: Yio
# id: (23,)	text: Chu
# id: (24,)	text: Kang
# id: (25,)	text: Road
# id: (26,)	text: .
#
# -----
#
# id: (1,)	text: The
# id: (2,)	text: humble
# id: (3,)	text: -
# id: (4,)	text: looking
# id: (5,)	text: eatery
# id: (6,)	text: serves
# id: (7,)	text: items
# id: (8,)	text: reasonably
# id: (9,)	text: priced
# id: (10,)	text: around
# id: (11,)	text: the
# id: (12,)	text: $
# id: (13,)	text: 4
# id: (14,)	text: to
# id: (15,)	text: $
# id: (16,)	text: 5
# id: (17,)	text: range
# id: (18,)	text: .
#
# -----
#
# id: (1,)	text: Of
# id: (2,)	text: course
# id: (3,)	text: ’
# id: (4,)	text: affordable
# id: (5,)	text: ’
# id: (6,)	text: dim
# id: (7,)	text: sum
# id: (8,)	text: is
# id: (9,)	text: subjective
# id: (10,)	text: as
# id: (11,)	text: there
# id: (12,)	text: are
# id: (13,)	text: always
# id: (14,)	text: other
# id: (15,)	text: places
# id: (16,)	text: such
# id: (17,)	text: as
# id: (18,)	text: Kuai
# id: (19,)	text: San
# id: (20,)	text: Dian
# id: (21,)	text: Xin
# id: (22,)	text: 块三点心
# id: (23,)	text: .
#
# -----
#
# id: (1,)	text: (
# id: (2,)	text: Also
# id: (3,)	text: read
# id: (4,)	text: :
# id: (5,)	text: 10
# id: (6,)	text: Off
# id: (7,)	text: -
# id: (8,)	text: Peak
# id: (9,)	text: Dining
# id: (10,)	text: Deals
# id: (11,)	text: For
# id: (12,)	text: Affordable
# id: (13,)	text: Dim
# id: (14,)	text: Sum
# id: (15,)	text: )
#
# -----
#
# id: (1,)	text: That
# id: (2,)	text: same
# id: (3,)	text: ulu
# id: (4,)	text: stretch
# id: (5,)	text: of
# id: (6,)	text: Yio
# id: (7,)	text: Chu
# id: (8,)	text: Kang
# id: (9,)	text: Road
# id: (10,)	text: seems
# id: (11,)	text: to
# id: (12,)	text: be
# id: (13,)	text: bustling
# id: (14,)	text: with
# id: (15,)	text: activities
# id: (16,)	text: .
#
# -----
#
# id: (1,)	text: If
# id: (2,)	text: you
# id: (3,)	text: need
# id: (4,)	text: your
# id: (5,)	text: coffee
# id: (6,)	text: and
# id: (7,)	text: cakes
# id: (8,)	text: ,
# id: (9,)	text: relatively
# id: (10,)	text: recent
# id: (11,)	text: café
# id: (12,)	text: additions
# id: (13,)	text: include
# id: (14,)	text: Urban
# id: (15,)	text: Table
# id: (16,)	text: ,
# id: (17,)	text: Amber
# id: (18,)	text: Ember
# id: (19,)	text: and
# id: (20,)	text: Two
# id: (21,)	text: Bakery
# id: (22,)	text: –
# id: (23,)	text: all
# id: (24,)	text: within
# id: (25,)	text: a
# id: (26,)	text: short
# id: (27,)	text: walking
# id: (28,)	text: distance
# id: (29,)	text: .
#
# -----
#
# id: (1,)	text: The
# id: (2,)	text: location
# id: (3,)	text: used
# id: (4,)	text: to
# id: (5,)	text: be
# id: (6,)	text: occupied
# id: (7,)	text: by
# id: (8,)	text: another
# id: (9,)	text: Chinese
# id: (10,)	text: eatery
# id: (11,)	text: ,
# id: (12,)	text: which
# id: (13,)	text: unfortunately
# id: (14,)	text: did
# id: (15,)	text: not
# id: (16,)	text: survive
# id: (17,)	text: the
# id: (18,)	text: low
# id: (19,)	text: footfall
# id: (20,)	text: of
# id: (21,)	text: this
# id: (22,)	text: area
# id: (23,)	text: .
#
# -----
#
# id: (1,)	text: Let
# id: (2,)	text: ’s
# id: (3,)	text: have
# id: (4,)	text: better
# id: (5,)	text: faith
# id: (6,)	text: for
# id: (7,)	text: Dim
# id: (8,)	text: Sum
# id: (9,)	text: House
# id: (10,)	text: .
#
# -----
#
# id: (1,)	text: What
# id: (2,)	text: caught
# id: (3,)	text: my
# id: (4,)	text: attention
# id: (5,)	text: were
# id: (6,)	text: the
# id: (7,)	text: adorable
# id: (8,)	text: animal
# id: (9,)	text: buns
# id: (10,)	text: which
# id: (11,)	text: usually
# id: (12,)	text: require
# id: (13,)	text: effort
# id: (14,)	text: to
# id: (15,)	text: craft
# id: (16,)	text: .
#
# -----
#
# id: (1,)	text: While
# id: (2,)	text: the
# id: (3,)	text: names
# id: (4,)	text: are
# id: (5,)	text: not
# id: (6,)	text: clearly
# id: (7,)	text: stated
# id: (8,)	text: on
# id: (9,)	text: the
# id: (10,)	text: menu
# id: (11,)	text: ,
# id: (12,)	text: there
# id: (13,)	text: is
# id: (14,)	text: the
# id: (15,)	text: “
# id: (16,)	text: Porcupine
# id: (17,)	text: ”
# id: (18,)	text: Red
# id: (19,)	text: Bean
# id: (20,)	text: Paste
# id: (21,)	text: Bun
# id: (22,)	text: (
# id: (23,)	text: $
# id: (24,)	text: 4.50
# id: (25,)	text: )
# id: (26,)	text: and
# id: (27,)	text: “
# id: (28,)	text: Chick
# id: (29,)	text: ”
# id: (30,)	text: Lotus
# id: (31,)	text: Paste
# id: (32,)	text: Bun
# id: (33,)	text: (
# id: (34,)	text: $
# id: (35,)	text: 4.50
# id: (36,)	text: )
# id: (37,)	text: .
#
# -----
#
# id: (1,)	text: Though
# id: (2,)	text: the
# id: (3,)	text: yellow
# id: (4,)	text: -
# id: (5,)	text: chick
# id: (6,)	text: bao
# id: (7,)	text: appearance
# id: (8,)	text: may
# id: (9,)	text: remind
# id: (10,)	text: some
# id: (11,)	text: of
# id: (12,)	text: Crystal
# id: (13,)	text: Jade
# id: (14,)	text: ’s
# id: (15,)	text: version
# id: (16,)	text: .
#
# -----
#
# id: (1,)	text: “
# id: (2,)	text: Aiyo
# id: (3,)	text: ,
# id: (4,)	text: why
# id: (5,)	text: so
# id: (6,)	text: cute
# id: (7,)	text: .
# id: (8,)	text: ”
#
# -----
#
# id: (1,)	text: (
# id: (2,)	text: Took
# id: (3,)	text: me
# id: (4,)	text: awhile
# id: (5,)	text: to
# id: (6,)	text: ‘
# id: (7,)	text: play
# id: (8,)	text: ’
# id: (9,)	text: around
# id: (10,)	text: with
# id: (11,)	text: it
# id: (12,)	text: and
# id: (13,)	text: snapped
# id: (14,)	text: tons
# id: (15,)	text: of
# id: (16,)	text: photos
# id: (17,)	text: before
# id: (18,)	text: I
# id: (19,)	text: reluctantly
# id: (20,)	text: popped
# id: (21,)	text: it
# id: (22,)	text: into
# id: (23,)	text: my
# id: (24,)	text: mouth
# id: (25,)	text: .
# id: (26,)	text: )
#
# -----
#
# id: (1,)	text: The
# id: (2,)	text: buns
# id: (3,)	text: were
# id: (4,)	text: steamed
# id: (5,)	text: soft
# id: (6,)	text: and
# id: (7,)	text: fluffy
# id: (8,)	text: ,
# id: (9,)	text: generously
# id: (10,)	text: stuffed
# id: (11,)	text: with
# id: (12,)	text: red
# id: (13,)	text: bean
# id: (14,)	text: or
# id: (15,)	text: lotus
# id: (16,)	text: paste
# id: (17,)	text: filing
# id: (18,)	text: .
#
# -----
#
# id: (1,)	text: I
# id: (2,)	text: liked
# id: (3,)	text: that
# id: (4,)	text: their
# id: (5,)	text: paste
# id: (6,)	text: filling
# id: (7,)	text: was
# id: (8,)	text: not
# id: (9,)	text: so
# id: (10,)	text: cloyingly
# id: (11,)	text: sweet
# id: (12,)	text: ,
# id: (13,)	text: which
# id: (14,)	text: made
# id: (15,)	text: it
# id: (16,)	text: very
# id: (17,)	text: much
# id: (18,)	text: enjoyable
# id: (19,)	text: .
#
# -----
#
# id: (1,)	text: There
# id: (2,)	text: was
# id: (3,)	text: also
# id: (4,)	text: the
# id: (5,)	text: Deep
# id: (6,)	text: -
# id: (7,)	text: Fried
# id: (8,)	text: Dumplings
# id: (9,)	text: with
# id: (10,)	text: Mushroom
# id: (11,)	text: (
# id: (12,)	text: $
# id: (13,)	text: 4
# id: (14,)	text: )
# id: (15,)	text: ,
# id: (16,)	text: molded
# id: (17,)	text: into
# id: (18,)	text: the
# id: (19,)	text: shape
# id: (20,)	text: of
# id: (21,)	text: a
# id: (22,)	text: carrot
# id: (23,)	text: then
# id: (24,)	text: embedded
# id: (25,)	text: with
# id: (26,)	text: a
# id: (27,)	text: stem
# id: (28,)	text: of
# id: (29,)	text: coriander
# id: (30,)	text: leaf
# id: (31,)	text: .
#
# -----
#
# id: (1,)	text: Plus
# id: (2,)	text: points
# id: (3,)	text: for
# id: (4,)	text: the
# id: (5,)	text: presentation
# id: (6,)	text: and
# id: (7,)	text: creativity
# id: (8,)	text: .
#
# -----
#
# id: (1,)	text: It
# id: (2,)	text: had
# id: (3,)	text: a
# id: (4,)	text: chewy
# id: (5,)	text: sweet
# id: (6,)	text: rice
# id: (7,)	text: cake
# id: (8,)	text: exterior
# id: (9,)	text: ,
# id: (10,)	text: filled
# id: (11,)	text: with
# id: (12,)	text: savoury
# id: (13,)	text: mushroom
# id: (14,)	text: bits
# id: (15,)	text: .
#
# -----
#
# id: (1,)	text: While
# id: (2,)	text: their
# id: (3,)	text: menu
# id: (4,)	text: is
# id: (5,)	text: not
# id: (6,)	text: that
# id: (7,)	text: extensive
# id: (8,)	text: ,
# id: (9,)	text: you
# id: (10,)	text: can
# id: (11,)	text: still
# id: (12,)	text: find
# id: (13,)	text: regular
# id: (14,)	text: dim
# id: (15,)	text: sum
# id: (16,)	text: suspects
# id: (17,)	text: such
# id: (18,)	text: as
# id: (19,)	text: Siew
# id: (20,)	text: Mai
# id: (21,)	text: (
# id: (22,)	text: $
# id: (23,)	text: 4.50
# id: (24,)	text: )
# id: (25,)	text: ,
# id: (26,)	text: Har
# id: (27,)	text: Kau
# id: (28,)	text: (
# id: (29,)	text: $
# id: (30,)	text: 4.50
# id: (31,)	text: )
# id: (32,)	text: ,
# id: (33,)	text: Pan-
# id: (34,)	text: fried
# id: (35,)	text: Carrot
# id: (36,)	text: Cake
# id: (37,)	text: (
# id: (38,)	text: $
# id: (39,)	text: 4.50
# id: (40,)	text: )
# id: (41,)	text: ,
# id: (42,)	text: BBQ
# id: (43,)	text: Pork
# id: (44,)	text: Cheong
# id: (45,)	text: Fun
# id: (46,)	text: (
# id: (47,)	text: $
# id: (48,)	text: 4.80
# id: (49,)	text: )
# id: (50,)	text: ,
# id: (51,)	text: Century
# id: (52,)	text: Egg
# id: (53,)	text: Congee
# id: (54,)	text: (
# id: (55,)	text: $
# id: (56,)	text: 4.80
# id: (57,)	text: )
# id: (58,)	text: and
# id: (59,)	text: Lotus
# id: (60,)	text: Leaf
# id: (61,)	text: Glutinous
# id: (62,)	text: Rice
# id: (63,)	text: (
# id: (64,)	text: $
# id: (65,)	text: 4.50
# id: (66,)	text: )
# id: (67,)	text: .
#
# -----
#
# id: (1,)	text: I
# id: (2,)	text: would
# id: (3,)	text: say
# id: (4,)	text: most
# id: (5,)	text: of
# id: (6,)	text: them
# id: (7,)	text: tasted
# id: (8,)	text: quite
# id: (9,)	text: decent
# id: (10,)	text: and
# id: (11,)	text: above
# id: (12,)	text: average
# id: (13,)	text: ,
# id: (14,)	text: with
# id: (15,)	text: most
# id: (16,)	text: hits
# id: (17,)	text: and
# id: (18,)	text: minor
# id: (19,)	text: misses
# id: (20,)	text: .
#
# -----
#
# id: (1,)	text: Worthy
# id: (2,)	text: of
# id: (3,)	text: mention
# id: (4,)	text: would
# id: (5,)	text: be
# id: (6,)	text: the
# id: (7,)	text: Pan-fried
# id: (8,)	text: Shredded
# id: (9,)	text: Yam
# id: (10,)	text: with
# id: (11,)	text: Golden
# id: (12,)	text: Pumpkin
# id: (13,)	text: (
# id: (14,)	text: $
# id: (15,)	text: 4
# id: (16,)	text: )
# id: (17,)	text: .
#
# -----
#
# id: (1,)	text: I
# id: (2,)	text: liked
# id: (3,)	text: how
# id: (4,)	text: they
# id: (5,)	text: sandwiched
# id: (6,)	text: soft
# id: (7,)	text: pumpkin
# id: (8,)	text: fillings
# id: (9,)	text: using
# id: (10,)	text: firm
# id: (11,)	text: yam
# id: (12,)	text: layer
# id: (13,)	text: for
# id: (14,)	text: the
# id: (15,)	text: differential
# id: (16,)	text: in
# id: (17,)	text: bite
# id: (18,)	text: texture
# id: (19,)	text: ,
# id: (20,)	text: before
# id: (21,)	text: being
# id: (22,)	text: pan-fried
# id: (23,)	text: till
# id: (24,)	text: golden
# id: (25,)	text: brown
# id: (26,)	text: for
# id: (27,)	text: the
# id: (28,)	text: crispy
# id: (29,)	text: exterior
# id: (30,)	text: .
#
# -----
#
# id: (1,)	text: Their
# id: (2,)	text: Shanghai
# id: (3,)	text: Xiao
# id: (4,)	text: Long
# id: (5,)	text: Bao
# id: (6,)	text: (
# id: (7,)	text: $
# id: (8,)	text: 8.80
# id: (9,)	text: )
# id: (10,)	text: was
# id: (11,)	text: also
# id: (12,)	text: memorable
# id: (13,)	text: ,
# id: (14,)	text: with
# id: (15,)	text: thin
# id: (16,)	text: dumpling
# id: (17,)	text: skin
# id: (18,)	text: encasing
# id: (19,)	text: marinated
# id: (20,)	text: minced
# id: (21,)	text: pork
# id: (22,)	text: swimming
# id: (23,)	text: in
# id: (24,)	text: a
# id: (25,)	text: pool
# id: (26,)	text: of
# id: (27,)	text: “
# id: (28,)	text: zhup
# id: (29,)	text: ”
# id: (30,)	text: (
# id: (31,)	text: gravy
# id: (32,)	text: )
# id: (33,)	text: .
#
# -----
#
# id: (1,)	text: *
# id: (2,)	text: Slurps
# id: (3,)	text: *
# id: (4,)	text: I
# id: (5,)	text: found
# id: (6,)	text: their
# id: (7,)	text: premises
# id: (8,)	text: quite
# id: (9,)	text: small
# id: (10,)	text: for
# id: (11,)	text: a
# id: (12,)	text: dim
# id: (13,)	text: sum
# id: (14,)	text: place
# id: (15,)	text: ;
# id: (16,)	text: it
# id: (17,)	text: has
# id: (18,)	text: only
# id: (19,)	text: space
# id: (20,)	text: for
# id: (21,)	text: 4
# id: (22,)	text: tables
# id: (23,)	text: on
# id: (24,)	text: upper
# id: (25,)	text: storey
# id: (26,)	text: and
# id: (27,)	text: 3
# id: (28,)	text: more
# id: (29,)	text: on
# id: (30,)	text: the
# id: (31,)	text: ground
# id: (32,)	text: floor
# id: (33,)	text: .
#
# -----
#
# id: (1,)	text: So
# id: (2,)	text: be
# id: (3,)	text: warned
# id: (4,)	text: of
# id: (5,)	text: the
# id: (6,)	text: waiting
# id: (7,)	text: time
# id: (8,)	text: due
# id: (9,)	text: to
# id: (10,)	text: limited
# id: (11,)	text: capacity
# id: (12,)	text: .
#
# -----
#
# id: (1,)	text: They
# id: (2,)	text: do
# id: (3,)	text: offer
# id: (4,)	text: reservations
# id: (5,)	text: on
# id: (6,)	text: weekday
# id: (7,)	text: ,
# id: (8,)	text: but
# id: (9,)	text: strictly
# id: (10,)	text: for
# id: (11,)	text: walk
# id: (12,)	text: -
# id: (13,)	text: ins
# id: (14,)	text: on
# id: (15,)	text: weekends
# id: (16,)	text: and
# id: (17,)	text: public
# id: (18,)	text: holiday
# id: (19,)	text: .
#
# -----
#
# id: (1,)	text: Dim
# id: (2,)	text: Sum
# id: (3,)	text: House

# %% [markdown]
# The sentences and tokens generated by Stanza appear to be much more consistent for the Food Reviews Scraping dataset.
# We can see 2 main details:
# 1. symbols such as ", (, ) and . are seen as tokens.
# 2. Float numbers are recognised and not used as EOS tokens.

# %%
def segment_sentences(directory):
    sentence_length = []
    print("Checking:",os.path.basename(directory))
    for file in os.listdir(directory):
        with open(os.path.join(directory,file),'r') as f:
            text = f.read()
            doc = nlp(text)
            for i, sentence in enumerate(doc.sentences):
                sentence_length.append(len(sentence.tokens))
    counter = Counter(sentence_length)
#     print(sentence_length)
    return counter
counter = segment_sentences(FOOD_REV_DIR)
# Out:
# Checking: food_reviews_scraping

# %%
def show_distribution(counter):
#     labels, values = zip(*counter.items())

#     indexes = np.arange(len(labels))
#     width = 1

#     plt.bar(indexes, values, width)
    plt.bar(list(counter.keys()), list(counter.values()))
    plt.show()
show_distribution(counter)

# %%
def get_sentences_of_length(directory, min_length=0, max_length=1000):
    sentence_length = []
    for file in os.listdir(directory):
        with open(os.path.join(directory,file),'r') as f:
            text = f.read()
            doc = nlp(text)
            for i, sentence in enumerate(doc.sentences):
                sentence_length.append(len(sentence.tokens))
                if len(sentence.tokens) >= min_length and len(sentence.tokens) < max_length:
                    print('\n-----\n')
                    print(*[token.text for token in sentence.tokens])

# %%
get_sentences_of_length(CV_PAPER_DIR, 1,2)
# Out:
# -----
#
# INTRODUCTION
#
# -----
#
# PEAKS
#
# -----
#
# 271
#
# -----
#
# 'I
#
# -----
#
# 8
#
# -----
#
# 'I
#
# -----
#
# I
#
# -----
#
# '
#
# -----
#
# /
#
# -----
#
# '
#
# -----
#
# I
#
# -----
#
# )
#
# -----
#
# \
#
# -----
#
# I
#
# -----
#
# \
#
# -----
#
# --.----r
#
# -----
#
# ,
#
# -----
#
# 'I
#
# -----
#
# ....
#
# -----
#
# ....
#
# -----
#
# TIME
#
# -----
#
# t
#
# -----
#
# 272
#
# -----
#
# v
#
# -----
#
# 273
#
# -----
#
# 274
#
# -----
#
# =>
#
# -----
#
# -----..'t-
#
# -----
#
# @
#
# -----
#
# =
#
# -----
#
# A
#
# -----
#
# @
#
# -----
#
# :
#
# -----
#
# V
#
# -----
#
# :
#
# -----
#
# j
#
# -----
#
# \
#
# -----
#
# t
#
# -----
#
# _________
#
# -----
#
# ~,_2__----
#
# -----
#
# @
#
# -----
#
# \.
#
# -----
#
# 275
#
# -----
#
# 276
#
# -----
#
# ...
#
# -----
#
# ..../
#
# -----
#
# -',
#
# -----
#
# \....
#
# -----
#
# ..
#
# -----
#
# '
#
# -----
#
# ....
#
# -----
#
# .......
#
# -----
#
# ..?.:....
#
# -----
#
# ....
#
# -----
#
# ?????
#
# -----
#
# ???.
#
# -----
#
# P
#
# -----
#
# 2
#
# -----
#
# ___.;.J
#
# -----
#
# 277
#
# -----
#
# CONCLUSIONS
#
# -----
#
# REFERENCES
#
# -----
#
# 20375-5000
#
# -----
#
# INTRODUCTION
#
# -----
#
# @
#
# -----
#
# 302
#
# -----
#
# 303
#
# -----
#
# +
#
# -----
#
# =
#
# -----
#
# 304
#
# -----
#
# 305
#
# -----
#
# -
#
# -----
#
# 306
#
# -----
#
# and
#
# -----
#
# '
#
# -----
#
# or
#
# -----
#
# 307
#
# -----
#
# DISCUSSION
#
# -----
#
# 308
#
# -----
#
# REFERENCES
#
# -----
#
# 309
#
# -----
#
# 1
#
# -----
#
# Abstract
#
# -----
#
# 220
#
# -----
#
# ?
#
# -----
#
# Calculating
#
# -----
#
# 221
#
# -----
#
# Cover
#
# -----
#
# 222
#
# -----
#
# References
#
# -----
#
# 623
#
# -----
#
# 624
#
# -----
#
# '.
#
# -----
#
# a
#
# -----
#
# ,
#
# -----
#
# SO
#
# -----
#
# 101
#
# -----
#
# ISO
#
# -----
#
# ZOO
#
# -----
#
# UI
#
# -----
#
# :~kfhJfEirQ
#
# -----
#
# )01
#
# -----
#
# II
#
# -----
#
# 100
#
# -----
#
# ISO
#
# -----
#
# 100
#
# -----
#
# 110
#
# -----
#
# '
#
# -----
#
# 50
#
# -----
#
# 100
#
# -----
#
# UO
#
# -----
#
# ZOO
#
# -----
#
# ZSO
#
# -----
#
# 100
#
# -----
#
# c
#
# -----
#
# .1
#
# -----
#
# '
#
# -----
#
# 100
#
# -----
#
# ISO
#
# -----
#
# 100
#
# -----
#
# 110
#
# -----
#
# lot
#
# -----
#
# LS
#
# -----
#
# =R
#
# -----
#
# 625
#
# -----
#
# =
#
# -----
#
# 626
#
# -----
#
# ~
#
# -----
#
# 0
#
# -----
#
# ~
#
# -----
#
# -
#
# -----
#
# '
#
# -----
#
# ~
#
# -----
#
# a
#
# -----
#
# -----------
#
# -----
#
# o
#
# -----
#
# 627
#
# -----
#
# 628
#
# -----
#
# b
#
# -----
#
# a
#
# -----
#
# c
#
# -----
#
# .n
#
# -----
#
# sa
#
# -----
#
# .sa
#
# -----
#
# _
#
# -----
#
# ut
#
# -----
#
# _
#
# -----
#
# pixel
#
# -----
#
# ...~~
#
# -----
#
# sa
#
# -----
#
# .
#
# -----
#
# ~
#
# -----
#
# -
#
# -----
#
# ~
#
# -----
#
# .
#
# -----
#
# _
#
# -----
#
# .
#
# -----
#
# ut
#
# -----
#
# _
#
# -----
#
# .
#
# -----
#
# ~
#
# -----
#
# ~
#
# -----
#
# (
#
# -----
#
# ut
#
# -----
#
# ,
#
# -----
#
# _
#
# -----
#
# 629
#
# -----
#
# 630
#
# -----
#
# 631
#
# -----
#
# ?
#
# -----
#
# 298
#
# -----
#
# SHORTCOMINGS
#
# -----
#
# 299
#
# -----
#
# DISCUSSION
#
# -----
#
# 300
#
# -----
#
# References
#
# -----
#
# Proc.
#
# -----
#
# Proc.
#
# -----
#
# ABSTRACT
#
# -----
#
# -
#
# -----
#
# ?
#
# -----
#
# 784
#
# -----
#
# 785
#
# -----
#
# Patient
#
# -----
#
# 786
#
# -----
#
# 787
#
# -----
#
# CONCLUSION
#
# -----
#
# REFERENCES
#
# -----
#
# 788
#
# -----
#
# 789
#
# -----
#
# 9
#
# -----
#
# 13
#
# -----
#
# STIMULUS
#
# -----
#
# BEHAVIOR
#
# -----
#
# 11
#
# -----
#
# I
#
# -----
#
# 15
#
# -----
#
# r----------~
#
# -----
#
# I
#
# -----
#
# L
#
# -----
#
# ..:
#
# -----
#
# -
#
# -----
#
# I
#
# -----
#
# SIGNAL
#
# -----
#
# I
#
# -----
#
# -
#
# -----
#
# ..J
#
# -----
#
# ?
#
# -----
#
# 17
#
# -----
#
# Sound
#
# -----
#
# 790
#
# -----
#
# AMPLIFICATION
#
# -----
#
# -----1~
#
# -----
#
# DISPERSION
#
# -----
#
# -----1~
#
# -----
#
# INTEGRATOR
#
# -----
#
# Sound
#
# -----
#
# 791
#
# -----
#
# m
#
# -----
#
# DISPERSION
#
# -----
#
# SORTER
#
# -----
#
# 792
#
# -----
#
# FUNCTION
#
# -----
#
# 1
#
# -----
#
# 1
#
# -----
#
# 1
#
# -----
#
# ---+---~.c
#
# -----
#
# 793
#
# -----
#
# 13121114131
#
# -----
#
# DISPERSION
#
# -----
#
# ~
#
# -----
#
# MICROPHONE
#
# -----
#
# ABSTRACT
#
# -----
#
# J
#
# -----
#
# 684
#
# -----
#
# >
#
# -----
#
# mn
#
# -----
#
# ~
#
# -----
#
# d
#
# -----
#
# 1
#
# -----
#
# 2
#
# -----
#
# ~
#
# -----
#
# ~
#
# -----
#
# Figure
#
# -----
#
# J
#
# -----
#
# K
#
# -----
#
# J
#
# -----
#
# 685
#
# -----
#
# ~
#
# -----
#
# =am
#
# -----
#
# 686
#
# -----
#
# on
#
# -----
#
# >
#
# -----
#
# Figure
#
# -----
#
# .
#
# -----
#
# 687
#
# -----
#
# ?
#
# -----
#
# 688
#
# -----
#
# and
#
# -----
#
# 689
#
# -----
#
# r
#
# -----
#
# =
#
# -----
#
# 690
#
# -----
#
# 691
#
# -----
#
# J
#
# -----
#
# J
#
# -----
#
# DISCUSSION
#
# -----
#
# 692
#
# -----
#
# ACKNOWLEOOEMENTS
#
# -----
#
# REFERENCES
#
# -----
#
# Proc.
#
# -----
#
# Abstract
#
# -----
#
# ...
#
# -----
#
# 0
#
# -----
#
# ZO
#
# -----
#
# ???
#
# -----
#
# ..
#
# -----
#
# ??..
#
# -----
#
# 516
#
# -----
#
# Introduction
#
# -----
#
# Classification
#
# -----
#
# 517
#
# -----
#
# -t-----tI----4t---t---f--.---1
#
# -----
#
# --
#
# -----
#
# Figure
#
# -----
#
# 518
#
# -----
#
# 519
#
# -----
#
# VDD
#
# -----
#
# Vj
#
# -----
#
# ~
#
# -----
#
# Excitatory
#
# -----
#
# J
#
# -----
#
# ?1
#
# -----
#
# Figure
#
# -----
#
# 520
#
# -----
#
# Input
#
# -----
#
# .1
#
# -----
#
# ..L
#
# -----
#
# 1..
#
# -----
#
# 02
#
# -----
#
# ..
#
# -----
#
# ,
#
# -----
#
# ...
#
# -----
#
# ...-
#
# -----
#
# ...
#
# -----
#
# Input
#
# -----
#
# !
#
# -----
#
# Figure
#
# -----
#
# 521
#
# -----
#
# Chip
#
# -----
#
# ~
#
# -----
#
# ~
#
# -----
#
# +
#
# -----
#
# ,
#
# -----
#
# 522
#
# -----
#
# Conclusion
#
# -----
#
# 523
#
# -----
#
# References
#
# -----
#
# 1
#
# -----
#
# 2
#
# -----
#
# 3
#
# -----
#
# 4
#
# -----
#
# 5
#
# -----
#
# 6
#
# -----
#
# Abstract
#
# -----
#
# Introduction
#
# -----
#
# ?
#
# -----
#
# 23
#
# -----
#
# outputs
#
# -----
#
# inputs
#
# -----
#
# du
#
# -----
#
# 24
#
# -----
#
# i
#
# -----
#
# Let
#
# -----
#
# Wi
#
# -----
#
# ith
#
# -----
#
# 25
#
# -----
#
# ~
#
# -----
#
# I
#
# -----
#
# '
#
# -----
#
# a=l
#
# -----
#
# =
#
# -----
#
# i=l
#
# -----
#
# 26
#
# -----
#
# inputs
#
# -----
#
# outputs
#
# -----
#
# Let
#
# -----
#
# I
#
# -----
#
# T
#
# -----
#
# ,
#
# -----
#
# 8y3
#
# -----
#
# JlBI
#
# -----
#
# 27
#
# -----
#
# LW~.Zk
#
# -----
#
# '
#
# -----
#
# i
#
# -----
#
# k
#
# -----
#
# where
#
# -----
#
# i
#
# -----
#
# k
#
# -----
#
# k
#
# -----
#
# Fig.
#
# -----
#
# 28
#
# -----
#
# z
#
# -----
#
# z
#
# -----
#
# z
#
# -----
#
# z
#
# -----
#
# z
#
# -----
#
# zil
#
# -----
#
# 1
#
# -----
#
# 3
#
# -----
#
# ~
#
# -----
#
# 3
#
# -----
#
# 3
#
# -----
#
# 3
#
# -----
#
# 3
#
# -----
#
# Conclusion
#
# -----
#
# aI
#
# -----
#
# aI
#
# -----
#
# m
#
# -----
#
# and
#
# -----
#
# '
#
# -----
#
# =
#
# -----
#
# 0
#
# -----
#
# ith
#
# -----
#
# aw
#
# -----
#
# '
#
# -----
#
# T
#
# -----
#
# ayl
#
# -----
#
# y
#
# -----
#
# .
#
# -----
#
# where
#
# -----
#
# '
#
# -----
#
# kth
#
# -----
#
# 30
#
# -----
#
# 8
#
# -----
#
# 8yJ
#
# -----
#
# j
#
# -----
#
# :~~.
#
# -----
#
# =
#
# -----
#
# ?
#
# -----
#
# T
#
# -----
#
# JEEr
#
# -----
#
# INTRODUCTION
#
# -----
#
# 243
#
# -----
#
# 244
#
# -----
#
# RESULTS
#
# -----
#
# Class
#
# -----
#
# Since
#
# -----
#
# 245
#
# -----
#
# Figure
#
# -----
#
# ~
#
# -----
#
# -
#
# -----
#
# -
#
# -----
#
# 8
#
# -----
#
# 6
#
# -----
#
# ~
#
# -----
#
# .
#
# -----
#
# ~
#
# -----
#
# ~
#
# -----
#
# "
#
# -----
#
# ;
#
# -----
#
# "
#
# -----
#
# ;
#
# -----
#
# ;
#
# -----
#
# 14
#
# -----
#
# -
#
# -----
#
# 12
#
# -----
#
# -
#
# -----
#
# 10
#
# -----
#
# ~
#
# -----
#
# 8
#
# -----
#
# 6
#
# -----
#
# 4
#
# -----
#
# ~
#
# -----
#
# 2
#
# -----
#
# .-
#
# -----
#
# o
#
# -----
#
# ;
#
# -----
#
# 1011121314151617181920
#
# -----
#
# Figure
#
# -----
#
# 14
#
# -----
#
# 14
#
# -----
#
# 12
#
# -----
#
# 12
#
# -----
#
# 10
#
# -----
#
# 10
#
# -----
#
# 8
#
# -----
#
# 8
#
# -----
#
# 6
#
# -----
#
# 6
#
# -----
#
# CII
#
# -----
#
# 4
#
# -----
#
# 4
#
# -----
#
# ~
#
# -----
#
# 2
#
# -----
#
# 2
#
# -----
#
# 0
#
# -----
#
# 0
#
# -----
#
# ?rot
#
# -----
#
# ~
#
# -----
#
# Po
#
# -----
#
# 0
#
# -----
#
# 1
#
# -----
#
# 2
#
# -----
#
# 3
#
# -----
#
# 0
#
# -----
#
# 1
#
# -----
#
# 2
#
# -----
#
# 3
#
# -----
#
# 246
#
# -----
#
# DISCUSSION
#
# -----
#
# 247
#
# -----
#
# 248
#
# -----
#
# Abstract
#
# -----
#
# Introduction
#
# -----
#
# ?
#
# -----
#
# 486
#
# -----
#
# s
#
# -----
#
# 7
#
# -----
#
# 487
#
# -----
#
# where
#
# -----
#
# 488
#
# -----
#
# '
#
# -----
#
# 489
#
# -----
#
# 490
#
# -----
#
# 491
#
# -----
#
# 492
#
# -----
#
# 493
#
# -----
#
# 494
#
# -----
#
# References
#
# -----
#
# ?
#
# -----
#
# 613
#
# -----
#
# Figure
#
# -----
#
# a
#
# -----
#
# 0:::1
#
# -----
#
# 614
#
# -----
#
# COl
#
# -----
#
# '
#
# -----
#
# .u
#
# -----
#
# Figure
#
# -----
#
# x
#
# -----
#
# 615
#
# -----
#
# *.
#
# -----
#
# '
#
# -----
#
# '
#
# -----
#
# ~
#
# -----
#
# '
#
# -----
#
# 616
#
# -----
#
# ./
#
# -----
#
# /
#
# -----
#
# '
#
# -----
#
# state
#
# -----
#
# \
#
# -----
#
# Figure
#
# -----
#
# 617
#
# -----
#
# 2
#
# -----
#
# ~
#
# -----
#
# 0
#
# -----
#
# 618
#
# -----
#
# ~
#
# -----
#
# a
#
# -----
#
# .
#
# -----
#
# af
#
# -----
#
# ag
#
# -----
#
# 2
#
# -----
#
# 619
#
# -----
#
# 5,10,11,13
#
# -----
#
# i
#
# -----
#
# Figure
#
# -----
#
# 620
#
# -----
#
# O.
#
# -----
#
# ;
#
# -----
#
# ,
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# .
#
# -----
#
# '
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# ???
#
# -----
#
# ?
#
# -----
#
# .
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# ??????
#
# -----
#
# '
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# ,
#
# -----
#
# ?
#
# -----
#
# .
#
# -----
#
# ?
#
# -----
#
# .?
#
# -----
#
# ?
#
# -----
#
# ?????
#
# -----
#
# ....
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# .
#
# -----
#
# .
#
# -----
#
# ???.
#
# -----
#
# ?
#
# -----
#
# '
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# .
#
# -----
#
# ?
#
# -----
#
# .....
#
# -----
#
# 621
#
# -----
#
# Acknowledgments
#
# -----
#
# References
#
# -----
#
# INTRODUCTION
#
# -----
#
# 1
#
# -----
#
# ?
#
# -----
#
# 776
#
# -----
#
# 13
#
# -----
#
# 14
#
# -----
#
# inputs
#
# -----
#
# 1
#
# -----
#
# V
#
# -----
#
# o
#
# -----
#
# +u
#
# -----
#
# n
#
# -----
#
# E
#
# -----
#
# n
#
# -----
#
# n
#
# -----
#
# L
#
# -----
#
# 777
#
# -----
#
# ?
#
# -----
#
# 0
#
# -----
#
# 0
#
# -----
#
# ??
#
# -----
#
# ??
#
# -----
#
# ?
#
# -----
#
# 0
#
# -----
#
# ?
#
# -----
#
# 0
#
# -----
#
# ?
#
# -----
#
# Sites
#
# -----
#
# n
#
# -----
#
# m
#
# -----
#
# i=l
#
# -----
#
# j=l
#
# -----
#
# 778
#
# -----
#
# CONCENTRATORS
#
# -----
#
# /r
#
# -----
#
# SITES
#
# -----
#
# 1
#
# -----
#
# 2
#
# -----
#
# ~~
#
# -----
#
# i
#
# -----
#
# '~n
#
# -----
#
# ~
#
# -----
#
# :
#
# -----
#
# :
#
# -----
#
# -
#
# -----
#
# -
#
# -----
#
# -
#
# -----
#
# -
#
# -----
#
# :.
#
# -----
#
# -
#
# -----
#
# II
#
# -----
#
# ??
#
# -----
#
# 779
#
# -----
#
# E
#
# -----
#
# =
#
# -----
#
# A
#
# -----
#
# m
#
# -----
#
# 2
#
# -----
#
# +
#
# -----
#
# B
#
# -----
#
# m
#
# -----
#
# n+k?
#
# -----
#
# j=1
#
# -----
#
# i=1
#
# -----
#
# IJ
#
# -----
#
# J
#
# -----
#
# 780
#
# -----
#
# and
#
# -----
#
# 781
#
# -----
#
# SITES
#
# -----
#
# 1
#
# -----
#
# 5
#
# -----
#
# @
#
# -----
#
# .46
#
# -----
#
# .40
#
# -----
#
# .63
#
# -----
#
# .39
#
# -----
#
# .92
#
# -----
#
# .38
#
# -----
#
# .81
#
# -----
#
# .56
#
# -----
#
# @
#
# -----
#
# .51
#
# -----
#
# .76
#
# -----
#
# .46
#
# -----
#
# .39
#
# -----
#
# .77
#
# -----
#
# .41
#
# -----
#
# H
#
# -----
#
# @
#
# -----
#
# .81
#
# -----
#
# .54
#
# -----
#
# .52
#
# -----
#
# I
#
# -----
#
# .60
#
# -----
#
# .67
#
# -----
#
# .44
#
# -----
#
# J
#
# -----
#
# @
#
# -----
#
# .76
#
# -----
#
# K
#
# -----
#
# .42
#
# -----
#
# .33
#
# -----
#
# .55
#
# -----
#
# L
#
# -----
#
# @
#
# -----
#
# A
#
# -----
#
# .47
#
# -----
#
# .28
#
# -----
#
# B
#
# -----
#
# .72
#
# -----
#
# .75
#
# -----
#
# C
#
# -----
#
# .95
#
# -----
#
# .71
#
# -----
#
# D
#
# -----
#
# .78
#
# -----
#
# E
#
# -----
#
# .31
#
# -----
#
# .62
#
# -----
#
# F
#
# -----
#
# .25
#
# -----
#
# G
#
# -----
#
# .55
#
# -----
#
# .71
#
# -----
#
# CONCLUSION
#
# -----
#
# 782
#
# -----
#
# Frequency
#
# -----
#
# Frequency
#
# -----
#
# 5
#
# -----
#
# 3.2
#
# -----
#
# 4.2
#
# -----
#
# 5.2
#
# -----
#
# 6.2
#
# -----
#
# 7.2
#
# -----
#
# Cost
#
# -----
#
# o
#
# -----
#
# 8.2
#
# -----
#
# REFERENCES
# -----
#
# ABSTRACT
#
# -----
#
# INTRODUCTION
#
# -----
#
# @
#
# -----
#
# 378
#
# -----
#
# .
#
# -----
#
# "
#
# -----
#
# .....
#
# -----
#
# ..
#
# -----
#
# '.
#
# -----
#
# '
#
# -----
#
# ......
#
# -----
#
# Figure
#
# -----
#
# The
#
# -----
#
# 379
#
# -----
#
# 380
#
# -----
#
# '
#
# -----
#
# .a:..J
#
# -----
#
# ~
#
# -----
#
# ~
#
# -----
#
# ~.
#
# -----
#
# (
#
# -----
#
# i
#
# -----
#
# ?
#
# -----
#
# '
#
# -----
#
# .r
#
# -----
#
# I
#
# -----
#
# Fig.
#
# -----
#
# 381
#
# -----
#
# 382
#
# -----
#
# 383
#
# -----
#
# laser
#
# -----
#
# ~---,t+
#
# -----
#
# -
#
# -----
#
# PB
#
# -----
#
# Xtal
#
# -----
#
# PM
#
# -----
#
# Figure
#
# -----
#
# 384
#
# -----
#
# 385
#
# -----
#
# -~t
#
# -----
#
# -~t
#
# -----
#
# -~t
#
# -----
#
# 2
#
# -----
#
# T
#
# -----
#
# -
#
# -----
#
# ??
#
# -----
#
# +.+
#
# -----
#
# Y
#
# -----
#
# 1
#
# -----
#
# 3
#
# -----
#
# 2
#
# -----
#
# 4
#
# -----
#
# Figure
#
# -----
#
# ...
#
# -----
#
# 1'1
#
# -----
#
# j
#
# -----
#
# Ia.
#
# -----
#
# !
#
# -----
#
# l
#
# -----
#
# t
#
# -----
#
# 0
#
# -----
#
# ~
#
# -----
#
# W
#
# -----
#
# Figure
#
# -----
#
# Fig.
#
# -----
#
# 386
#
# -----
#
# CONCLUSION
#
# -----
#
# ACKNOWLEDGEMENTS
#
# -----
#
# REFERENCES
#
# -----
#
# 4
#
# -----
#
# 53
#
# -----
#
# Wij
#
# -----
#
# Vj
#
# -----
#
# denotes
#
# -----
#
# 54
#
# -----
#
# 55
#
# -----
#
# E
#
# -----
#
# where
#
# -----
#
# oj
#
# -----
#
# and
#
# -----
#
# 6
#
# -----
#
# Let
#
# -----
#
# tj
#
# -----
#
# 56
#
# -----
#
# fL.
#
# -----
#
# tJ
#
# -----
#
# Let
#
# -----
#
# =
#
# -----
#
# or
#
# -----
#
# 57
#
# -----
#
# =L
#
# -----
#
# Say
#
# -----
#
# tj
#
# -----
#
# *
#
# -----
#
# tj
#
# -----
#
# 58
#
# -----
#
# 59
#
# -----
#
# 60
#
# -----
#
# References
#
# -----
#
# 61
#
# -----
#
# ?
#
# -----
#
# 185
#
# -----
#
# I
#
# -----
#
# 186
#
# -----
#
# Figure
#
# -----
#
# 187
#
# -----
#
# i=l
#
# -----
#
# 188
#
# -----
#
# Let
#
# -----
#
# and
#
# -----
#
# ~-
#
# -----
#
# J
#
# -----
#
# n_
#
# -----
#
# P{y
#
# -----
#
# 189
#
# -----
#
# 0.8
#
# -----
#
# 0.6
#
# -----
#
# "
#
# -----
#
# 1Il.2
#
# -----
#
# 1Il.3
#
# -----
#
# J
#
# -----
#
# 190
#
# -----
#
# liLS
#
# -----
#
# CONCLUSION
#
# -----
#
# 191
#
# -----
#
# REFERENCES
#
# -----
#
# Rep.
#
# -----
#
# INTRODUCTION
#
# -----
#
# Parameter
#
# -----
#
# Type
#
# -----
#
# .
#
# -----
#
# ?
#
# -----
#
# i
#
# -----
#
# Algorithm
#
# -----
#
# 769
#
# -----
#
# min
#
# -----
#
# '
#
# -----
#
# 770
#
# -----
#
# NOV
#
# -----
#
# '
#
# -----
#
# ~~~~~of~~
#
# -----
#
# 2~~---------------
#
# -----
#
# '
#
# -----
#
# '
#
# -----
#
# H
#
# -----
#
# o
#
# -----
#
# 1000
#
# -----
#
# 2000
#
# -----
#
# 3000
#
# -----
#
# 4000
#
# -----
#
# o
#
# -----
#
# 1000
#
# -----
#
# 2000
#
# -----
#
# 3000
#
# -----
#
# 4000
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# 771
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# 22
#
# -----
#
# 11
#
# -----
#
# Roan
#
# -----
#
# 12
#
# -----
#
# {-
#
# -----
#
# 13
#
# -----
#
# ~
#
# -----
#
# I
#
# -----
#
# ,
#
# -----
#
# 23
#
# -----
#
# 24
#
# -----
#
# rmbi
#
# -----
#
# -
#
# -----
#
# Roan
#
# -----
#
# y
#
# -----
#
# t
#
# -----
#
# 772
#
# -----
#
# Wall
#
# -----
#
# Preprocessing
#
# -----
#
# A
#
# -----
#
# ?
#
# -----
#
# Preprocessing
#
# -----
#
# 0
#
# -----
#
# O
#
# -----
#
# ??
#
# -----
#
# ..
#
# -----
#
# Search
#
# -----
#
# A
#
# -----
#
# x
#
# -----
#
# ?
#
# -----
#
# 773
#
# -----
#
# ?
#
# -----
#
# "
#
# -----
#
# "
#
# -----
#
# .
#
# -----
#
# I
#
# -----
#
# "
#
# -----
#
# ;
#
# -----
#
# i
#
# -----
#
# 774
#
# -----
#
# CONCLUSION
#
# -----
#
# REFERENCES
#
# -----
#
# '
#
# -----
#
# ABSTRACT
#
# -----
#
# INTRODUCTION
#
# -----
#
# ?
#
# -----
#
# 32
#
# -----
#
# W
#
# -----
#
# fT
#
# -----
#
# ?
#
# -----
#
# 33
#
# -----
#
# ...
#
# -----
#
# and
#
# -----
#
# where
#
# -----
#
# and
#
# -----
#
# .
#
# -----
#
# -
#
# -----
#
# ?
#
# -----
#
# 34
#
# -----
#
# -
#
# -----
#
# -
#
# -----
#
# -
#
# -----
#
# 1
#
# -----
#
# k
#
# -----
#
# 2
#
# -----
#
# n-
#
# -----
#
# 36
#
# -----
#
# ?
#
# -----
#
# !!
#
# -----
#
# 4
#
# -----
#
# ~
#
# -----
#
# !
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# '
#
# -----
#
# ,
#
# -----
#
# I
#
# -----
#
# if
#
# -----
#
# ,
#
# -----
#
# lU
#
# -----
#
# 'I
#
# -----
#
# U
#
# -----
#
# '
#
# -----
#
# -
#
# -----
#
# N
#
# -----
#
# 11=0
#
# -----
#
# where
#
# -----
#
# 37
#
# -----
#
# DISCUSSION
#
# -----
#
# 38
#
# -----
#
# 1'1
#
# -----
#
# ~
#
# -----
#
# U
#
# -----
#
# --{.
#
# -----
#
# !
#
# -----
#
# e
#
# -----
#
# ~
#
# -----
#
# z
#
# -----
#
# ?f-t
#
# -----
#
# -
#
# -----
#
# -.
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# 51
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# en
#
# -----
#
# TIme
#
# -----
#
# ~
#
# -----
#
# !.
#
# -----
#
# !
#
# -----
#
# 1
#
# -----
#
# 1
#
# -----
#
# ~
#
# -----
#
# z
#
# -----
#
# .:-
#
# -----
#
# ~
#
# -----
#
# ~
#
# -----
#
# ?
#
# -----
#
# l
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# j
#
# -----
#
# I
#
# -----
#
# u
#
# -----
#
# I
#
# -----
#
# tu
#
# -----
#
# TIme
#
# -----
#
# 39
#
# -----
#
# ---{'.-\
#
# -----
#
# j
#
# -----
#
# '
#
# -----
#
# at
#
# -----
#
# i!!
#
# -----
#
# e
#
# -----
#
# zii
#
# -----
#
# ~
#
# -----
#
# C
#
# -----
#
# ?
#
# -----
#
# ?
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# 51
#
# -----
#
# u
#
# -----
#
# '1
#
# -----
#
# i!!
#
# -----
#
# z
#
# -----
#
# ~
#
# -----
#
# C
#
# -----
#
# ?
#
# -----
#
# It
#
# -----
#
# ?
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# ,
#
# -----
#
# ?
#
# -----
#
# 40
#
# -----
#
# ABSTRACT
#
# -----
#
# INTRODUCTION
#
# -----
#
# .
#
# -----
#
# 1
#
# -----
#
# 1
#
# -----
#
# 1
#
# -----
#
# ?
#
# -----
#
# 475
#
# -----
#
# !
#
# -----
#
# dt
#
# -----
#
# '
#
# -----
#
# dt
#
# -----
#
# 1
#
# -----
#
# Er
#
# -----
#
# 1
#
# -----
#
# ds
#
# -----
#
# I
#
# -----
#
# 476
#
# -----
#
# Method
#
# -----
#
# '
#
# -----
#
# Does
#
# -----
#
# 477
#
# -----
#
# F
#
# -----
#
# J
#
# -----
#
# Method
#
# -----
#
# dt
#
# -----
#
# =
#
# -----
#
# T
#
# -----
#
# G
#
# -----
#
# In
#
# -----
#
# Methods
#
# -----
#
# 478
#
# -----
#
# =
#
# -----
#
# d
#
# -----
#
# c
#
# -----
#
# ~
#
# -----
#
# =
#
# -----
#
# '
#
# -----
#
# 479
#
# -----
#
# I
#
# -----
#
# ,
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# ,
#
# -----
#
# I
#
# -----
#
# v
#
# -----
#
# v
#
# -----
#
# I
#
# -----
#
# -
#
# -----
#
# ~
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# ~
#
# -----
#
# ~
#
# -----
#
# #
#
# -----
#
# ...
#
# -----
#
# 1
#
# -----
#
# =-
#
# -----
#
# -
#
# -----
#
# 4
#
# -----
#
# 3
#
# -----
#
# r
#
# -----
#
# 480
#
# -----
#
# time
#
# -----
#
# 1
#
# -----
#
# 100
#
# -----
#
# 2
#
# -----
#
# 78
#
# -----
#
# 75
#
# -----
#
# 3
#
# -----
#
# 71
#
# -----
#
# 74
#
# -----
#
# 7
#
# -----
#
# 59
#
# -----
#
# 63
#
# -----
#
# 10
#
# -----
#
# 49
#
# -----
#
# 60
#
# -----
#
# 13
#
# -----
#
# 110
#
# -----
#
# 39
#
# -----
#
# 0.030
#
# -----
#
# DISCUSSION
#
# -----
#
# 481
#
# -----
#
# V..
#
# -----
#
# transitions
#
# -----
#
# 5
#
# -----
#
# I
#
# -----
#
# 6
#
# -----
#
# Vv
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# I
#
# -----
#
# 33
#
# -----
#
# 5
#
# -----
#
# 0
#
# -----
#
# 40
#
# -----
#
# 0
#
# -----
#
# 46
#
# -----
#
# I
#
# -----
#
# 53
#
# -----
#
# I
#
# -----
#
# 2
#
# -----
#
# I
#
# -----
#
# 2
#
# -----
#
# 0
#
# -----
#
# I
#
# -----
#
# !
#
# -----
#
# 0
#
# -----
#
# Figure
#
# -----
#
# 482
#
# -----
#
# a)
#
# -----
#
# 1
#
# -----
#
# 483
#
# -----
#
# APPENDIX
#
# -----
#
# -
#
# -----
#
# dgj
#
# -----
#
# dt
#
# -----
#
# i
#
# -----
#
# dt
#
# -----
#
# dt
#
# -----
#
# dt
#
# -----
#
# _v
#
# -----
#
# dt
#
# -----
#
# j
#
# -----
#
# dt
#
# -----
#
# dt
#
# -----
#
# --~-
#
# -----
#
# S
#
# -----
#
# vo.
#
# -----
#
# 484
#
# -----
#
# ACKNOWLEDGEMENTS
#
# -----
#
# REFERENCES
#
# -----
#
# INTRODUCTION
#
# -----
#
# 565
#
# -----
#
# 566
#
# -----
#
# 32
#
# -----
#
# vG
#
# -----
#
# ______~~~----~~----_=~
#
# -----
#
# \
#
# -----
#
# SETRST
#
# -----
#
# --------I
#
# -----
#
# \
#
# -----
#
# S
#
# -----
#
# ?
#
# -----
#
# R
#
# -----
#
# Q
#
# -----
#
# 0
#
# -----
#
# .
#
# -----
#
# 32
#
# -----
#
# ?
#
# -----
#
# Figure
#
# -----
#
# ...
#
# -----
#
# ~
#
# -----
#
# '
#
# -----
#
# .
#
# -----
#
# Figure
#
# -----
#
# =
#
# -----
#
# 567
#
# -----
#
# Figure
#
# -----
#
# 568
#
# -----
#
# 569
#
# -----
#
# Figure
#
# -----
#
# 570
#
# -----
#
# j
#
# -----
#
# =
#
# -----
#
# S
#
# -----
#
# CONCLUSIONS
#
# -----
#
# Synaptic
#
# -----
#
# 571
#
# -----
#
# Figure
#
# -----
#
# ACKNOWLEDGEMENTS
#
# -----
#
# REFERENCES
#
# -----
#
# 572

# %% [markdown]
# We see that the sentences that seem to be longer is because the tokenizer recognises symbols such as (, $ and ) as standalone tokens. This might cause these sentences to appear longer than they seem to be and can affect our comparisons with datasets of other domains.

# %%
# get_sentences_of_length(22,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4dc51c283297> in <module>()
# ----> 1 get_sentences_of_length(22,30)
#
# <ipython-input-8-4a207d6cb6d3> in get_sentences_of_length(directory, min_length, max_length)
#       1 def get_sentences_of_length(directory, min_length=0, max_length=1000):
#       2     sentence_length = []
# ----> 3     for file in os.listdir(directory):
#       4         with open(os.path.join(directory,file),'r') as f:
#       5             text = f.read()
#
# TypeError: listdir: path should be string, bytes, os.PathLike or None, not int

# %% [markdown]
# As we mentioned before, special symbols including " get considered as an individual token. Here, we also see that words such as "doesn't" gets split into 2 tokens instead of one.

# %% [markdown]
# ### 2.1 Comparing All Datasets
# Now we try to parse and analyze the other 2 domain datasets.

# %%
for dataset_dir in [FOOD_REV_DIR, CV_PAPER_DIR, GAME_DIR]:
    count = segment_sentences(dataset_dir)
    print(count)
    show_distribution(count)
# Out:
# Checking: food_reviews_scraping
# Counter({8: 42, 19: 40, 16: 37, 21: 37, 11: 36, 10: 35, 20: 34, 2: 33, 13: 30, 15: 29, 18: 28, 30: 28, 12: 28, 24: 28, 17: 27, 26: 26, 9: 24, 22: 24, 7: 24, 28: 22, 25: 22, 29: 21, 32: 20, 33: 19, 27: 19, 23: 17, 14: 16, 6: 15, 31: 14, 35: 13, 1: 13, 5: 12, 34: 11, 42: 9, 39: 9, 38: 9, 41: 9, 4: 8, 37: 7, 40: 7, 44: 6, 36: 6, 43: 5, 45: 5, 3: 4, 48: 4, 47: 4, 67: 3, 53: 3, 68: 3, 54: 3, 50: 3, 65: 3, 46: 3, 71: 2, 49: 2, 55: 2, 57: 2, 61: 2, 56: 2, 59: 1, 58: 1, 64: 1, 87: 1, 70: 1, 81: 1, 74: 1, 62: 1, 84: 1, 69: 1})
# Checking: Deep Learning and Computer Vision papers
# Counter({1: 1219, 2: 497, 3: 336, 4: 158, 5: 155, 12: 150, 15: 141, 20: 134, 18: 129, 6: 128, 16: 123, 8: 122, 7: 121, 19: 120, 21: 120, 13: 119, 10: 118, 14: 117, 17: 113, 9: 110, 24: 108, 22: 108, 11: 105, 25: 100, 23: 97, 26: 90, 30: 76, 27: 73, 32: 65, 28: 60, 31: 59, 29: 55, 35: 52, 37: 45, 33: 45, 36: 44, 34: 38, 38: 29, 39: 26, 40: 25, 44: 20, 43: 19, 45: 18, 42: 18, 41: 17, 49: 17, 50: 16, 48: 14, 46: 13, 53: 13, 47: 13, 52: 12, 55: 8, 62: 8, 54: 7, 51: 6, 63: 4, 61: 4, 58: 4, 65: 4, 56: 4, 59: 3, 57: 3, 69: 3, 68: 3, 70: 2, 77: 2, 60: 2, 93: 2, 79: 2, 71: 1, 81: 1, 89: 1, 88: 1, 84: 1, 107: 1, 95: 1, 66: 1, 92: 1, 64: 1, 117: 1, 116: 1, 168: 1, 76: 1, 102: 1, 75: 1, 101: 1, 85: 1, 72: 1, 143: 1, 78: 1})
# Checking: darren_documents
# Counter({1: 4823, 2: 2214, 6: 1808, 7: 1778, 10: 1773, 13: 1772, 12: 1755, 11: 1744, 9: 1737, 15: 1735, 8: 1704, 3: 1685, 14: 1668, 5: 1597, 16: 1583, 4: 1515, 17: 1438, 18: 1435, 19: 1226, 20: 1199, 21: 1115, 22: 939, 23: 884, 24: 846, 25: 684, 26: 659, 27: 630, 28: 563, 29: 454, 30: 435, 32: 368, 31: 368, 33: 361, 34: 297, 35: 226, 36: 205, 37: 187, 38: 162, 40: 160, 39: 160, 41: 143, 44: 127, 43: 116, 42: 114, 46: 87, 45: 84, 49: 75, 47: 63, 48: 58, 50: 51, 51: 49, 53: 36, 57: 34, 56: 32, 52: 29, 54: 28, 55: 28, 59: 25, 58: 17, 63: 16, 62: 14, 68: 13, 67: 12, 65: 12, 66: 11, 61: 10, 69: 9, 75: 9, 77: 9, 60: 9, 64: 9, 72: 8, 104: 8, 73: 7, 71: 6, 70: 6, 87: 6, 79: 5, 85: 5, 84: 5, 107: 4, 76: 4, 93: 4, 88: 4, 97: 4, 103: 4, 110: 4, 91: 3, 106: 3, 74: 3, 100: 3, 89: 3, 86: 3, 131: 3, 102: 3, 153: 2, 148: 2, 114: 2, 121: 2, 120: 2, 174: 2, 80: 2, 113: 2, 94: 2, 101: 2, 105: 2, 108: 2, 239: 2, 212: 2, 134: 2, 109: 2, 90: 2, 213: 1, 118: 1, 117: 1, 152: 1, 99: 1, 116: 1, 119: 1, 139: 1, 127: 1, 132: 1, 156: 1, 135: 1, 237: 1, 155: 1, 202: 1, 96: 1, 95: 1, 128: 1, 125: 1, 112: 1, 115: 1, 129: 1, 225: 1, 146: 1, 250: 1, 145: 1, 263: 1, 83: 1, 78: 1, 220: 1, 98: 1, 82: 1, 163: 1, 178: 1, 123: 1, 273: 1, 218: 1, 207: 1, 221: 1, 159: 1, 161: 1, 251: 1, 320: 1, 224: 1, 240: 1, 196: 1, 247: 1})

# %% [markdown]
# ### 3.1 Analysing Outliers
# We see that there are numerous sentences that seem to have an absurd number of tokens in them. We will need to take a closer look to see if they are reliable or whether they should be seen as outliers.

# %%
get_sentences_of_length(GAME_DIR, 200)
# Out:
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~| | - Table of Contents ..................... CT.TS | | - Walkthrough ........................... 01.00 | | - Prologue......................... 01.01 | | - Silent Hill ...................... 01.02 | | - Getting to School ................ 01.03 | | - Midwich Elementary School........ 01.04 | | - Alternate School................. 01.05 | | - Silent Hill ...................... 01.06 | | - Alchemilla Hospital.............. 01.07 | | - Alternate Hospital............... 01.08 | | - Silent Hill ...................... 01.09 | | - Alternate Silent Hill ............ 01.10 | | - Silent Hill ...................... 01.11 | | - Sewers ........................... 01.12 | | - Silent Hill ...................... 01.13 | | - Kaufmann Sidequest ............... 01.14 | | - Alternate Silent Hill ............ 01.15 | | - Sewers PArt II ................... 01.16 | | - Amusement Park ................... 01.17 | | - Nowhere .......................... 01.18 | | - Boss Guide ............................ 02.00 | | - Lizard ........................... 02.01 | | - Larva ............................ 02.02 | | - Moth............................. 02.03 | | - Woman............................ 02.04 | | - Final Boss ....................... 02.05 | | - Endings ............................... 03.00 | | - Item Locations ........................ 04.00 | | - Item List ............................. 05.00 | | - Legal & Copyright ..................... LE. AL | | - Credits & Thanks ...................... CR. DS | |____________________________________________________________________________|
#
# -----
#
# _____ _______ , -' ___ | _ _ `-. , -' / , -' \|| |.-. | \ ,'|________ |`. |`._____.-. | | / / | || | _______ | \ | |_ __ , ' | | | | `. , '| | | | | | | || | `. __ || \ | | | | | |___| | | | | | | | \ `-.___ | | | | | | ` || |\ \ | | | | | ___ | | | | | | | `-.___ `-. | | | | | |__ | | \ | | | | | | | | | | | | | `-. | | | |___| __| | | \ | | | | | | | | | | |___| | | |_ || | | | | \ _| | | | | | | | | | | | / / '-----| |__, || , ' | _| | | | |, '_`.'-----| |______,| | \___,-' / , '_____| `.| `.| ,'_________| |_____,-' __ __ | `. __ |\ | __ __ | | | `. | | , ' `.\ / | \ | | `. , ' `. | | |__, ' |__ , ' | | \ /\ / | \| |__.' | | '._ ,' | `. '.__ , ' \/ \/ | '.__,
#
# -----
#
# .'¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯'. | | | Directional Buttons : | | | | Up : Select items / Display item menu. | | | | RIGHT : Quick Heal. | | | | Left : Holster Gun. | | | | Down : Use Lighter . | | | | Left Stick : Select items / Move / Shake off enemy . | | | | Left Stick + R1 : Run. | | | | L3 : Turn the flashlight ON / OFF . | | | | Right Stick : Rotate camera. | | | | R3 : Zoom camera . | | | | X Button : Select / Interact with items . | | | | Circle : Cancel / Discard items / Put away flashlight . | | | | Square : Attack ( hold for Strong attack ) . | | | | Triangle : Block. | | | | L1 : Look back ( see what 's behind Murphy ) . | | | | L2 : Lock on / Aim / Aim weapon . | | | | R2 : Throw item / Toggle display / Fire gun . | | | | Start Button :
#
# -----
#
# _____ _ _ ____ _ _ _____ _ _ _ _ _ / _ \| | | | | __|| \ | ||_ _| | | | || | | | | | | | |_|| | | | | | | \ | | | | | | | || | | | | | | \___ | | | | | |_ | \ | | | | | |_| | | | | | | | \___ \| | | | | _| | |\ \ | | | | | _ || | | | | | _ \ || | | | | | | | \ | | | | | | || | | | | | | |_| | | | | |__ | |__ | | \ | | | | | | || || |__ | |__ \_____/|_||____||____||_| \_| |_| |_| |_||_||____||____| _ _ ___ _ _ _ __ | \ | / \ | | | / \ | | | | \ | | | | | | | | | | | | | | |_ | _/ | | | | | _ | | | | | | | | | | | | | | | | | | | | |__ \_/ | \_/ \_/ _ |_/ |__
#
# -----
#
# ======================================================================= | | | # ###### ### | | / # ## # # ## | | / # # # ## ## # | | # # # # ## # # | | # # # ## # # | | # # ### ### ## /# # ### / # ## # ## # # ### | | # ## ### ### # # / # ## # ## / # ### / # ## # # ## # | | # ## ### # # # # / # ## # # # ## / # # | | # ## /# # ## # # # # # ## # # # # # # | | # / /# # ## # # ### # #### # # # # # # | | # / # # ## ## ### #### # # # # # # | | # / # # # # # # # # # # # # | | /# # / # # # # #### / # # # # # # | | / # # # # # # ## / ### / ### / # ## # ## / # ## ### # # | | / # # # # # ## / ## / # # # ## # ## ### # # | | | | | \)
#
# -----
#
# ------------------------- | | P L O T A N A L Y S I S | | ------------------------- | | | | # # ### ## # ## ### | | # ## # ## / #### / # ### # ## | | /# / / # # # # / # ## ## # # | | / / / # # # # # # # | | / / # # # # # | | # # ## # ### # # # # | | # # ## # ### # # # # | | # # #### #### # # # # # # | | # # ## # # # # # # # | | # # ## # # # # # # # # | | # # # ## # # # # # # | | / # # # # # # # # | | / # # / # # ## # # # # | | / # # # ## # # ### / ### / # ## / | | / # # # # / ## / # # / | | # | | ## | | | =======================================================================
#
# -----
#
# About the monster in the water Photo on chair Picture in the gallery " Thus one 's life turns to riches " Fairy tale , Beginning Fairy tale , continued Fairy tale , Last Part Silent Hill Tourist Information About Leonard and Stanley 2 F east hall memo ( Easy Riddle Level ) 2 F east hall memo ( Normal Riddle Level ) 2 F east hall memo ( Hard Riddle Level ) Corpse tattoo Memo about the corpse Photo - Backside of shelf " Hope House " article Stanley 's diary ( Visiting room ) Stanley 's diary ( Room C4 ) Stanley 's diary ( East hall ) Stanley 's diary ( Room M4 ) Stanley 's diary ( S.T. room ) Stanley 's diary ( Storeroom ) Stanley 's diary ( Staircase ) Stanley 's diary ( Room S7 ) The Song of the Sparrow ( Hard Riddle Level ) The Song of the Owl ( Hard Riddle Level ) The Song of the Thrush ( Hard Riddle Level ) The Song of Cock Robin ( Hard Riddle Level ) The Song of the Lark ( Hard Riddle Level ) The Song of the Dove ( Hard Riddle Level ) The Song of the Linnet ( Hard Riddle Level ) The Song of the Rook ( Hard Riddle Level ) The Song of the Wren ( Hard Riddle Level ) The Song of the Kite ( Hard Riddle Level ) Crematory door ( Hard Riddle Level )
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~| | - Table of Contents ............ Tof C | | - Walkthrough .................. 1.00 | | - Controls ................ 0.00 | | - Room 302................ 1.01 | | - Subway World ............ 1.02 | | - Room 302................ 1.03 | | - Subway World ............ 1.04 | | - Room 302................ 1.05 | | - Forest World ............ 1.06 | | - Room 302................ 1.07 | | - Forest World ............ 1.08 | | - Room 302................ 1.09 | | - Water Prison World...... 1.10 | | - Room 302................ 1.11 | | - Water Prison World...... 1.12 | | - Room 302................ 1.13 | | - Building World .......... 1.14 | | - Room 302................ 1.15 | | - Apartment World......... 1.16 | | - Room 302................ 1.17 | | - Hospital World .......... 1.18 | | - Room 302................ 1.19 | | - Hospital World .......... 1.20 | | - Subway World 2.......... 1.21 | | - Room 302................ 1.22 | | - Subway World 2.......... 1.23 | | - Forest World 2.......... 1.24 | | - Water Prison World 2 .... 1.25 | | - Building World 2........ 1.26 | | - Room 302 of the Past.... 1.27 | | - Room 302................ 1.28 | | - Outside Room 302........ 1.29 | | - Ritual Area ............. 1.30 | | - Plot Summary ................. 2.00 | | - Item Checklists .............. 3.00 | | - End of the Game .............. 4.00 | | - Legal & Copyright ............ L.0C | | - Credits & Thanks ............. C.0T | |____________________________________________________________________________|
#
# -----
#
# ======================================================================= | | | # ###### ### | | / # ## # # ## | | / # # # ## ## # | | # # # # ## # # | | # # # ## # # | | # # ### ### ## /# # ### / # ## # ## # # ### | | # ## ### ### # # / # ## # ## / # ### / # ## # # ## # | | # ## ### # # # # / # ## # # # ## / # # | | # ## /# # ## # # # # # ## # # # # # # | | # / /# # ## # # ### # #### # # # # # # | | # / # # ## ## ### #### # # # # # # | | # / # # # # # # # # # # # # | | /# # / # # # # #### / # # # # # # | | / # # # # # # ## / ### / ### / # ## # ## / # ## ### # # | | / # # # # # ## / ## / # # # ## # ## ### # # | | | | | \)
#
# -----
#
# ------------------------- | | P L O T A N A L Y S I S | | ------------------------- | | | | # # ### ## # ## ### | | # ## # ## / #### / # ### # ## | | /# / / # # # # / # ## ## # # | | / / / # # # # # # # | | / / # # # # # | | # # ## # ### # # # # | | # # ## # ### # # # # | | # # #### #### # # # # # # | | # # ## # # # # # # # | | # # ## # # # # # # # # | | # # # ## # # # # # # | | / # # # # # # # # | | / # # / # # ## # # # # | | / # # # ## # # ### / ### / # ## / | | / # # # # / ## / # # / | | # | | ## | | | =======================================================================
# -----
#
# Characters ..........................................................( 01000 ) i - Characters ....................................................( 01001 ) 2 . Full Walkthrough ....................................................( 00000 ) i - Silent Hill ...................................................( 00001 ) ii - Wood Side Apartment ..........................................( 00002 ) iii - Blue Creek Apartment ........................................( 00003 ) iv - Silent Hill .................................................. ( 00004 ) v - Brookhaven Hospital ...........................................( 00005 ) vi - Alternate Hospital ...........................................( 00006 ) vii - Silent Hill .................................................( 00007 ) viii - Silent Hill Historical Society ............................. ( 00008 ) ix - Labyrinth .................................................... ( 00009 ) x - Lakeview Hotel ................................................ ( 0000 A ) xi - Alternate Hotel ..............................................( 0000 C ) 3 . Additional Info .....................................................( 10000 ) i - Weapons .......................................................( 10001 ) ii - Items ........................................................( 10002 ) iii - Enemies .....................................................( 10003 ) iv - Endings ......................................................( 10004 ) v - Item List .....................................................( 10005 ) 4 . Maps ................................................................( 00100 ) i - Silent Hill ...................................................( 00101 ) ii - Wood Side Apartment ..........................................( 00102 ) iii - Blue Creek Apartment ........................................( 00103 ) iv - Brookhaven Hospital .......................................... ( 00104 ) v - Toluca Prison .................................................( 00105 ) vi - Labyrinth ....................................................( 00106 ) vii - Lakeview Hotel ..............................................( 00107 ) 5 . Version History .....................................................( 0001 A ) 6 . Legal ...............................................................( 0001 B ) 7 . Credits .............................................................( 0001 C )
#
# -----
#
# o----------------------------------------------------------------------------o | _ | | WOOD SIDE APARTMENT 2F |_|_________ | | |_| | | | |_| I / | | |/ | | | || $ 209 | | | || | | | | | | | | ||_________| _________ | | | | | | | | | | | | | | | | || G | | \ | | || 208 | | 212 | | | || | | | | | || | | | | | ||_________| |_________ | | | || | | || | | || | | | | | | | | | | | | | | || 207 | | 211 | | | | | | | | | | | | | | | | | | | | ||_________| |_________|| | | || | | | | | | | | | | E || | | | | | | | | | | || 206 | | D 210 | | | | | | | | | | | | | | | | || | | ____________________________________||_________|_____________|_________|| | | |------------------------------------------------------------------------| | | | | |____|| | | | |_||| | | | | | |_ _ | | | | C |_|-| | | | | | | _| | | | | | |_| | | | | | 201 | 202 | _| | |_| 203 | 204 | 205 | _|_| | | | | | H |_|_| | | | | | | | | | | | | | | | | | | | |__________|__________|_____|
#
# -----
#
# o----------------------------------------------------------------------------o | _ | | WOOD SIDE APARTMENT 3F |_|_________ | | |_| | | | |_| / | | |/ | | | || 309 | | | || | | | || | | | ||_________| | | || | | | || | | | || | | | | | 308 | | | | | | | | | | | | | ||_________| | | | | | | | | | | | | | | | | | | | 307 | | | || | | | || J | | | ||_________| | | || | | | | | | | | | | | | | || 306 | | | || | | | || | | | ____________________________________||_________|________________________ | | |---------------------------------K--------------------------------------| | | | | |____|| | | | |_||| | | | | F | |_ _ | | N | | |_|-| | | | | | | _| | | | | | |_| | | | | | 301 | 302 | _| | |_| 303 | 304 | 305 | _|_| | | | | | |_|_| | | | | | | | | | | | | | L M | | | | | | |__________|__________|_____|
#
# -----
#
# _________ _________ | | | ||______ 1F | ||______ 2F | ||______ 3 F | | | || |||||| | || || |||| | || | | || | | | | | || | | ||| | || | | ||| | || | | || | | | | 108 ||______|__ | 208 ||______|__ | 308 ||______|__ | | | || | | || | | || | | | | || | | | | | | | | | | | | || 107 | | M $ | | 207 | | | | 307 | | | | || | | N || | | | | | | | |_________|| | |_________|| | |_________|| | | | | ||_________| | ||_________| | ||_________| | | | || | | | | | | | | | | | | | | | | | | | | | | | | | | 109 | | 106 | | 209 | | 206 | | 309 | | 306 | | | | || | | | | | | | | | | | | IJ | | | | | | | | | | | | | |_________||_________|
#
# -----
#
# |_________||_________| | | | || L | | G || | | | | | | | _|____|| | _|____|| | _|____|| | | | | ||||||| 105 | | |||||| | 205 | | |||||| | 305 | | | __|_||||||| | __|_|||| F| | | __|_|||||| | | | | | || K $ | | | | | | | | | | | | ||_________| | ||_________| | ||_________| | | | 101 || | | 201 || | | 301 || | | | | || | | || | | | | | | | | || 104 | | || 204 | | || 304 | | | |_________|| | |_________|| | |_________|| | | | | || | | | | | | | | | | | | ||_________| | ||_________| | ||_________| | | | || | | | | | | | | | | | | | | | | || A | | | | | | | | 102 | | 103 | | 202 | | 203 B | | 302 | | 303 | | | | || | | || E C | | | | | | | | | | | | || D | | | | | | | |_________||_________|
#
# -----
#
# -------------------------------------------------------------------o | | | LOCATIONS | | | | 1 - Shower Room 2 - Elevator | | 3 - Bath 4 - Rest Room | | 5 - Examining Room 2 6 - Pharmacy | | 7 - Store Room 8 - Visiting Room | | 9 - Reception Office 10 - Document Room | | 11 - Examination Room 12 - Doctor 's Lounge | | 13 - Examining Room 1 14 - Elevator | | 15 - Director 's Room 16 - Meeting Room | | 17 - Men's Washroom 18 - Women 's Washroom | | 19 - Cafeteria 20 - Kitchen | | 21 - Electrical Room 22 - Store Room | | 23 - Elevator 24 - Store Room | | 25 - Boiler Room 26 - Pump Room | | 27 - Elevator 28 - Shower Room | | 29 - Bath 3 30 - Examining Room 4 | | 31 - Rest Room 32 - Special Treatment Room | | 33 - Store Room 34 - Elevator | | 35 - Elevator Control Room 36 - Elevator | | 37 - Bath 2 38 - Examining Room 3 | | 39 - Rest Room 40 - Women 's Locker Room | | 41 - Nurse 's Station 42 - Men's Locker Room | | 43 - Linen Room 44 - Elevator | | | | ITEMS | | | | A - Map of Hospital B - Health Drink | | C -
#
# -----
#
# o----------------------------------------------------------------------------o | _________________________________ | | | | | | ___________________ | 1 F | | |____| | | | | | | | | | | | | || | | | | |____||_|_|_|_|_|_|_|_|_|_|| | | |____| | | | | | | K | | | | | | ||____________________________________ | | | | | ||_|_|_|_|_|_|_|_|_|_|| | | | |____| |____|E___________________ | | | | | RSTU | | N M || || | | | |____| |____||_______ || | | | | | |____|| _____| || | | | | O | | | | | | | | | | | | | | QP | |____|| |_|_| | _____|| | | | |__ | | $ || | | | | | | | | | | | |__|_| |____|| | | | F | |_ | | | | | | |____ | || |_|_|_| | | || L | | | | | |____|| | | | | |_ | | | | | | | | | | | | | | | | | J | | | | | | |_| || |_|_|_| |___|_ || | | | | |_| | | | | | | | | | | | | |_| || |_|_|_| || | | | _|____|_|____||_______| || | | | | || I | | | | | ||___________________|| | | | |_____________|D___________________ | | | | | | | | | | | G | | | | H | ||____________________________________| | | | $ ||_|_|_|_|_|_|_|_|_|_|| | | | C || | | | | | | | | | || | | | B A ||_|_|_|_|_|_|_|_|_|_|| | | |_____________|_____________________| | | | | B1 F | | ____________ | | | || | | | |_____||_____| | | | | | | | | |_____||_____| TOLUCA PRISON | | |__| | | |__| | o----------------------------------------------------------------------------o
#
# -----
#
# o----------------------------------------------------------------------------o | | | LABYRINTH | | _____ | | | | || | | |_ _| _______|| | | | $ | | ______ | | | |_____| || || _____ ______ | | ||_____________|| || | | | | | | | ______ _____ | | |__| |__ | | | | | | | | | __ | || | | | || ||_____||_______ | | | D |-- | | || |______|_______ | |_____| |______| | | || | | | | | | | | | | | | || | | || | |__ | | | | | | | | _|__ | | | ____||___|| | | | | | | | | _________| __||__ | | | | | | | | | | | | | | | | | | |____|| | | | | | | | ____| | | | | | | | | | ___ |______| || | | | |__ | _______________|| H | | | || || |_$______________|____| | | || | | | | | | ||______|| |_____| | | |_______ | | | ||___ | | | | _ _| | | || | | | | | ||______||| | | |_________| | | ___ ______________ | | | FG_| |_E____________| | | | o----------------------------------------------------------------------------o
#
# -----
# ______________________ | | | || | |28 | | |31 | | | | | 101 | | 102 | | | | | | | | | | || | |___| |_____|___|____| | | |__________||__________| | | |29 | ______| | | | || | | | | | | | | | | || | |___|___|_____| | | | | | 103 || 104 | _________________ |27 | |30 | | | | | | || | | | | !@ | | | | | | | |__________||__________| | $ = | | | |_____| |______| | | | | | | | | | | _____ |33 | | | | | | | | Lobby | | | |32 | _ | | | | | 105 | | 106 | | | | ___| | | | | | | || | | |___|_|26 | | | | | | |__________||__________| | ___ |23 | | | | |_ _____| | | | || | | |___| | |_|___| | | |34 | | | | || | | |___| |___|25 | |______| | | | | | 107 | | 108 | | |___| | 24 | | | |||| | |_____| | | | || |___| |___| | | | |------| |35 | | | |__________||_________|_||_| |___| | | YZ | |_||||_| | | | | | ||11 |12 |_||_| |___| |___|_____|
#
# -----
#
# 4 - Kitchen | | 5 - Electrical Room 6 - Elevator | | 7 - Elevator 8 - Store Room | | 9 - Pump Room 10 - Boiler Room | | 11 - Women 's Washroom 12 - Men's Washroom | | 13 - Store room 14 - Kitchen | | 15 - Kitchen 16 - Employee Cafeteria | | 17 - Dishroom 18 - Elevator | | 19 - Refrigerator Room 20 - Freezer Room | | 21 - Pantry 22 - Elevator | | 23 - Gift Shop 24 - Reception | | 25 - Office 26 - Telephone Operator 's Room | | 27 - Employee Lounge 28 - Manager 's Residence | | 29 - Men's Locker Room 30 - Women 's Locker Room | | 31 - Security Office 32 - Laundry Room | | 33 - Manager 's Office 34 - Women 's Washroom | | 35 - Men's Washroom 36 - Women 's Washroom | | 37 - Men's Washroom 38 - Lounge | | 39 - Reading Room 40 - Cloak Room | | 41 - Hall Anteroom 42 - Service Room | | 43 - Store Room 44 - Elevator | | 45 - Elevator 46 - Women 's Washroom | | 47 - Men's Washroom 48 - Observation Room | | 49 - Elevator 50 - Elevator | | | | ITEMS | | | | A - Hotel Map ( Guests ) B -

# %%
get_sentences_of_length(GAME_DIR, 1,4)
# Out:
# -----
#
# /|__|____/\___ >___|
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~|
#
# -----
#
# |____________________________________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ----------------------------------------------------
#
# -----
#
# 01.01
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# -------------------------------------------------
#
# -----
#
# 01.02
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ------------------------------------
#
# -----
#
# 01.03
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ---------------------------
#
# -----
#
# 01.04
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# More Demon
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# -------------------------------------
#
# -----
#
# 01.05
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# |+--------------------------------------------------------------------------+|
#
# -----
#
# || ||__________________________________________________________________________||
#
# -----
#
# +----------------------------------------------------------------------------+
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# -------------------------------------------------
#
# -----
#
# 01.06
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ----------------------------------
#
# -----
#
# 01.07
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# As
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# -----------------------------------
#
# -----
#
# 01.08
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# -------------------------------------------------
#
# -----
#
# 01.09
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# Lastly
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# --------------------------------
#
# -----
#
# 01.10
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# || ||__________________________________________________________________________||
#
# -----
#
# +----------------------------------------------------------------------------+
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# |+--------------------------------------------------------------------------+|
#
# -----
#
# || ||__________________________________________________________________________||
#
# -----
#
# +----------------------------------------------------------------------------+
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# -------------------------------------------------
#
# -----
#
# 01.11
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ------------------------------------------------------
#
# -----
#
# 01.12
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# -------------------------------------------------
#
# -----
#
# 01.13
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# -------------------------------------
#
# -----
#
# 01.14
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# Kaufmann
#
# -----
#
# Before Kaufman leaves
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# --------------------------------
#
# -----
#
# 01.15
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ----------------------------------------------
#
# -----
#
# 01.16
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ---------------------------------------
#
# -----
#
# 01.17
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# |+--------------------------------------------------------------------------+|
#
# -----
#
# ||
#
# -----
#
# || ||__________________________________________________________________________||
#
# -----
#
# +----------------------------------------------------------------------------+
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# 01.18
#
# -----
#
# --+ ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~_~~|
#
# -----
#
# | |_______________________|____________________________________________________|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# |+--------------------------------------------------------------------------+|
#
# -----
#
# ||
#
# -----
#
# || ||__________________________________________________________________________||
#
# -----
#
# +----------------------------------------------------------------------------+
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# +--
#
# -----
#
# LIZARD
#
# -----
#
# ---------------------------------------------------------
#
# -----
#
# 02.01 --+
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# |+--------------------------------------------------------------------------+|
#
# -----
#
# || ||__________________________________________________________________________||
#
# -----
#
# +----------------------------------------------------------------------------+
#
# -----
#
# +-- LARVA
#
# -----
#
# ----------------------------------------------------------
#
# -----
#
# 02.02 --+
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# || ||__________________________________________________________________________||
#
# -----
#
# +----------------------------------------------------------------------------+
#
# -----
#
# +--
#
# -----
#
# MOTH
#
# -----
#
# -----------------------------------------------------------
#
# -----
#
# 02.03 --+
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# |+--------------------------------------------------------------------------+|
#
# -----
#
# || ||__________________________________________________________________________||
#
# -----
#
# +----------------------------------------------------------------------------+
#
# -----
#
# +--
#
# -----
#
# CYBIL
#
# -----
#
# ----------------------------------------------------------
#
# -----
#
# 02.04 --+
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# |+--------------------------------------------------------------------------+|
#
# -----
#
# ||
#
# -----
#
# || ||__________________________________________________________________________||
#
# -----
#
# +----------------------------------------------------------------------------+
#
# -----
#
# +-- FINAL BOSS
#
# -----
#
# -----------------------------------------------------
#
# -----
#
# 02.05 --+
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# |+--------------------------------------------------------------------------+|
#
# -----
#
# ||
#
# -----
#
# || ||__________________________________________________________________________||
#
# -----
#
# +----------------------------------------------------------------------------+
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# |+------------------------++------------------------------------------------+|
#
# -----
#
# ||------------------------||------------------------------------------------||
#
# -----
#
# || Bad+ Ending
#
# -----
#
# ||------------------------||------------------------------------------------||
#
# -----
#
# ||------------------------||------------------------------------------------||
#
# -----
#
# ||________________________||________________________________________________||
#
# -----
#
# +----------------------------------------------------------------------------+
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# |+------------------------++-----------------------------------------++-----+|
#
# -----
#
# || AMPOULE ||
#
# -----
#
# Antique Shop -
#
# -----
#
# Nowhere -
#
# -----
#
# Alt. School -
#
# -----
#
# Nowhere -
#
# -----
#
# The Sewers -
#
# -----
#
# +----------------------------------------------------------------------------+
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+
#
# -----
#
# )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+
#
# -----
#
# )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# K .
#
# -----
#
# ( ========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# ( | o|
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+
#
# -----
#
# )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# SCREWDRIVER |o|
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# SILVER MEDALLION
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+ )
#
# -----
#
# (========================)-(=================================================+
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~\/~~~~~~~\/~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\/~~~~~~~\/~~
#
# -----
#
# __||_______||____________________________________________________||_______||__
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~\/~~~~~~~\/~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\/~~~~~~~\/~~
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ______________________________________________________________________________
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# -----
#
# '
#
# -----
#
# '
#
# -----
#
# +====================================================+
#
# -----
#
# Version 3.0
#
# -----
#
# 10/07/08
#
# -----
#
# +====================================================+
#
# -----
#
# Again !
#
# -----
#
# +=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# -----
#
# TABLE OF CONTENTS
#
# -----
#
# +=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+
#
# -----
#
# 1 . )
#
# -----
#
# 2 . )
#
# -----
#
# 4 . )
#
# -----
#
# Weaponry
#
# -----
#
# 5 . )
#
# -----
#
# 6 . )
#
# -----
#
# Conclusion
#
# -----
#
# 7 . )
#
# -----
#
# Contact
#
# -----
#
# 8 . )
#
# -----
#
# Version History
#
# -----
#
# 9 . )
#
# -----
#
# Afterword
#
# -----
#
# Press Ctrl +
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# '
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ===
#
# -----
#
# Whereas Pyramid
#
# -----
#
# ===
#
# -----
#
# ===
#
# -----
#
# Does
#
# -----
#
# ===
#
# -----
#
# by Wandering
#
# -----
#
# One
#
# -----
#
# note :
#
# -----
#
# Why ?
#
# -----
#
# THE BUTCHER !
#
# -----
#
# Travis ' dark
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ===
#
# -----
#
# ===
#
# -----
#
# ===
#
# -----
#
# ===
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# 5 . )
#
# -----
#
# BESTIARY ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ===
#
# -----
#
# ===
#
# -----
#
# ===
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# OVERALL
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# Childof
#
# -----
#
# Wandering
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# ++++++++++++++++
#
# -----
#
# And you !
#
# -----
#
# Thanks .
#
# -----
#
# One
#
# -----
#
# So nyeh .
#
# -----
#
# \_\_|
#
# -----
#
# |_|\__,_|_|\__,
#
# -----
#
# |___/_|___/ |___/
#
# -----
#
# Memos list .
#
# -----
#
# 1.1 6/17/2007 :
#
# -----
#
# www.supercheats.com
#
# -----
#
# www.neoseeker.com
#
# -----
#
# Hi there ,
#
# -----
#
# Memos list .
#
# -----
#
# But it seems
#
# -----
#
# - " ...
#
# -----
#
# " Lucky !
#
# -----
#
# Hell ,
#
# -----
#
# Since
#
# -----
#
# " Rachael ...
#
# -----
#
# Aaaaaaaahhhh !!!!!
#
# -----
#
# Jasper "
#
# -----
#
# Pretty simple .
#
# -----
#
# Henry .
#
# -----
#
# Duh .
#
# -----
#
# GREAT idea .
#
# -----
#
# Ewww .
#
# -----
#
# Try it .
#
# -----
#
# Sunderland "
#
# -----
#
# Besides ,
#
# -----
#
# '
#
# -----
#
# Besides ,
#
# -----
#
# Poor baby .
#
# -----
#
# Since
#
# -----
#
# Look !
#
# -----
#
# Hmm ...
#
# -----
#
# Gee thanks ,
#
# -----
#
# Thanks ,
#
# -----
#
# Joseph !
#
# -----
#
# ----------------------------------------
#
# -----
#
# Lucky them !
#
# -----
#
# This room ...
#
# -----
#
# Creepy ...
#
# -----
#
# Duh .
#
# -----
#
# Double duh .
#
# -----
#
# Ten heart ...
#
# -----
#
# No. 2 ...
#
# -----
#
# Ten hearts ...
#
# -----
#
# No. 4 ...
#
# -----
#
# Ten hearts ...
#
# -----
#
# No. 1 ...
#
# -----
#
# The pain ...
#
# -----
#
# Joseph Schreiber "
#
# -----
#
# '
#
# -----
#
# Joseph Schreiber "
#
# -----
#
# Copyright 2007
#
# -----
#
# o+--=====================================================================--+o
#
# -----
#
# FAQ
#
# -----
#
# Version : 1.2
#
# -----
#
# o+--=====================================================================--+o
#
# -----
#
# o+--=====================================================================--+o
#
# -----
#
# [ I.1 ]
#
# -----
#
# [ V.1 ]
#
# -----
#
# [ V.3 ]
#
# -----
#
# o+--=====================================================================--+o
#
# -----
#
# + Introduction +
#
# -----
#
# o+--===============================-----------===========================--+o
#
# -----
#
# o+--=====================================================================--+o +
#
# -----
#
# Basics +
#
# -----
#
# o+--===============================-----------===========================--+o
#
# -----
#
# Toggle flashlight ;
#
# -----
#
# o+--=====================================================================--+o
#
# -----
#
# + Walkthrough +
#
# -----
#
# o+-
#
# -----
#
# Question Primary Influence
#
# -----
#
# 1 .
#
# -----
#
# 2 .
#
# -----
#
# 4 .
#
# -----
#
# 5 .
#
# -----
#
# 6 .
#
# -----
#
# 7 .
#
# -----
#
# +--------------+---------+
#
# -----
#
# +--------------+---------+
#
# -----
#
# --- III.1 Junkyard
#
# -----
#
# ***
#
# -----
#
# --- III.1 Streets
#
# -----
#
# +-- BRANCH --+
#
# -----
#
# 1 .
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# --- III.1 Playground
#
# -----
#
# Sports Bar -
#
# -----
#
# Entrance Criteria :
#
# -----
#
# PI Variations :
#
# -----
#
# ***
#
# -----
#
# --- III.1 Streets
#
# -----
#
# ***
#
# -----
#
# ** UFO **
#
# -----
#
# +--------------------------+---------+
#
# -----
#
# +--------------------------+---------+
#
# -----
#
# o+-
#
# -----
#
# Question Primary Influence
#
# -----
#
# 1 .
#
# -----
#
# 2 .
#
# -----
#
# 3 .
#
# -----
#
# Coloring Time !
#
# -----
#
# ***
#
# -----
#
# +--------+---------+
#
# -----
#
# --- III.3 Cabin
#
# -----
#
# ***
#
# -----
#
# ** UFO **
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# ** UFO **
#
# -----
#
# Pz.
#
# -----
#
# ***
#
# -----
#
# Climb it .
#
# -----
#
# ***
#
# -----
#
# o+-
#
# -----
#
# -+o
#
# -----
#
# Title Influence
#
# -----
#
# Greaser outfit ;
#
# -----
#
# Class Influence
#
# -----
#
# +---------------------+---------+
#
# -----
#
# ** UFO **
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# --- III.5 Cathouse
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# --- III.5 Wonderland
#
# -----
#
# ** UFO **
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# --- III.5 Courtyard
#
# -----
#
# ** UFO **
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# +-- BRANCH --+
#
# -----
#
# 1 .
#
# -----
#
# Art Studio
#
# -----
#
# 2 . Planetarium
#
# -----
#
# -+o
#
# -----
#
# PI Variations :
#
# -----
#
# - Family PI
#
# -----
#
# -+o
#
# -----
#
# Quick Solution :
#
# -----
#
# ***
#
# -----
#
# ** UFO **
#
# -----
#
# ***
#
# -----
#
# PI Variations :
#
# -----
#
# --- III.5 Paparazzi
#
# -----
#
# Game
#
# -----
#
# ***
#
# -----
#
# Indicator Variations :
#
# -----
#
# --- III.5 Drowning
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# +---------------------+---------+--------+
#
# -----
#
# +---------------------+---------+--------+
#
# -----
#
# -+o
#
# -----
#
# +-------------+---------+
#
# -----
#
# +-------------+---------+
#
# -----
#
# Follow Lisa .
#
# -----
#
# ***
#
# -----
#
# o+-
#
# -----
#
# -+o
#
# -----
#
# - Bull -
#
# -----
#
# - King -
#
# -----
#
# - Wilhelm -
#
# -----
#
# +-- BRANCH --+
#
# -----
#
# 1 .
#
# -----
#
# Warehouse
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# 2 .
#
# -----
#
# Mall Entrance
#
# -----
#
# ***
#
# -----
#
# ** UFO **
#
# -----
#
# +------------------+---------+
#
# -----
#
# -+o
#
# -----
#
# Quick Solution :
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# ** UFO **
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# +-- BRANCH --+
#
# -----
#
# 1 .
#
# -----
#
# New Looks
#
# -----
#
# Hair Salon
#
# -----
#
# -+o
#
# -----
#
# Quick Solution :
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# CONTRA .
#
# -----
#
# Blasphemy !!
#
# -----
#
# ***
#
# -----
#
# Glitch ?
#
# -----
#
# Whatever .
#
# -----
#
# ***
#
# -----
#
# PI Variations :
#
# -----
#
# ** UFO **
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# o+-
#
# -----
#
# ***
#
# -----
#
# 1 .
#
# -----
#
# 2 .
#
# -----
#
# 3 .
#
# -----
#
# 4 .
#
# -----
#
# Basically ,
#
# -----
#
# +----------------------+----------+
#
# -----
#
# ***
#
# -----
#
# Kinda gross ...
#
# -----
#
# ***
#
# -----
#
# Photograph it .
#
# -----
#
# ** UFO **
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# o+-
#
# -----
#
# -+o
#
# -----
#
# +-------------------------+----------+
#
# -----
#
# ***
#
# -----
#
# ***
#
# -----
#
# Play it .
#
# -----
#
# ***
#
# -----
#
# --- III.12 Docks
#
# -----
#
# ** UFO **
#
# -----
#
# Trust me :)
#
# -----
#
# Keep running .
#
# -----
#
# Start swimming !
#
# -----
#
# ** UFO **
#
# -----
#
# .
#
# -----
#
# ***
#
# -----
#
# o+--=====================================================================--+o
#
# -----
#
# +
#
# -----
#
# Therapy Sessions +
#
# -----
#
# +----------+--------+
#
# -----
#
# Question Primary Influence
#
# -----
#
# 1 .
#
# -----
#
# 2 .
#
# -----
#
# 4 .
#
# -----
#
# 5 .
#
# -----
#
# 6 .
#
# -----
#
# 7 .
#
# -----
#
# Question Primary Influence
#
# -----
#
# 1 .
#
# -----
#
# 2 .
#
# -----
#
# 3 .
#
# -----
#
# Coloring Time !
#
# -----
#
# +-----------------------------+--------+
#
# -----
#
# +-----------------------------+--------+
#
# -----
#
# Title Influence
#
# -----
#
# Greaser outfit ;
#
# -----
#
# Class Influence
#
# -----
#
# +---------------------+--------+
#
# -----
#
# +---------------------+--------+
#
# -----
#
# +-------------------+--------+
#
# -----
#
# +-------------------+--------+
#
# -----
#
# - Bull -
#
# -----
#
# - King -
#
# -----
#
# - Wilhelm -
#
# -----
#
# +----------+--------+
#
# -----
#
# Basically ,
#
# -----
#
# +----------------+--------+
#
# -----
#
# o+--=====================================================================--+o
#
# -----
#
# + Endings +
#
# -----
#
# o+--===============================-----------===========================--+o
#
# -----
#
# ***
#
# -----
#
# +------------------+-------+
#
# -----
#
# o+- Broken -+o
#
# -----
#
# Major PI :
#
# -----
#
# Description :
#
# -----
#
# o+-
#
# -----
#
# Major PI :
#
# -----
#
# Description :
#
# -----
#
# o+-
#
# -----
#
# Hero Forever
#
# -----
#
# -+o
#
# -----
#
# Major PI :
#
# -----
#
# Description :
#
# -----
#
# Cheryl whispers .
#
# -----
#
# Major PI :
#
# -----
#
# Description :
#
# -----
#
# Major PI :
#
# -----
#
# Description :
#
# -----
#
# Harry summons .
#
# -----
#
# He complies .
#
# -----
#
# Major PI :
#
# -----
#
# Description :
#
# -----
#
# Again ...
#
# -----
#
# o+-
#
# -----
#
# Drunk Dad -+o
#
# -----
#
# Major PI :
#
# -----
#
# Description :
#
# -----
#
# " Now !
#
# -----
#
# He demands .
#
# -----
#
# +------------+-------+
#
# -----
#
# Big .
#
# -----
#
# Pet -
#
# -----
#
# Shop -
#
# -----
#
# 12 - III.12
#
# -----
#
# Docks -
#
# -----
#
# o+--=====================================================================--+o
#
# -----
#
# + Puzzles +
#
# -----
#
# +-----------+--------+
#
# -----
#
# +---------+--------+
#
# -----
#
# +---------+--------+
#
# -----
#
# +-------------+--------+
#
# -----
#
# +-------------+--------+
#
# -----
#
# +-------------+--------+
#
# -----
#
# Quick Solution :
#
# -----
#
# +-------------+--------+
#
# -----
#
# +----------------+--------+
#
# -----
#
# +----------------+--------+
#
# -----
#
# +---------------+--------+
#
# -----
#
# +-----------------+--------+
#
# -----
#
# +-----------------+--------+
#
# -----
#
# Quick Solution :
#
# -----
#
# +------------------+--------+
#
# -----
#
# +------------------+--------+
#
# -----
#
# Quick Solution :
#
# -----
#
# o+--=====================================================================--+o
#
# -----
#
# Hidden Fire
#
# -----
#
# Frozen Waters
#
# -----
#
# A Broken Ward
#
# -----
#
# Pinned Beauty
#
# -----
#
# Suffocated Forever
#
# -----
#
# Heavenly Protection
#
# -----
#
# A Frigid Jewel
#
# -----
#
# An Eternal Rose
#
# -----
#
# Infinite Jest
#
# -----
#
# Memories Undeveloped
#
# -----
#
# My Flyind lizard
#
# -----
#
# - From III.11
#
# -----
#
# A Happy Bond
#
# -----
#
# Memories Untaken
#
# -----
#
# - From III.11
#
# -----
#
# Your Diamond Heart
#
# -----
#
# - From III.11
#
# -----
#
# The Dragon
#
# -----
#
# - From III.12
#
# -----
#
# o+--=====================================================================--+o +
#
# -----
#
# Ghosts +
#
# -----
#
# Drowning Boy
#
# -----
#
# Hanging Deer
#
# -----
#
# Hot and Bothered
#
# -----
#
# Dead Dog
#
# -----
#
# Mall -
#
# -----
#
# Dragon Slayer
#
# -----
#
# - From III.12
#
# -----
#
# Park Entrance -
#
# -----
#
# o+--=====================================================================--+o
#
# -----
#
# o+--=====================================================================--+o
#
# -----
#
# +
#
# -----
#
# Phone Numbers +
#
# -----
#
# Bodkin Insurance 555-3800
#
# -----
#
# Brodie Insurance 555-3900
#
# -----
#
# Brookhaven Hospital 555-9300
#
# -----
#
# Dahlia
#
# -----
#
# Join Tookie 555-8665
#
# -----
#
# Nightingale Apts. 555-4139
#
# -----
#
# Police Department 555-6358
#
# -----
#
# Riverside Motel 555-4340
#
# -----
#
# School Magazine 555-7857
#
# -----
#
# Southside Salvage 555-2212
#
# -----
#
# o+--=====================================================================--+o
#
# -----
#
# +
#
# -----
#
# Legal +
#
# -----
#
# - Gamefaqs.com
#
# -----
#
# - Neoseeker.com
#
# -----
#
# Konami Digital Entertainment
# -----
#
# -------------------------------------------------------------------------------
#
# -----
#
# -------------------------------------------------------------------------------
#
# -----
#
# ----------------------
#
# -----
#
# 01/26/09
#
# -----
#
# ------------------------
#
# -----
#
# -------------------------------------------------------------------------------
#
# -----
#
# -------------------------------------------------------------------------------
#
# -----
#
# -
#
# -----
#
# --------
#
# -----
#
# -------------------------------------------------------------------------------
#
# -----
#
# TABLE OF CONTENTS
#
# -----
#
# -------------------------------------------------------------------------------
#
# -----
#
# Section
#
# -----
#
# _______________________________________________________________________________ ///////////////////////////////////////////////////////////////////////////////
#
# -----
#
# I ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# ===============================================================================
#
# -----
#
# - Berserker
#
# -----
#
# ===============================================================================
#
# -----
#
# After all ...
#
# -----
#
# -- Extra Info
#
# -----
#
# +
#
# -----
#
# http://berserkersblog.blogspot.com/2008/10/silent-hill-homecoming-guide.html
#
# -----
#
# +
#
# -----
#
# +
#
# -----
#
# http://www.gamefaqs.com/console/ps3/file/942059/54329
#
# -----
#
# _______________________________________________________________________________ ///////////////////////////////////////////////////////////////////////////////
#
# -----
#
# II
#
# -----
#
# ===============================================================================
#
# -----
#
# ********
#
# -----
#
# CONTROLS ********
#
# -----
#
# -- Xbox 360
#
# -----
#
# ******
#
# -----
#
# SAVING ******
#
# -----
#
# *******
#
# -----
#
# JOURNAL *******
#
# -----
#
# ***
#
# -----
#
# MAP ***
#
# -----
#
# **********
#
# -----
#
# OBJECTIVES **********
#
# -----
#
# ************
#
# -----
#
# WEAPON WHEEL ************
#
# -----
#
# ***************
#
# -----
#
# INVENTORY WHEEL ***************
#
# -----
#
# ********************
#
# -----
#
# ******
#
# -----
#
# HEALTH ******
#
# -----
#
# *************************
#
# -----
#
# ENVIRONMENTAL INTERACTION *************************
#
# -----
#
# *************
#
# -----
#
# OPENING DOORS *************
#
# -----
#
# ***************
#
# -----
#
# ********************
#
# -----
#
# *************
#
# -----
#
# DIALOGUE MENU *************
#
# -----
#
# ******
#
# -----
#
# COMBAT ******
#
# -----
#
# =====================
#
# -----
#
# =====================
#
# -----
#
# =======
#
# -----
#
# Weapons
#
# -----
#
# =======
#
# -----
#
# ============
#
# -----
#
# Fast Attacks
#
# -----
#
# ============
#
# -----
#
# ==============
#
# -----
#
# Strong Attacks
#
# -----
#
# ==============
#
# -----
#
# ===========
#
# -----
#
# Combination
#
# -----
#
# ===========
#
# -----
#
# =======
#
# -----
#
# Gunplay
#
# -----
#
# =======
#
# -----
#
# =======
#
# -----
#
# Dodging
#
# -----
#
# =======
#
# -----
#
# ===============
#
# -----
#
# Evasive Rolling
#
# -----
#
# ===============
#
# -----
#
# ============================
#
# -----
#
# ============================
#
# -----
#
# ========= Grappling
#
# -----
#
# =========
#
# -----
#
# =========
#
# -----
#
# Finishers
#
# -----
#
# =========
#
# -----
#
# ==================
#
# -----
#
# Melee Combat Moves
#
# -----
#
# ==================
#
# -----
#
# ------------------------------
#
# -----
#
# ------------------------------
#
# -----
#
# -->
#
# -----
#
# Normal Attacks
#
# -----
#
# -->
#
# -----
#
# Combination Attacks
#
# -----
#
# -->
#
# -----
#
# Counter Attacks
#
# -----
#
# ------------------
#
# -----
#
# ------------------
#
# -----
#
# -->
#
# -----
#
# Normal Attacks
#
# -----
#
# -->
#
# -----
#
# Combination attacks
#
# -----
#
# -->
#
# -----
#
# Counter Attacks
#
# -----
#
# --------------------
#
# -----
#
# --------------------
#
# -----
#
# -->
#
# -----
#
# Normal Attacks
#
# -----
#
# -->
#
# -----
#
# Combination Attacks
#
# -----
#
# -->
#
# -----
#
# Counter Attacks
#
# -----
#
# ----------------------------
#
# -----
#
# ----------------------------
#
# -----
#
# -->
#
# -----
#
# Normal Attacks
#
# -----
#
# -->
#
# -----
#
# Combination Attacks
#
# -----
#
# -->
#
# -----
#
# Counter Attacks
#
# -----
#
# -------------------------------------
#
# -----
#
# -------------------------------------
#
# -----
#
# -->
#
# -----
#
# Melee Attack
#
# -----
#
# -->
#
# -----
#
# Capacity and Pickups
#
# -----
#
# -----------------------------------------------------------------------------
#
# -----
#
# ---------------------------
#
# -----
#
# ---------------------------
#
# -----
#
# -->
#
# -----
#
# Melee Attack
#
# -----
#
# -->
#
# -----
#
# Capacity and Pickups
#
# -----
#
# 12 Gauge Shotgun
#
# -----
#
# Bluesteel Shotgun
#
# -----
#
# ---------------------------------------------------------------------------
#
# -----
#
# ---------------------------------------
#
# -----
#
# ---------------------------------------
#
# -----
#
# -->
#
# -----
#
# Melee Attack
#
# -----
#
# -->
#
# -----
#
# Capacity and Pickups
#
# -----
#
# --------------------------------------------------------------------------
#
# -----
#
# ----------------------------
#
# -----
#
# ----------------------------
#
# -----
#
# -->
#
# -----
#
# Melee Attack
#
# -----
#
# -->
#
# -----
#
# Capacity and Pickups
#
# -----
#
# Laser Pistol
#
# -----
#
# --------------------------------------
#
# -----
#
# _______________________________________________________________________________ ///////////////////////////////////////////////////////////////////////////////
#
# -----
#
# III
#
# -----
#
# ===============================================================================
#
# -----
#
# Objective :
#
# -----
#
# ==
#
# -----
#
# Operating Room ==
#
# -----
#
# Bingo !
#
# -----
#
# ++
#
# -----
#
# ** 624872 **
#
# -----
#
# Objective Update :
#
# -----
#
# == Storage ==
#
# -----
#
# Examine the !!
#
# -----
#
# SAVE POINT !!
#
# -----
#
# How amusing .
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# ->
#
# -----
#
# Yawn .
#
# -----
#
# A !!
#
# -----
#
# SAVE POINT !!
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# ->
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# ->
#
# -----
#
# thank god .
#
# -----
#
# Choice Set 1
#
# -----
#
# -->
#
# -----
#
# Choice Set 2
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# SAVE POINT !!
#
# -----
#
# Reach inside .
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# ________________________________
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# ->
#
# -----
#
# Choice Set 1
#
# -----
#
# -->
#
# -----
#
# Choice Set 2A
#
# -----
#
# -->
#
# -----
#
# Choice Set 2B
#
# -----
#
# -->
#
# -----
#
# Choice Set 3A
#
# -----
#
# -->
#
# -----
#
# Choice Set 3B
#
# -----
#
# SAVE POINT !!
#
# -----
#
# ________________________
#
# -----
#
# _____________________________
#
# -----
#
# Objective Update
#
# -----
#
# [ ]
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# ->
#
# -----
#
# ++
#
# -----
#
# BOOKCASE PUZZLE ++
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# ->
#
# -----
#
# Objective Update :
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# ->
#
# -----
#
# Found Circular
#
# -----
#
# Saw -----
#
# -----
#
# __________________________________
#
# -----
#
# == Backyard ==
#
# -----
#
# Oh dear .
#
# -----
#
# == Kitchen ==
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# [ ]
#
# -----
#
# ==
#
# -----
#
# East Garden ==
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# ->
#
# -----
#
# SAVE POINT !!
#
# -----
#
# ==
#
# -----
#
# ==
#
# -----
#
# West Garden ==
#
# -----
#
# Aha !
#
# -----
#
# ________________________
#
# -----
#
# _________________________________
#
# -----
#
# Choice Set
#
# -----
#
# Choice Set 1
#
# -----
#
# -->
#
# -----
#
# Choice Set 2
#
# -----
#
# Y -
#
# -----
#
# {to 3 ]
#
# -----
#
# -->
#
# -----
#
# Choice Set 3
#
# -----
#
# Objective Update :
#
# -----
#
# SAVE POINT !!
#
# -----
#
# ________________________
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# ->
#
# -----
#
# Take Main
#
# -----
#
# ___________________________
#
# -----
#
# ==
#
# -----
#
# West Garden ==
#
# -----
#
# ==
#
# -----
#
# ==
#
# -----
#
# East Garden ==
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# ++
#
# -----
#
# +----|__|-------+
#
# -----
#
# +---------------+
#
# -----
#
# __________________________
#
# -----
#
# _________________________
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# A
#
# -----
#
# A
#
# -----
#
# __________________________
#
# -----
#
# _________________________
#
# -----
#
# ++
#
# -----
#
# G = Green
#
# -----
#
# Objective Update :
#
# -----
#
# ________________________________
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# ->
#
# -----
#
# ==
#
# -----
#
# Period .
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# SAVE POINT !!
#
# -----
#
# Choice Set 1
#
# -----
#
# -->
#
# -----
#
# Choice Set 2
#
# -----
#
# -->
#
# -----
#
# Choice Set 3
#
# -----
#
# -->
#
# -----
#
# Choice Set 4
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# Creepy .
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# ==
#
# -----
#
# Dining Room ==
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# SAVE POINT !!
#
# -----
#
# Backtrack to ...
#
# -----
#
# == Greenhouse ==
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# Choice Set 1
#
# -----
#
# Y -
#
# -----
#
# -->
#
# -----
#
# Choice Set 2A
#
# -----
#
# -->
#
# -----
#
# Choice Set 2B
#
# -----
#
# Y -
#
# -----
#
# -->
#
# -----
#
# Choice Set 3A
#
# -----
#
# -->
#
# -----
#
# Choice Set 3B
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# Debris Rain -
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# Defeated Sepulcher .
#
# -----
#
# == Cell ==
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# Choice Set 1
#
# -----
#
# -->
#
# -----
#
# Choice Set 2
#
# -----
#
# -->
#
# -----
#
# Choice Set 3
#
# -----
#
# -->
#
# -----
#
# Choice Set 4
#
# -----
#
# Objective Update :
#
# -----
#
# == Hallway ==
#
# -----
#
# Follow Wheeler .
#
# -----
#
# == Storage ==
#
# -----
#
# SAVE POINT !!
#
# -----
#
# ==
#
# -----
#
# Main Hall ==
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# Objective Update :
#
# -----
#
# [ ]
#
# -----
#
# == Lobby ==
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# -----
#
# -----
#
# == Garage ==
#
# -----
#
# ++
#
# -----
#
# LOCKER PUZZLE ++
#
# -----
#
# Voila !
#
# -----
#
# Objective Update :
#
# -----
#
# My god .
#
# -----
#
# -----
#
# -----
#
# Achievement unlocked :
#
# -----
#
# ->
#
# -----
#
# _________________________
#
# -----
#
# ...
#
# -----
#
# Wow .
#
# -----
#
# Unlike
#
# -----
#
# II - g.
#
# -----
#
# III .
#
# -----
#
# Endings
#
# -----
#
# IV .
#
# -----
#
# EASY
#
# -----
#
# Two down .
#
# -----
#
# EASY
#
# -----
#
# NORMAL
#
# -----
#
# HARD
#
# -----
#
# Like jelly ?
#
# -----
#
# Wow .
#
# -----
#
# Nifty .
#
# -----
#
# Logical ?
#
# -----
#
# Good .
#
# -----
#
# Like jelly ?
#
# -----
#
# 4 .
#
# -----
#
# 6 .
#
# -----
#
# EASY
#
# -----
#
# HARD
#
# -----
#
# EASY
#
# -----
#
# No tricks .
#
# -----
#
# HARD
#
# -----
#
# IV -e.
#
# -----
#
# Tarot Card Puzzle
#
# -----
#
# EASY
#
# -----
#
# IOI XXII XVII
#
# -----
#
# OXXO O XVIII
#
# -----
#
# XII CXXII CCXI
#
# -----
#
# II XXII XVII
#
# -----
#
# XX O XVIII
#
# -----
#
# XII CXXII CCXI
#
# -----
#
# V - b.
#
# -----
#
# BULLET ADJUST :
#
# -----
#
# Yeehaw !
#
# -----
#
# V -d.
#
# -----
#
# BONUS WEAPONS :
#
# -----
#
# V -e.
#
# -----
#
# V -f.
#
# -----
#
# V -g.
#
# -----
#
# The answer ?
#
# -----
#
# One .
#
# -----
#
# Nope .
#
# -----
#
# Pretty cool .
#
# -----
#
# Get it ?
#
# -----
#
# Hilarious ) .
#
# -----
#
# V -h.
#
# -----
#
# Disturbing .
#
# -----
#
# V - i.
#
# -----
#
# EASTEREGGS :
#
# -----
#
# Why ?
#
# -----
#
# - Ahem .
#
# -----
#
# Stinking traitor .
#
# -----
#
# Heh .
#
# -----
#
# LIFE DISPLAY :
#
# -----
#
# They are also
#
# -----
#
# Kudos Marc .
#
# -----
#
# Pure brilliance .
#
# -----
#
# v-i- 10 .
#
# -----
#
# Good stuff .
#
# -----
#
# - Ending :
#
# -----
#
# Sorry .
#
# -----
#
# VI .
#
# -----
#
# VII .
#
# -----
#
# ADARKERVISION.COM .
#
# -----
#
# Be well .
#
# -----
#
# |___|__/ |____|
#
# -----
#
# ____________________________________________________________________________
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~|
#
# -----
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# -----
#
# O============================================================================O
#
# -----
#
# O============================================================================O
#
# -----
#
# **
#
# -----
#
# 1 .
#
# -----
#
# O============================================================================O
#
# -----
#
# O============================================================================O
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o------------------o
#
# -----
#
# o-------------------------o
#
# -----
#
# o---------------o
#
# -----
#
# o---------------o
#
# -----
#
# o------------------o
#
# -----
#
# o-------o
#
# -----
#
# o-------o
#
# -----
#
# O============================================================================O
#
# -----
#
# O============================================================================O
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o-------
#
# -----
#
# Item Checklist -------o
#
# -----
#
# Continue North
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o-------
#
# -----
#
# Item Checklist -------o
#
# -----
#
# Now run
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o-------
#
# -----
#
# Item Checklist -------o
#
# -----
#
# o------------------------------o numerals .
#
# -----
#
# _________________________|_________________________|__________________________
#
# -----
#
# Very simple .
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o-------
#
# -----
#
# Item Checklist -------o
#
# -----
#
# Keep going
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o-------
#
# -----
#
# Item Checklist
#
# -----
#
# -------o
#
# -----
#
# '
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o-------
#
# -----
#
# Item Checklist
#
# -----
#
# -------o
#
# -----
#
# o------------------------------o
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o-------
#
# -----
#
# Item Checklist -------o
#
# -----
#
# '
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o-------
#
# -----
#
# Item Checklist
#
# -----
#
# -------o
#
# -----
#
# Now
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o-------
#
# -----
#
# Item Checklist -------o
#
# -----
#
# Head |
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o-------
#
# -----
#
# Item Checklist -------o
#
# -----
#
# o------------------------------o
#
# -----
#
# '
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o-------
#
# -----
#
# Item Checklist -------o
#
# -----
#
# Reading Room .
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o-------
#
# -----
#
# Item Checklist -------o
#
# -----
#
# Good job !
#
# -----
#
# O============================================================================O
#
# -----
#
# O============================================================================O
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o--------------o
#
# -----
#
# o---------o
#
# -----
#
# o------------o
#
# -----
#
# o---------o
#
# -----
#
# o-------------o
#
# -----
#
# o---------------o
#
# -----
#
# o----------o
#
# -----
#
# o-------------o
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o--------------o
#
# -----
#
# o-----------o
#
# -----
#
# o---------o
#
# -----
#
# o-----------------o
#
# -----
#
# o-----------------o
#
# -----
#
# o--------------o
#
# -----
#
# Rifle
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o----------o
#
# -----
#
# o-------------o
#
# -----
#
# o------------o
#
# -----
#
# o--------o
#
# -----
#
# o---------o
#
# -----
#
# o---------o
#
# -----
#
# /-------------------------------------------------------------o / ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o----------o
#
# -----
#
# o-------o
#
# -----
#
# o-------o
#
# -----
#
# o---------o
#
# -----
#
# o-----o
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# O============================================================================O
#
# -----
#
# O==============================+=============================================O
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# 107 | |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# Kit |
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------| | Lapis
#
# -----
#
# Eye Key |
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# Egg |
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# |------------------------------+---------------------------------------------|
#
# -----
#
# o----------------------------------------------------------------------------o
#
# -----
#
# O============================================================================O
#
# -----
#
# O============================================================================O
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# _/|
#
# -----
#
# |_______||________________________________________________
#
# -----
#
# o----------------------------------------------------------------------------o
#
# -----
#
# o- Legend
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# ---------
#
# -----
#
# |____________________________________|_____| | o----------------------------------------------------------------------------o
#
# -----
#
# |___________|____________|___________|_____| | o----------------------------------------------------------------------------o
#
# -----
#
# |___________|____________|___________|_____| | o----------------------------------------------------------------------------o
#
# -----
#
# o- Legend
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# |_________||_________|
#
# -----
#
# |_________||_________|
#
# -----
#
# o- Legend
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# _________________
#
# -----
#
# ______|______________|KK
#
# -----
#
# ______|______|
#
# -----
#
# o- Legend
#
# -----
#
# Kit J -
#
# -----
#
# -
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o- Legend
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# o- Legend
#
# -----
#
# Kit J -
#
# -----
#
# /-------------------------------------------------------------o /
#
# -----
#
# ------o------\
#
# -----
#
# \------------------------------------------------------------o
#
# -----
#
# |__|__|
#
# -----
#
# ___
#
# -----
#
# o- Legend
#
# -----
#
# Kit H -
#
# -----
#
# O============================================================================O
#
# -----
#
# O============================================================================O
#
# -----
#
# O============================================================================O
#
# -----
#
# O============================================================================O
#
# -----
#
# O============================================================================O
#
# -----
#
# O============================================================================O
#
# -----
#
# O============================================================================O

# %% [markdown]
# Most of the sentences that are high in token count but singly-counted seem to be caused by the scraping methods of the data. In this case, we can consider these as outliers and reprocess our data.

# %%
def has_three_words(tokens):
    count = 0
    for token in tokens:
        if token.text.isalpha():
            count += 1
    return count >= 3
        
def segment_sentences_without_outliers(directory):
    sentence_length = []
    print("Checking:",os.path.basename(directory))
    for file in os.listdir(directory):
        with open(os.path.join(directory,file),'r') as f:
            text = f.read()
            doc = nlp(text)
            for i, sentence in enumerate(doc.sentences):
                if len(sentence.tokens) > 1 and has_three_words(sentence.tokens):
                    sentence_length.append(len(sentence.tokens)) 
    counter = Counter(sentence_length)
    return Counter({k:v for k,v in counter.items() if v > 5})

counters = []

for dataset_dir in [FOOD_REV_DIR, CV_PAPER_DIR, GAME_DIR]:
    count = segment_sentences_without_outliers(dataset_dir)
    print(count)
    counters.append(count)
    show_distribution(count)
# Out:
# Checking: food_reviews_scraping
# Counter({8: 42, 19: 40, 16: 37, 21: 37, 11: 36, 10: 35, 20: 34, 13: 30, 15: 29, 18: 28, 30: 28, 12: 28, 24: 28, 17: 27, 26: 26, 9: 24, 22: 24, 7: 24, 28: 22, 25: 22, 29: 21, 32: 20, 33: 19, 27: 19, 23: 17, 14: 16, 31: 14, 6: 14, 35: 13, 5: 11, 34: 11, 42: 9, 39: 9, 38: 9, 41: 9, 37: 7, 40: 7, 44: 6, 36: 6})
# Checking: Deep Learning and Computer Vision papers
# Counter({12: 144, 15: 137, 20: 134, 18: 127, 21: 120, 16: 120, 19: 119, 14: 116, 17: 113, 13: 109, 22: 108, 24: 107, 10: 106, 25: 100, 9: 98, 23: 96, 11: 94, 8: 94, 7: 91, 26: 90, 6: 87, 5: 82, 30: 75, 27: 73, 32: 65, 28: 60, 31: 59, 29: 55, 35: 52, 4: 52, 3: 50, 37: 45, 33: 45, 36: 43, 34: 38, 38: 29, 39: 26, 40: 25, 44: 20, 43: 19, 45: 18, 41: 17, 49: 17, 42: 17, 50: 16, 48: 13, 46: 13, 53: 13, 47: 13, 52: 12, 55: 8, 62: 8, 54: 7, 51: 6})
# Checking: darren_documents
# Counter({13: 1763, 10: 1750, 12: 1737, 11: 1725, 9: 1718, 7: 1703, 15: 1703, 8: 1677, 14: 1654, 6: 1577, 16: 1563, 18: 1434, 17: 1434, 5: 1318, 19: 1225, 20: 1186, 21: 1113, 22: 933, 23: 879, 24: 840, 4: 770, 25: 676, 26: 654, 27: 622, 28: 559, 29: 448, 30: 432, 31: 366, 32: 362, 33: 358, 3: 340, 34: 296, 35: 225, 36: 202, 37: 187, 38: 162, 40: 159, 39: 159, 41: 139, 44: 120, 42: 114, 43: 110, 46: 86, 45: 84, 49: 72, 47: 60, 48: 58, 50: 50, 51: 47, 53: 33, 57: 32, 56: 32, 54: 28, 52: 28, 55: 27, 59: 25, 58: 17, 63: 16, 62: 13, 68: 12, 65: 12, 67: 11, 66: 11, 61: 10, 69: 9, 77: 9, 60: 9, 64: 9, 75: 8, 72: 8, 73: 7, 71: 6, 70: 6, 104: 6})

# %%
def get_mean_from_counter(counter):
    sum_of_numbers = sum(number*count for number, count in counter.items())
    count = sum(count for n, count in counter.items())
    print("Mean:", sum_of_numbers / count)
    print("Most Common:", [key for key, count in counter.most_common(3)])

print("Mean values for 3 datasets:")
for counter in counters:
    get_mean_from_counter(counter)
# Out:
# Mean values for 3 datasets:
# Mean: 20.460620525059667
# Most Common: [8, 19, 16]
# Mean: 20.790061746545135
# Most Common: [12, 15, 20]
# Mean: 17.185373190449333
# Most Common: [13, 10, 12]

# %%
def get_sentences_of_length_alpha_required(directory, min_length=0, max_length=1000):
    sentence_length = []
    for file in os.listdir(directory):
        with open(os.path.join(directory,file),'r') as f:
            text = f.read()
            doc = nlp(text)
            for i, sentence in enumerate(doc.sentences):
                sentence_length.append(len(sentence.tokens))
                if len(sentence.tokens) >= min_length and len(sentence.tokens) < max_length and has_three_words(sentence.tokens):
                    print('\n-----\n')
                    print(*[token.text for token in sentence.tokens])

# %%
get_sentences_of_length_alpha_required(CV_PAPER_DIR, 50)
get_sentences_of_length_alpha_required(GAME_DIR, 50)
# Out:
# -----
#
# The above relation ( 1 ) is also valid for the correlogram trough during the falling phase of the EPSP , as long as del dt > if the EPSP falls more rapidly than the trough is limited at zero firing rate ( as illustrated for the correlogram at bottom ) .
#
# -----
#
# A monosynaptic connection from cell A to cell B would produce a first - order cross - correlation peak P1 ( BIA , t ) , representing the conditional probability that neuron B fires above chance at time t , given a spike in cell A at time t = O .
#
# -----
#
# A disynaptic link may be produced by two serial monosynaptic connections , from A to C and from C to B ( Fig. 2 , bottom left ) , or by a common synaptic input from C ending on both A and B ( Fig. 2 , bottom right ) .
#
# -----
#
# Feedforward parallel pathways are formed when cell A is monosynaptically connected to B and in addition has a serial disynaptic connection through C , as illustrated in Fig. 3 ( bottom left ) ; the correlational effects of the two linkages from A to B would sum linearly , as shown for excitatory connections .
#
# -----
#
# A persistent difficulty for pattern recognition systems is the requirement that patterns or objects be recognized independent of irrelevant parameters or distortions such as orientation ( position , rotation , aspect ) , scale or size , background or context , doppler shift , time of occurrence , or signal duration .
#
# -----
#
# For the i - th unit Yi of order M defined on a discrete input space , let the output be given by Yi [ YiM ( X ) , P ( x ) ] - f ( WiO + ~ Wi 1 ( X1 ) P ( x1 )
#
# -----
#
# We will first switch to a continuous formulation , however , for reasons of simplicity and generality , and because it is easier to grasp the physical significance of the results , although any numerical simulation requires a discrete formulation and has significant implications for the implementation of our results .
#
# -----
#
# In the case of translation invariance , the constraint on the functional form of the weight functions requires that w 1 ( U ; XI ) - wl ( u ; X ]. - XO ) , w 2 ( U ; XI , X2 ) - w2 ( U ;XI - XO , X2 - XO ) ,
#
# -----
#
# For a discrete implementation with N input units ( pixels ) fully connected to an output unit , this requirement reduces the number of second - order weights from order N2 to order N , i.e. , only weights for differences of indexes are needed rather than all unique pair combinations .
#
# -----
#
# w2 ( u ; X1 Ia , xv'a ) .. w 2 ( u ;' X.l. '~ ) ' w 3 ( u ; xlla , x2 / a , x3 / a ) ... w3 ( U ; X ] . , X2 , X3 ) , etc .
#
# -----
#
# w2 ( u ; rl , r2 ; tl , t2 ) - w 2 ( u ; rllr 2 ; tl , t 2 ) . w3 ( u ;rl , r2 , r3 ; tl , t 2 , t3 ) - w3 ( u ; ( rl - r2 ) / r3 ; tl , t2 , t3 ) .
#
# -----
#
# - W2 ( U ; Xl / X2 ; Yl / Y2 ) , W2 ( U ; Xl , Yl ; X2 , Y2 ) - w2 ( U ; ( Xl - X2 ) / ( Yl - Y2 ) ) , etc. W2 ( U ; Xl , Yl ; X2 , Y2 )
#
# -----
#
# Consider first the case of change - of - scale by a , followed by a translation XC ; the constraints on the weights up to second order are : Wl ( U ; Xl ) - wl ( u ; ( xl - xo ) / a ) , w 2 ( u ; Xl , x2 )
#
# -----
#
# Then W2 ( U ; Xl , Yl ; X2 , Y2 ) = w2 ( u ; ( xl / a ) - xO , ( Yl / a ) - YO ; ( x 2 / a ) - xO' ( Y2 / a ) - yO )
#
# -----
#
# W2 ( U ; Xl , Yl ; X2 , Y2 ) w2 ( U ; ( Xl - x o ) / a , ( Yl - yo ) / a ; ( x2 - xo ) / a , ( Y2 - Yo ) / a ) .
#
# -----
#
# This is often cited as a problem with higher - order networks , but we take the view that one can learn a great deal more about the nature of a problem by examining it at this level rather than by simply training a network that has a general - purpose architecture .
#
# -----
#
# We show how to estimate ( 1 ) the number of functions that can be implemented by a particular network architecture , ( 2 ) how much analog precision is needed in the connections in the network , and ( 3 ) the number of training examples the network must see before it can be expected to form reliable generalizations .
#
# -----
#
# L - 1 } , the numbering of the hidden units can be permuted , and the polarity of the hidden units can be flipped , which means that 2 50 is less than 2B by a factor ( among others ) of III Nl ! 2 N , .
#
# -----
#
# Lightness algorithms 2 - 8 , pioneered by Land , assume that the color of an object can be specified by its lightness , or relative surface reflectance , in each of three independent chromatic channels , and that lightness is computed in the same way in each channel .
#
# -----
#
# Lightness algorithms constrain the problem by restricting their domain to a world of Mondrians , two - dimensional surfaces covered with patches of random colors 2 and by exploiting two constraints in that world : ( i ) r' ( x , y ) is unifonn within patches but has sharp discontinuities at edges between patches and ( ii ) e' ( x , y) varies smoothly across the Mondrian .
#
# -----
#
# We used 1500 such pairs of inputoutput examples ( each different from the others ) to train the operator shown in Fig. 2 . ( c ) shows the result obtained by the estimated operator when it acts on the input data ( a ) , not part of the training set .
#
# -----
#
# Interestingly , the filter our scheme synthesizes is very similar to Land 's most recent retinex operator 5 , which divides the image irradiance at each pixel by a weighted average of the irradiance at all pixels in a large surround and takes the logarithm of that result to yield lightness 13 .
#
# -----
#
# 2 . The space - invariant part of the estimated operator , obtained by shifting and averaging the rows of a 160 - pixel - wide central square of the matrix L , trained on a set of 1500 examples with linear illumination gradients ( see Fig. 1 ) .
#
# -----
#
# The significance of our results lies in the facts that a simple statistical technique may be used to synthesize a lightness algorithm from examples ; that the technique does as well as other techniques such as backpropagation ; and that a similar technique may be used for other problems in early vision .
#
# -----
#
# 9 . A. Hurlbert and T. Poggio , Artificia LIntelligence Laboratory Memo 909 , ( M.LT. , Cambridge , MA , 1987 ) . 10 . r'{x , y ) can be recovered at best only to within a constant , since Eq. 1 is invariant under the transformation of r' int. o ar ' and e' into a - ie ' , where a is a constant .
#
# -----
#
# The point ofinterest is that ifthe net is allowed to undergo synaptic modifications by means of a modified hebbian learning rule while being presented with a specific spatial pattern ( i.e. , cells at specific spatial locations within the net are externally stimulated ) , subsequent presentations of the same pattern with different temporal characteristics will cause the population to recall patterns which are spatially identical ( the same cells will be active ) but which have different temporal qualities .
#
# -----
#
# Furthermore , the net will fall into the same limit cycle independently of the duration of the input stimulus , so long as the input stimulus is presented for a long enough time to raise the population activity level beyond a minimum necessary to achieve self - sustained activity .
#
# -----
#
# Hence , if we suppose that the net " recognizes " the input when it falls into the corresponding limit cycle , it follows that the net will recognize a string of input patterns regardless of the duration of each input pattern , so long as each input is presented long enough for the net to fall into the appropriate limit cycle .
#
# -----
#
# If the response time of the cells were increased in higher layers , it may be possible to have the lowest level respond to stimuli quickly enough to distinguish phonemes ( or some sub-phonemic basic linguistic unit ) , then have populations from this first level feed into a slower , word - recognizing population layer , and so On. Such a model may be able to perform word recognition from an input consisting of continuous phoneme strings even when the phonemes may vary in duration of presentation .
#
# -----
#
# It should be noted that in the past few years some researchers have begun investigating the possibility of neural networks that can exhibit time - dependent behavior , and I would like to report on some of the available results as they relate to the topic of temporal patterns .
#
# -----
#
# This problem with artificial receptors is true for both single implants , that stimulate large sections of the cochlea with signals that cover a large portion of the spectrum [ 4 , 5 ] , and multi channel implants , that stimulate specific regions of the cochlea with specific portions of the auditory spectrum [ 3,13 ] .
#
# -----
#
# Since there is no way of finding out the values of compression and dispersion a part from clinical trials , or even if these values do change in certain conditions , we need to create a structure that is flexible enough to modify the program structure by simple manipulation of parameters .
#
# -----
#
# E.~. ; Payne , !. L. ; Stenson , N.R. ; Vega , A. ; and Wolf , R.V. , EvaluatiOn of subJects presently fitted with implanted auditory prostheses , " Annals of Otology , Rhinology , and Laryngology , 1977 , Vol. 86 ( Supp. 38 ) , pp. 1-176 .
#
# -----
#
# Eddington , D.K. ; Dobelle , W.H. ; Brackmann , D.E. ; Mladejovsky , M.G. ; and Parkin , J. , " Place and periodicity pitch by stimulation of multiple scala tympani electrodes in deaf volunteers , " American Society for Artificial Internal Organs , Transactions , 1978 , Vol. 24 , pp. 1 - 5 .
#
# -----
#
# House , W.F. ; Berliner , .K. ; Crary , W. ; Graham , M. ; Luckey , R ; ; Norton , N. ; Selters , W. ; Tobm , H. ; Urban , J. ; and Wexler , M. , Cochlear implants , " Annals of Otology , Rhinology and Laryngology , 1976 , Vol. 85 ( Supp. 27 ) , pp. 1 - 93 .
#
# -----
#
# Evans and J.P. Wilson ( eds. ) , Psychophysics and Physiology 0 f Hearing , London : Academic Press , 1977 . Wasserman , G.S. , " Limulus psychophysics : Temporal summation in the ventral eye , " Journal of Experimental Psychology : General , 1978 , Vol. 107 , pp. 276-286 .
#
# -----
#
# Increment threshold , " Perception & Psychophysics , 1981 , Vol. 29 , pp. 251-260 . Wasserman , G.S. ; Felsten , G. ; and Easland , G.S. , " Receptor saturation and the psychophysical function , " Investigative Ophthalmology and Visual Science , 1978 , Vol. 17 , p. 155 ( Abstract ) .
#
# -----
#
# Wasserman , G.S. ; Wang - Bennett , L.T. ; and Miyamoto , R.T. , " Temporal dispersion in natural receptors and pattern discrimination mediated by artificial receptor , " Proc. of the Fechner Centennial Symposium , Hans Buffart ( Ed. ) , Elsevier / North Holland , Amsterdam , 1987 .
# -----
#
# In monocular deprivation , for example , some cells remain responsive to the closed eye in spite of the very large shift of most cells to the open eye - Singer et. al. 5 found , using intracellular recording , that geniculo - cortical synapses on inhibitory interneurons are more resistant to monocular deprivation than are synapses on pyramidal cell dendrites .
#
# -----
#
# Recent work suggests that the density of inhibitory GABAergic synapses in kitten striate cortex is also unaffected by MD during the cortical period 6 , 7 . These results suggest that some LGN - cortical synapses modify rapidly , while others modify relatively slowly , with slow modification of some cortico - cortical synapses .
#
# -----
#
# [ 3 ] Cooper , L. N , Munro , P. W. & Scofield , C. L. ( 1985 ) in Synaptic Modification , Neuron Selectivity and Nervous System Organization , ed. C. Levy , J. A. Anderson & S. Lehmkuhle , ( Erlbaum Assoc . , N. J. ) .
#
# -----
#
# In pattern classification we wish to find the stored vector that has the largest dot product with the input vector , and we say that the the input is a member of the class represented by that feature , or simply that that stored vector is closest to input vector .
#
# -----
#
# Typical approaches which use transistors sized in powers of two to give conductance variability take up an area equivalent to the same number of minimum sized transistors as the dynamic range , which is expensive in area and enables only a few connections to be put on a chip .
#
# -----
#
# circuits are now small enough that enough processors can be put on one chip to make these designs of a useful size , sophisticated design tools are now available that enable a single person to design and simulate a complete circuit in a matter of months , and fabrication costs are low enough that highly speculative circuits can be made without requiring future volume production to offset prototype costs .
#
# -----
#
# The objective of the learning algorithm is to adjust the parameters ( weights ) of the network in small steps , so as to move the unique equilibrium state in a way that will result finally in an output as close as possible to the required one ( for each given input ) .
#
# -----
#
# To show that this asymptotic solution is in fact an equilibrium , one simply takes U2 ( t ) = Ul (t + T ) , where T is a constant , and applies the above argument ( that J (t ) -+ 0 as t -+ < Xl ) , and hence Ul ( t + T ) -+ udt ) as t -+
#
# -----
#
# The regular geometry and the simple three - layered architecture makes these structures ideally suitable for EEG recording 4 , 8 . The EEG generators in the various olfactory regions have been identified and their synaptic connectivities have been extensively studied9 , 10 , 5 , 4 , 11 , 6 .
#
# -----
#
# Assuming that the two groups have Qmax values that are normally distributed ( in group A , mean = 14.6 , median = 14.6 ; in group B , mean = 14.3 , median = 14.1 ) , and that they have equal variances ( st. deviation group A is 1.84 ; st. deviation group B is 2.05 ) but different means , we estimated the power of the t-test to detect that difference in means .
#
# -----
#
# , , , r , , 4 I - ~ , , ' : 1 ' , ; , , " , 1 ' ; ' , " " v , 2 .- , , , " v , , , , " ; , " . ' o 1011121314151617181920
#
# -----
#
# Moreover specific feedback loops between populations of neurons have been described and analyzed in the olfactory bulb and the prepyriform cortex 3 , 9 , 4 . A monosynaptic negative feedback loop has been shown to exist in the PPC , between the pyramidal cells and inhibitory cells , called granule cells 3 , 2 , 6 , 16 .
#
# -----
#
# Evidence for mutual inhibition ( granule to granule ) in the PPC also exists 17 , 6 . The analysis of cell firings versus EEG amplitude at selected time - lags allows one to derive a function ( the PSC ) that relates synaptic potentials to output in a neural feedback system .
#
# -----
#
# This principle of " maximum information preservation " states that the signal transformation that is to be realized at each stage is one that maximizes the information that the output signal values ( from that stage ) convey about the input signals values ( to that stage ) , subject to certain constraints and in the presence of processing noise .
#
# -----
#
# I provide motivation for this principle and -- for some simple model cases -- derive some of its consequences , discuss an algorithmic implementation , and show how the principle may lead to biologically relevant neural architectural features such as topographic maps , map distortions , orientation selectivity , and extraction of spatial and temporal signal correlations .
#
# -----
#
# Further analysis 4 .s has shown that a suitable Hebb - type rule causes a linear - response cell in a layered feedforward network ( without lateral connections ) to develop so that the statistical variance of its output activity ( in response to an ensemble of inputs from the previous layer ) is maximized , subject to certain constraints .
#
# -----
#
# This principle of " maximum information preservation " states that for a layer of cells L that is connected to and provides input to another layer M , the connections should develop so that the transformation of signals from L to M ( in the presence of processing noise ) has the property that the set of output values M conveys the maximum amount of information about the input values L , subject to various constraints on , e.g. , the range of lateral connections and the processing power of each cell .
#
# -----
#
# For a discrete message space , peL ) [ resp. P ( M ) ] is the probability of the input ( resp. output ) message being L ( resp. M ) , and P (L , M ) is the joint probability of the input being L and the output being M. [ For a continuous message space , probabilities are
#
# -----
#
# is smallest when each L is transformed into a unique M , and more generally is made small by " sharpening " the P (M IL ) distribution , so that for each L , P ( M IL ) is near zero except for a small set of messages M. How can one gain insight into biologically relevant properties of the L - M transformation that may follow from the principle of maximum information preservation ( which we also call the " infomax " principle ) ?
#
# -----
#
# ( i ) A noise process alters L to a message L ' lying within a neighborhood of radius v centered on L. ( ii ) The altered message L ' is mapped deterministically onto one of the output messages M. A given L' - M mapping corresponds to a partitioning of the L space into regions labeled by the output states M. ( We do not exclude a priori the possibility that multiple disjoint regions may be labeled by the same M. )
#
# -----
#
# Consider first the case in which peL ) is uniform over L. Then the information rate R ( using Eqn. 5 ) is given approximately ( through terms of order v ) by R = - ~ M [A ( M ) / A ] 10g [ A ( M ) / A ] - ( yv/A ) ~ Ms (M ) .
#
# -----
#
# Although this simple analysis applies to the low - noise case , it is plausible that even when v is comparable to the spatial scale of the M regions , infomax will favor making the M regions have approximately the same extent in all directions ( rather than be elongated ) , in order to " sharpen " p ( MI L ) and reduce the probability of the noise process mapping L onto many different M states .
#
# -----
#
# For a simple example in which each state M has n M- neighbors ( including itself ) , and each M-neighbor has an equal chance of being the final state ( given M ) , infomax tends to favor each M-neighborhood having similar extent in all directions ( in L space ) .
#
# -----
#
# [ Such a pattern could be generated by choosing ( from a specified distribution ) a position Xc as the nominal disk center , then setting the activity of the cell at position X to 1 with a probability that decreases with distance I x - Xc I . ]
#
# -----
#
# We have constructed a situation in which ( for an appropriate choice of noise level ) two of the dimensions of the L state space -- namely , those defined by the disk center coordinates -- have large variance compared to the variance induced by the noise process , while the other dimensions have variance comparable to that induced by noise .
#
# -----
#
# In other words , the center position of a pattern is changed only a small amount by the noise process ( compared to the typical difference between the center positions of two patterns ) , whereas the values of the other attributes of an input pattern differ as much from their noise - altered values as two typical input patterns differ from each other .
#
# -----
#
# For the present case this means that the M regions will tend to " tile " the two long dimensions of the L state space " slab , " and that a single M value will represent all points ill L space that differ only in their low - variance coordinates .
#
# -----
#
# Two horizontal bar patterns that are displaced by a horizontal distance that is small compared with the bar length , are more likely to be rendered indiscriminable by the noise process than are two vertical bar patterns that are displaced by the same horizontal distance ( which may be large compared with the bar 's width ) .
#
# -----
#
# Consider now an L - M transformation that consists of the three - step process ( discussed above ) ( i ) noise - induced L - L ' ; ( ii ) deterministic L ' - M' ; ( iii ) lateral - interaction - induced M ' - M. Step ( ii ) maps the two - dimensional L state space of points ( x , 0 ) onto a one - dimensional M state space .
#
# -----
#
# For the present discussion , we . consider L' - M' maps satisfying the following Ansatz : Points corresponding to the M states are spaced uniformly , and in topographic order , along a helical line in L state space ( which we recall is represented by the surface of a horizontal cylinder ) .
#
# -----
#
# We have seen ( previous sections ) that infomax tends to produce maps having ( i ) equal M-region areas , ( ii ) topographic organization , and ( iii ) an input domain ( for each M-neighborhood ) that has similar extent in all directions ( in L space ) .
#
# -----
#
# If each M state corresponds to a localized output activity pattern centered at some position in a one-dimensional array of M cells , then this solution corresponds to orientation - selective cells organized in " orientation columns " ( really " orientation intervals " in this one - dimensional model ) .
#
# -----
#
# A " labeling " of the linear array of cells according to whether their orientation preferences lie between 0 and 60 , 60 and 120 , or 120 and 180 degrees is indicated by the bold , light , and dotted line segments beneath the rectangle in Fig. 1 b ( and 1 c ) .
#
# -----
#
# Suppose that the initial network layers organize the information from each ear ( separately ) into tonotopic maps , and that ( by means of connections having a range of different time delays ) the signals received by both ears over some time interval appear as patterns of cell activity at some intermediate layer L. We can then apply the infomax principle to the signal transformation from layer L to the next layer M. The L state space can ( as before ) be represented as a rectangle , whose axes are now frequency and interaural delay ( rather than spatial position and bar orientation ) .
#
# -----
#
# More generally , Kohonen 's algorithm tends empirically 8 to produce maps having the property that if one constructs the Voronoi diagram corresponding to the positions of the M-points ( that is , assigns each point L to an M region based on which M- point L is closest to ) , one obtains a set of M regions that tend to have areas inversely proportional to P ( L ) , and neighborhoods ( corresponding to our input domains ) that tend to have similar extent in all directions rather than being elongated .
#
# -----
#
# This raises the possibility that the connection I have drawn between synaptic modification rules and an information - theoretic optimization principle may be an example of a more general relationship that is important for the emergence of complex and apparently " goal - oriented If structures and behaviors from relatively simple local interactions , in both neural and non-neural systems .
# -----
#
# where ~ is the state of the neural network , a position vector in a high - dimensional space ; f ( ~ ) is a scalar energy , which can be imagined as the height of a landscape as a function of position ~ ; g(~ ) = 0 is a scalar equation describing a subspace of the state space .
#
# -----
#
# During constrained optimization , the state should be attracted to the subspace g ( ~ ) = 0 , then slide along the subspace until it reaches the locally smallest value of f ( ~ ) on g (~ ) = O. In section 2 of the paper , we describe classical methods of constrained optimization , such as the penalty method and Lagrange multipliers .
#
# -----
#
# Note that there is a auxiliary differential equation for A , which is an additional " neuron " necessary to apply the constraint g (~ ) = O. Also , recall that when the system is at a constrained extremum , VI = - AVg , hence , x. = O. Energies involving Lagrange multipliers , however , have critical points which tend to be saddle points .
#
# -----
#
# is positive definite in G , if xa{ t) and Aa ( t ) are bounded , and remain in G for all time , and ~f F is non-empty , then F is the largest invariant set in G * , hence , by LaSalle 's invariance theorem , the system ( t ) , Aa ( t ) approaches Fast -+ 00 .
#
# -----
#
# k ( x * - xc ) = 0 , k ( y * - Yc ) = 0 , ( 30 ) where ( x * , y*) are city coordinates , ( xc , Yc ) is the closest snake point to the city , and k is the constraint strength .
#
# -----
#
# b ) Each concentrator j ( j = 1 , 2 , ... , m ) is connected to no more than kj sites ( where kj is the capacity of concentrator D. Figure 3 ( b ) illustrates a possible solution to the problem represented in Fig. 3 ( a ) .
#
# -----
#
# After some algebraic re-arrangement , Eq. 3 can be written in the form of Eq. 1 where . , { A * 8 ( i , k ) * ( 1 -8 U , I ) + B * 8U , 1 ) * ( 1 - 8 ( i , k ? , if i < n and k<n T IJ kl = ( 4 ) , C * 8 U , I ) * ( 1 - 8 ( i , k ? , if i >n or k>n .
#
# -----
#
# D ? 8 ( j , I ) ? ( 1 - 8 ( i , k ) ) ( cost [ i , j ] + cost [ k , I ] ) where cost [ i , j ] is the cost of assigning site i to concentrator j.
#
# -----
#
# Finally , the fact that photorefractive holograms may extend over the entire volume of the crystal has previously been shown to imply that as many as 10 10 interconnections may be stored in a single crystal with the independence of each interconnection guaranteed by an appropriate spatial arrangement of the interconnected neurons 6 , 5 .
#
# -----
#
# Abstract : We propose that the back propagation algorithm for supervised learning can be generalized , put on a satisfactory conceptual footing , and very likely made more efficient by defining the values of the output and input neurons as probabilities and varying the synaptic weights in the gradient direction of the log likelihood , rather than the ' error ' .
#
# -----
#
# It seems to us natural , in the context of the medical diagnosis pro blem , the other real world problems to which backpropagation has been applied , and indeed in any mapping problem where one desires to generalize from a limited and noisy set of examples , to interpret the output vector in probabilistic terms .
#
# -----
#
# Indeed because back propagation using the standard ' Error ' measure can not converge to generate outputs of 1 or 0 , it has been customary in the literature 4 to round the target values so that a target of 1 would be presented in the learning algorithm as some ad hoc number such as . 8 , whereas a target of 0 would be presented as . 2 .
#
# -----
#
# constructed with an intermediate layer which is not bypassed by any connections ( i.e. there are no connections from layers preceding to layers subsequent ) , and if furthermore the activation functions are chosen so that the values of each of the intermediate nodes tend towards either 1 or 0 * 2 , then this layer serves as a bottleneck to information flow .
#
# -----
#
# ( 1 ) Werbos , P , " Beyond Regression : New Tools for Prediction and Analysis in the Behavioral Sciences " , Harvard University Dissertation ( 1974 ) ( 2 ) Parker D. B. , " Learning Logic " , MIT Tech Report TR - 47 , Center for Computationl Research in Economics and Management Science , MIT , 1985 ( 3 ) Le Cun , Y. , Proceedings of Cognitiva 85,p599-604 , Paris ( 1985 ) ( 4 ) Rumelhart , D. E. , Hinton , G. E. , Williams , G. E. , " Learning Internal Representations by Error Propagation " , in " Parallel Distributed Processing " , vol 1 , eds .
#
# -----
#
# Rumelhart , D. E. , McClelland , J. L. , MIT Press , Cambridge MA , ( 1986 ) ( 5 ) Sejnowski , T. J. , Rosenberg , C. R. , Complex Systems , v 1 , pp 145-168 ( 1987 ) ( 6 ) LeCun , Y. , Address at 1987 Snowbird Conference on Neural Networks ( 7 ) Gorman , P. , Sejnowski , T. J. , " Learned Classification of Sonar Targets Using a Massively Parallel Network " , in " Workshop on Neural Network Devices and Applications " , JPLD - 4406 , ( 1987 ) pp224-237 ( 8 ) Rosenblatt , F. , " Principles of Neurodynamics : Perceptrons and
#
# -----
#
# the theory of brain mechanisms " , Spartan Books , Washington DC ( 1962 ) ( 9 ) Widrow , B. , Hoff , M. E. , 1960 IRE WESCON Cony . Record , Part 4 , 96-104 ( 1960 ) ( 10 ) Duda , R. 0 . , Hart , P. E. , " Pattern Classification and Scene Analysis " , John Wiley and Sons , N.Y. , ( 1973 ) ( 11 ) Guiasu , S. , " Information Theory with Applications " , McGraw Hill , NY , ( 1977 ) ( 12 ) Baum , E.B. , " Generalizing Back Propagation to Computation " , in " Neural Networks for Computing " , A l P Conf. Proc. 151 , Snowbird UT ( 1986 ) pp47 - 53 ( 13 ) Anderson , C.H. , Abrahams , E. , " The Bayes Connection " , Proceedings of the IEEE International Conference on Neural N etwor ks , San Diego , ( 1987 )
#
# -----
#
# Let ( ) ( , Y ) be an ( address . datum ) pair . vhere ) ( is a vector of n ?ls and Y is a vector of m ? ls. and let ( ) ( l ) , y ( I ) ) , ... , ( ) ( M ) , y ( M ) ) . be M ( address , datum ) pairs stored in an associative memory .
#
# -----
#
# In practice it is too difficult to compute the capacity of a given associative memory yith inputs of length n and outputs of length Tn. Fortunately , though , it is easier to compute the asymptotic rate at which A1 increases , as n and Tn increase , for a given family of associative memories .
#
# -----
#
# Recall that our definition of the capacity of an associative memory is the largest A1 such that for most sequences of addresses X ( 1 ) , ... , X ( M ) and most sequences of data y ( l ) , ... , y ( M ) , the memory can correct fraction 8 errors .
#
# -----
#
# It fol10vs that the total number of distinct y U ) s can be at most 2 n jv n .d ' Nov , from Stirling 's formula it can be shovn that if d:S ; nj2 , then vn.d = 2nh2 ( d / n ) + O( logn ) , vhere h 2 ( 8 ) = - 81og 2 8 - ( 1 - 8 ) log2 ( 1 - 8 ) is the binary entropy function in bits , and O ( logn ) is some function yhose magnitude grovs more slovly than a constant times log n.
#
# -----
#
# Thus the total number of distinct y ( j ) s can be at most 2 n ( 1 - h2 ( S ? + O ( logn ) Since any set containing I most sequences ' of Af Tn - bit vords vill contain a large number of distinct vords ( if Tn is
#
# -----
#
# In general a function fen ) is said to be O ( g ( n ) ) if f ( n ) fg ( n ) is bounded , i.e. , if there exists a constant a such that If ( n ) 1 : 5 a\g ( n ) 1 for all n.
#
# -----
#
# It does not seem surprising , then , that the capacity of the Kanerva associative memory can grov exponentially in n , for it is knovn that the capacity of the Hopfield array grovs almost linearly in k , assuming the coordinates of the k-vector are dravn at random by independent flips of a fair coin [ 1 ] .
#
# -----
#
# The components of the n-vectors X ( l ) , .. . , X ( Mn ) , the m-vectors y ( l ) , ... , y( , Yn ) , and the k X n matrix Z are assumed to be lID equiprobable ? 1 random variables .
#
# -----
#
# If the exponential growth rate of the number of stored words Afn is asymptotically less than C p , , , ( 0 ) , then for every sufficiently large address length n. there is some realization of the nx 2 n " preprocessor matrix Z such that the associative memory can correct fraction 0 errors for most sequences of Afn ( address , datum ) pairs .
#
# -----
#
# For K , > K , o ( p ) , Cp , , , ( o ) remains unchanged , while for K$ K , o ( p ) , Cp , , , ( o ) is simply shifted do VIl by the difference KO ( p ) - K , .
#
# -----
#
# A universal upper bound on the growth of the capacity of such an associative memory was shown by a sphere packing argument to be exponential with rate 1 - h 2 ( c ) , where h2 ( C ) is the binary entropy function and 8 is the radius of attraction .
# -----
#
# After observing the first sample ( Xl , Yl ) E X x Y , Fa is reduced to Fi so that I ( xt ) = Yl for any I E F. After observing the second sample ( X2 ' Y2 ) E X x Y , Fl is further reduced to F2 so that i ( xt ) = Yl and I ( X2 ) = Y2 for any I E F .
#
# -----
#
# Algorithm 2 , At the initial stage , let So be composed of an arbitrary element in X x Y . For every i = 1 , 2 " " , let ii - lex ) for any x E X equal some y. such that ( x? , y.) E Si -l and d ( x , x ? ) =
#
# -----
#
# Then , measure the Euclidean distance 6 between fj and a black point B on x being the closest to B. Let d ( x , x ) be the summation of 6's for all black points B 's on x divided by the number of B 's . ?
#
# -----
#
# If the Fourier transforms r ( f ) = F{r ( t ) } , w ; ( f ) = F { W ; ( t ) } , Yj ( f ) = F { Yi ( t ) } , and aj ( f ) = F { ai ( t ) } exist , then Yi ( f )
#
# -----
#
# Let W ( k ) ( t ) = [ WI ( t ) ( k ) ( t ) where w/k ) ( t ) is the vector whose elements W ; ) t ) ( t ) are transfer functions to the neuron i at the k - th step of learning .
#
# -----
#
# four , five , six. 10 [ \ I ~ ] seven , eight , nine } , was translated into a bipolar pattern , adding 11 [ u w ] 12 two time units of transition between two consequtive phonemes [ a ; J 13 [ a ] by interpolating the frequency and bandwidth parameters [ a Wl 14 linearly .
#
# -----
#
# These test pat17 [ y ] terns are shown in Fig. 3 . 18 [ r ] 19 [ I ] 20 [ f ] 21 [ v ] I 'IlDM _ Label I 1 5 7 , II Il 15 .7 . , JI 21 Z5 17 It 2 4 , I II 11 14 16 II II U 14 I ' II JO 22 [ 9 ] II. 23 [ \ ] 24 [ s ] 25 [ z ] 26 [ p ] 27 [ t ] 28 [ d ] 29 [ k ] 30 [n ]
#
# -----
#
# Model 1 ( Spatio - temporal Matched Filter Bank ) Let a (t ) = O ( t ) , ( / tk ) = et in ( 3.3 ) where ek is a unit vector with it s elements eki = O ( k - i ) . ( 6.4 )
#
# -----
#
# Given a spatio - temporal pattern of size L x K , i.e. , L spatial elements and K temporal elements , the number of calculations required to process the first stage of filtering by both models is the same as that by a static formal neuron network in which each neuron is connected to the L x K input elements .
#
# -----
#
# The model operates in two stages : in the first stage , it calculates the correlation between the input and prototype patterns stored in the transfer function matrix , and , in the second stage , a lateral inhibition network selects the output of the phoneme pattern close to the input pattern .
#
# -----
#
# that describes how a unit is driven by inputs , a linear ordinary differential operator with constant coefficients D ( v ) that describes the dynamical response of each unit , and a function g that describes how the output of a computational unit is detennined from its state v.
#
# -----
#
# The critical result that allows us to map \\ optimization problems into transform that detennines unit i 's networks described by Eq. output from state variable Vi ( 1 ) is that conditions on the constituents of the equation differential operator specifying the can be chosen so that along dynamical characteristics of unit i any solution trajectory , the E function corresponding function governing how inputs to to the system will be a unit i are combined to drive it monotonic function of time .
#
# -----
#
# In conclusion , mapping optimization problems onto dynamical systems summarized by Eq. ( l ) can be reduced to a matter of differentiation if a scalar function representation of the problem can be found and the integrals of Eqs. ( 2 b ) and ( 3 b ) are ignorable .
#
# -----
#
# this study anticipates application to the creation of analog devices that would instantiate Eq. ( 1 ) ; hence , we are not interested in estimating the number of discrete steps that would be required to find local optima , an appropriate performance measure if the point was to develop new numerical methods .
#
# -----
#
# For this case , if Vj = 0 is on the trajectory of any computational unit i for one method , Vj 0 is on the trajectory of that unit for the other method ; hence , a comparison of settling times can be obtained by comparing time estimates for a computational unit to evolve from near 0 to near an extremum or , equivalently , the converse .
#
# -----
#
# spherical surface : ( 12 ) where ~ is the electric potential at the spherical conductor surface , ' Xsamp / ~ is the location of the sample point ( x denotes a vector , i the corresponding unit vector , and x the corresponding vector magnitude ) , j 1 ; is the dipole moment of dipole i , and d ; is the vector from dipole i to X:ampl ~
#
# -----
#
# Further simplifications of the problem included 1 ) choosing the dipole model locations to correspond exactly to various locations of the cluster , 2 ) requiring dipole model moments to . be I , 0 , or - I , and 3 ) representing dipole moments at cluster locations with two bit binary numbers .
#
# -----
#
# In real world situations , we do not know the source distribution underlying ~_asar~d . ) , C is an experimentally detennined constant ( . 002 was used ) , and ~ c lJIS '~r is Eq. ( 12 ) where the sum of Eq. ( 12 ) is taken over all cluster locations and the k,h coordinate of the i , h cluster location dipole moment is ?
#
# -----
#
# The calculations were done for two initial states , one where the output of 1 computational unit was set to zero and one where outputs of 13 computational units were set to zero ; bence , 1 and 13 , respectively , half transitions were required to reach the target hypercube comer .
#
# -----
#
# 4 which illustrates one dimensional search starting at point I. Since both optimization methods must decrease function E monotonically , both must head along the same path to the minimum point A. Now consider Fig. 5 which illustrates a two dimensional search starting at point I : Here , the two methods need n't follow the same paths .
#
# -----
#
# ~ erent dipole different target different dipole different target comer comer solution comer comer , solution 1 4 0 5 0 0 4 1 1 1 0 3 4 4 1 1 0 0 4 1 1 2 0 2 1 4 4 1 0 0 3 1 1 5 0 0 5 5 0 0 0 I 0 2 3 0 5 0 0
#
# -----
#
# It is noted that the measured electric potentials , Figure 6 : Schematized circuits for a com - ~_as " rcd ' appear as linear coefficients in F of Eq. putational unit Notation is consistem ( 14 ) ; hence , they would appear as constant terms in with Horowitz and Hill IS .
#
# -----
#
# note that funcunit for method Vr b ) Computational tion Ij of Fig. 1 corresponding to the optimization of . ti thod V function F of Eq. ( 14 ) would involve a weighted umt or me ... linear sum of inputs g 1 ( v 1 ) , ??? , gN ( VN ) .
#
# -----
#
# Non-sphericity ar!d major inhomogeneities in conductivity Car ! be dealt with , to a certain extent , by replacing Eq. ( 12 ) with a generalized equation based on a numerical approximation of a boundary integral equation 20 4 ) The cerebral activity of interest may not be observable at the scalp .
#
# -----
#
# To show that for a dynamical system based on method Vr E , . is a monotonic function of time given that all functions g are differentiable and monotonic in the same sense , we need to show that the derivative of ET with respect to time is semi-definite :
#
# -----
#
# In order to use the results derived above to conclude that Eq. ( 1 ) can be used for optimization of functions 4 and Et in the vicinity of some point we need to show that there exists a neighborhood of Vo in which there exist solution trajectories to Eq. ( 1 ) .
#
# -----
#
# Bawn E. , Neural Networks for Computing , ed. Denker 1.S. ( AlP Confrnc . Proc. 151 , ed. Lerner R.G. ) , p 53 - 58 , 1986 . Brody D.A. , IEEE Trans. v BME - 32 , n 2 , pl06-110 , 1968 . Brody D.A. , Terry F.H. , ! deker RE. , IEEE Trans. v BME - 20 , p141-143 , 1973 . Cohen M.A. , Grossberg S. , IEEE Trans. v SMC - 13 , p815-826 , 1983 . Cuffin B.N. , IEEE Trans. v BME - 33 , n 9 , p854-861 . 1986 . Darcey T.M. , AIr J.P. , Fender D.H. , Prog . Brain Res. , v 54 , pI28-134 , 1980 . Freeman W J. , " Mass Action in the Nervous System " , Academic Press , Inc. , 1975 .
#
# -----
#
# Gevins A.S. , Morgan N.H. , IEEE Trans. , v BME - 33 , n 12 , pl054-1068 , 1986 . Goles E. , Vichniac G.Y. , Neural Networks for Computing , ed. Denker J.S. ( AlP Confrnc . Proc. 151 , ed. Lerner R.G. ) , p 165-181 , 1986 . Guckenheimer J. , Holmes P. , " Nonlinear Oscillations , Dynamical Systems , and Bifurcations of Vector Fields " , Springer Verlag , 1983 .
#
# -----
#
# Hosek RS. , Sances A. , Jodat RW. , Larson S.I. , IEEE Trans. , v BME - 25 , nS , p 405-413 , 1978 . Hutchinson J.M. , Koch C. , Neural Networks for Computing , ed. Denker J.S. ( AlP Confrnc . Proc. 151 , ed. Lerner RG. ) , p 235-240 , 1986 . Jeffery W. , Rosner R , Astrophys . I. , v 310 , p473-481 , 1986 . Lapedes A. , Farber R. , Neural Networks for Computing , ed. Denker 1.S. ( AlP Confrnc .
#
# -----
#
# Platt I.C. , Hopfield J.J. , Neural Networks for Computing , ed. Denker I.S. ( AlP Confrnc . Proc. 151 , ed. Lerner RG. ) , p364-369 , 1986 . Press W.H. , Flannery B.P. , Teukolsky S.A. , Vetterling W.T. , " Numerical Recipes " , Cambridge U. Press , 1986 .
# -----
#
# The authors would like to thank John Lambe for his invaluable suggestions , T . Duong for his assistance in the breadboard hardware development , J. Lamb and S. Thakoor for their help in the thin film resistor deposition , and R. Nixon and S. Chang for their assistance in the chip layout design .
#
# -----
#
# Khanna , MRS Proc. 95 , 627 ( 1987 ) W. Hubbard , D. Schwartz , J. Denker , H.P. Graf , R. Howard , L. Jackel , B. Straughn , and D. Tennant , AIP Conf. Proc. 151 , 227 ( 1986 ) M.A. Sivilotti , M.R. Emerling , and C. Mead , AIP Conf. Proc. 151 , 408 ( 1986 ) J.P. Sage , K. Thompson , and R.S. Withers , AIP Conf. Proc. 151 ,
#
# -----
#
# |~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~| | - Table of Contents ..................... CT.TS | | - Walkthrough ........................... 01.00 | | - Prologue......................... 01.01 | | - Silent Hill ...................... 01.02 | | - Getting to School ................ 01.03 | | - Midwich Elementary School........ 01.04 | | - Alternate School................. 01.05 | | - Silent Hill ...................... 01.06 | | - Alchemilla Hospital.............. 01.07 | | - Alternate Hospital............... 01.08 | | - Silent Hill ...................... 01.09 | | - Alternate Silent Hill ............ 01.10 | | - Silent Hill ...................... 01.11 | | - Sewers ........................... 01.12 | | - Silent Hill ...................... 01.13 | | - Kaufmann Sidequest ............... 01.14 | | - Alternate Silent Hill ............ 01.15 | | - Sewers PArt II ................... 01.16 | | - Amusement Park ................... 01.17 | | - Nowhere .......................... 01.18 | | - Boss Guide ............................ 02.00 | | - Lizard ........................... 02.01 | | - Larva ............................ 02.02 | | - Moth............................. 02.03 | | - Woman............................ 02.04 | | - Final Boss ....................... 02.05 | | - Endings ............................... 03.00 | | - Item Locations ........................ 04.00 | | - Item List ............................. 05.00 | | - Legal & Copyright ..................... LE. AL | | - Credits & Thanks ...................... CR. DS | |____________________________________________________________________________|
#
# -----
#
# | ITEM CHECKLIST | Handgun ........................................|_| | | | Health Drink ...................................|_| | | | Flashlight .....................................|_| | | | Residential Area Map...........................|_| | | | Kitchen Knife ..................................|_| | | | Health Drink ...................................|_| | | | Pocket Radio...................................|_| | | | Handgun Bullets ................................|_| | | | Handgun Bullets ................................|_| | | | Health Drink ...................................|_| | | | Handgun Bullets ................................|_| | | | Handgun Bullets ................................|_| | | | Health Drink ...................................|_| | | | Health Drink ...................................|_| | | | Health Drink ...................................|_| | | | First Aid Kit ..................................|_| | | | Health Drink ...................................|_| | | | Handgun Bullets ................................|_| | | | Handgun Bullets ................................|_| | | | Steel Pipe.....................................|_|
#
# -----
#
# | ITEM CHECKLIST | Handgun Bullets ................................|_| | | | Key of " Lion " ..................................|_| | | | Key of " Scarecrow " .............................|_| | | | Health Drink ...................................|_| | | | First Aid Kit ..................................|_| | | | Health Drink ...................................|_| | | | House Key ......................................|_| | | | First Aid Kit ..................................|_| | | | Handgun Bullets ................................|_| | | | Health Drink ...................................|_| | | | Handgun Bullets ................................|_| | | | Health Drink ...................................|_| | | | Health Drink ...................................|_| | | | Handgun Bullets ................................|_| | | | Health Drink ...................................|_| | | | Handgun Bullets ................................|_| | | | Health Drink ...................................|_| | | | Health Drink ...................................|_|
#
# -----
#
# | ITEM CHECKLIST | School Map.....................................|_| | | | Handgun Bullets ................................|_| | | | Health Drink ...................................|_| | | | First Aid Kit ..................................|_| | | | Handgun Bullets ................................|_| | | | Handgun Bullets ................................|_| | | | Health Drink ...................................|_| | | | Chemical .......................................|_| | | | Gold Medallion .................................|_| | | | Handgun Bullets ................................|_| | | | First Aid Kit ..................................|_| | | | Handgun Bullets ................................|_| | | | Silver Medallion ...............................|_|
#
# -----
#
# The final answer is : _______________________________________________________________________ | | | | | | | | | | | | | | | 5 | | | | | | | | | 3 | | | |_____| |_____| | |_____| |_____| |_____| | | | | | | | | | | | 1 | | | 4 | 2 | | |________|___________|________|________|___________|___________|________|
#
# -----
#
# | ITEM CHECKLIST | First Aid Kit ..................................|_| | | | Handgun Bullets ................................|_| | | | Picture Card ...................................|_| | | | Health Drink ...................................|_| | | | First Aid Kit ..................................|_| | | | Health Drink ...................................|_| | | | Handgun Bullets ................................|_| | | | Shotgun ........................................|_| | | | Handgun Bullets ................................|_| | | | Handgun Bullets ................................|_| | | | Shotgun Shells .................................|_| | | | Handgun Bullets ................................|_| | | | Rubber Ball ....................................|_| | | | Handgun Bullets ................................|_| | | | Health Drink ...................................|_| | | | Shotgun Shells .................................|_| | | | Library Reserve Key ............................|_| | | | First Aid Kit ..................................|_| | | | Handgun Bullets ................................|_| | | | Classroom Key ..................................|_| | | | Health Drink ...................................|_| | | | Health Drink ...................................|_| | | | Shotgun Shells .................................|_| | | | Shotgun Shells .................................|_| | | | Ampoule ........................................|_|
#
# -----
#
# | ITEM CHECKLIST | K. Gordon Key ..................................|_| | | | Handgun Bullets ................................|_| | | | Handgun Bullets ................................|_| | | | Health Drink ...................................|_| | | | Health Drink ...................................|_| | | | Handgun Bullets ................................|_| | | | Handgun Bullets ................................|_| | | | Handgun Bullets ................................|_| | | | Shotgun Shells .................................|_| | | | First Aid Kit ..................................|_| | | | Flauros ........................................|_| | | | Drawbridge Key .................................|_| | | | Health Drink ...................................|_| | | | Health Drink ...................................|_| | | | Shopping District
#
# -----
#
# ...
#
# -----
#
# \________||_____________||| | || V || \__nathan_ave____ _______| | || | | | | | | | | || || W Y | m | | | | | | | | | | u | | | | | || | | | n| | | | | || ||c | s|_____||| | || X || a | o|------^| | | |r | n | | | | |r | | | | ||o | s | | | | |l | t| Z | | | |l | | | | || _______________| |_______| | South Vale
#
# -----
#
# -------------------------------------------------------------------o | | | LOCATIONS | | | | A - Rosewater Park B - Silent Hill Savings Bank | | C - Pet Center D - Wood Side Apartment | | E - Blue Creek Apartment F - St. Stella Church | | G - South Silent Hill Fire Station H - Ridgeview Medical Center | | I - Big Jay 's J - Grand Market | | K - Cafe Mist L - Cafe Texan | | M - Neely 's Bar N - Gonzale 's Mexican Restaurant | | O - Happy Burger P - Flower Shop | | Q - Lucky Jade Restaurant R - Rosewater Park | | S - Parking T - Boat Launch | | U - Silent Hill Historical Society V - Pete 's Bowl - O - Rama | | W - Texxon Gas X - Heaven 's Night | | Y - Jacks Inn Z - Blue Creek Apartment | | | o----------------------------------------------------------------------------o
#
# -----
#
# o----------------------------------------------------------------------------o | _ | | WOOD SIDE APARTMENT 1F |_|_________ | | |_| | | | | _| / | | |/ | | | || 104 | | | || S | | | | | | | | ||_________| | | || | ________ | | || | | | | | __________________ || | | | | | | | | || 103 | | \ | | | ___________ | | || | | 107 | | | | | | | | || | | | | | | | Q | | | ||_________| | | | | | |___________| | | || | |________ | | | | _______ __| | || | | O| | | |/\ | || | | || | | | | | | |\ / | | | | | || 102 | | | | | | |___|_______||__| | || | | 106 | | | | | | || | | | | | | | |________||_________| | || | | | --------
#
# -----
#
# |________|| | | |_________________ | | | | | | | | | | | | | | | | | | | | | | | | | | | | | || | | 101 | | 105 | | | | || | | | | | | | | || || R | | || | | __________________________||________||_________| |_______ | | | | | ____|| |_||| | | | | |_ _ | | _|- | | | | | | _| | | |_| | | | | | |_| | |_ | _|_ | | | | | |_|_B | P | | | | | | | A $ | | | | | | |_____________________|_____|
#
# -----
#
# o----------------------------------------------------------------------------o | _ | | WOOD SIDE APARTMENT 2F |_|_________ | | |_| | | | |_| I / | | |/ | | | || $ 209 | | | || | | | | | | | | ||_________| _________ | | | | | | | | | | | | | | | | || G | | \ | | || 208 | | 212 | | | || | | | | | || | | | | | ||_________| |_________ | | | || | | || | | || | | | | | | | | | | | | | | || 207 | | 211 | | | | | | | | | | | | | | | | | | | | ||_________| |_________|| | | || | | | | | | | | | | E || | | | | | | | | | | || 206 | | D 210 | | | | | | | | | | | | | | | | || | | ____________________________________||_________|_____________|_________|| | | |------------------------------------------------------------------------| | | | | |____|| | | | |_||| | | | | | |_ _ | | | | C |_|-| | | | | | | _| | | | | | |_| | | | | | 201 | 202 | _| | |_| 203 | 204 | 205 | _|_| | | | | | H |_|_| | | | | | | | | | | | | | | | | | | | |__________|__________|_____|
#
# -----
#
# o----------------------------------------------------------------------------o | _ | | WOOD SIDE APARTMENT 3F |_|_________ | | |_| | | | |_| / | | |/ | | | || 309 | | | || | | | || | | | ||_________| | | || | | | || | | | || | | | | | 308 | | | | | | | | | | | | | ||_________| | | | | | | | | | | | | | | | | | | | 307 | | | || | | | || J | | | ||_________| | | || | | | | | | | | | | | | | || 306 | | | || | | | || | | | ____________________________________||_________|________________________ | | |---------------------------------K--------------------------------------| | | | | |____|| | | | |_||| | | | | F | |_ _ | | N | | |_|-| | | | | | | _| | | | | | |_| | | | | | 301 | 302 | _| | |_| 303 | 304 | 305 | _|_| | | | | | |_|_| | | | | | | | | | | | | | L M | | | | | | |__________|__________|_____|
#
# -----
#
# -------------------------------------------------------------------o | | | ITEMS | | | | A - Map of Apartment Building B - Health Drink | | C - Flashlight D - Handgun Bullets | | E - Handgun Bullets F - Handgun | | G - Key to Room 202 H - Clock Key | | I - Health Drink J - Courtyard
#
# -----
#
# _________ _________ | | | ||______ 1F | ||______ 2F | ||______ 3 F | | | || |||||| | || || |||| | || | | || | | | | | || | | ||| | || | | ||| | || | | || | | | | 108 ||______|__ | 208 ||______|__ | 308 ||______|__ | | | || | | || | | || | | | | || | | | | | | | | | | | | || 107 | | M $ | | 207 | | | | 307 | | | | || | | N || | | | | | | | |_________|| | |_________|| | |_________|| | | | | ||_________| | ||_________| | ||_________| | | | || | | | | | | | | | | | | | | | | | | | | | | | | | | 109 | | 106 | | 209 | | 206 | | 309 | | 306 | | | | || | | | | | | | | | | | | IJ | | | | | | | | | | | | | |_________||_________|
#
# -----
#
# |_________||_________| | | | || L | | G || | | | | | | | _|____|| | _|____|| | _|____|| | | | | ||||||| 105 | | |||||| | 205 | | |||||| | 305 | | | __|_||||||| | __|_|||| F| | | __|_|||||| | | | | | || K $ | | | | | | | | | | | | ||_________| | ||_________| | ||_________| | | | 101 || | | 201 || | | 301 || | | | | || | | || | | | | | | | | || 104 | | || 204 | | || 304 | | | |_________|| | |_________|| | |_________|| | | | | || | | | | | | | | | | | | ||_________| | ||_________| | ||_________| | | | || | | | | | | | | | | | | | | | | || A | | | | | | | | 102 | | 103 | | 202 | | 203 B | | 302 | | 303 | | | | || | | || E C | | | | | | | | | | | | || D | | | | | | | |_________||_________|
#
# -----
#
# Kit H - Handgun Bullets | | I - Angela 's Knife J - Coin [ Prisoner ] | | K - White Chrism L - Lyne House Key | | M - Handgun Bullets N - Apartment Stairway Key | | $ - Save Point | | | o----------------------------------------------------------------------------o
#
# -----
#
# |6 | ____________ |15 | | | | | | | |9 |10 | | PP | | | | | | | | | | |______| | | | | |______| | $ B | C | |16 | | | | | | 7 | | | | | | | | | Garden | | | |_______|____| |______| | | | | |______| |11 |12 | |17 | | | | _|____|8 | | | | |__ | | | | |5 | | | | G | | |___| | | | | | | |_____| | |__| | | | | ________ | |______| |13 |____ ___| |18 | | | | | |2 | |_|___________| |||||| | | |14 | |______| | | | | | | |_|3 | | |----- | | | | |19 | | | | | |__|_|_| | | ||||||_| |___|____| | | | | |_____________| | |___|_______|___|______|
#
# -----
#
# |______| | | |_____________%AA_______________________ | | | |20 | | | | | | | | | | |_____| | | | | | | | | | | | V | | DD | 4 | |____| | | | | | | | | | | | | | Day Room | | | | | | | Pool |__|__| C4 | C3 | C2 | C1 | | |____| | | | | | |1 | | | | | | | | | | | | | | | U | BB | CC | | | | | | | |_________|_____|_____|_____|_____|_____|_____|_________________|_|______| | | | | | | | | BF ______ | | _______________ |25 | | | |||||||| | 22 |_______| | | | |______| | NN |23 | |______| | | |21 | |______|_____| |26 | | | |______|________________|______| | | |24 | | | | | | | |______| | | | o----------------------------------------------------------------------------o
#
# -----
#
# _________________ | | | |__________________________________________ | | | | | | | S | S | S | $ |S | S | S | S | S | S | S | S | S | S |_____ | | | | | | |1 | 1 | 1 | R|1 | 9 | 8 | 7 | 6 | 5 | 4 | 3 | 2 | 1 | 31 | |____| | | | |4 |3 | 2 | II|0 | | | | | | | Q | | | | Day Room | | | | | RF
#
# -----
#
# |_S|__|__|JJ|__|__|__|__|__|__|__|__|__|___| | |____| | | | ___________ | | | | | | |_____| |35 |______ | | | | | | ||||||| | | | |_____|_________________|_| | | | |_____| | ________ | | | | |40 | | | | | | | D E | |_____ | | | | |______| |42 F | | | | | |41 | |_____| | | | | | | |43 | | | | | | | | | | | | | ________
#
# -----
#
# H | | | | | | | | | | | | |_____| | | | | | | | | | | | |39 | |____| | | | | | | | | | | | Day Room | | | | | | M6 | M5 | M4 | M3 | M2 | M1 | | |____| | | | |O GG | | | | | | | OO | | | | | N HH | | EE FF | LM | JK | | | | | | | |______|_____|______|______|______|_____|_____|_________________|_| | | | o----------------------------------------------------------------------------o
#
# -----
# -------------------------------------------------------------------o | | | LOCATIONS | | | | 1 - Shower Room 2 - Elevator | | 3 - Bath 4 - Rest Room | | 5 - Examining Room 2 6 - Pharmacy | | 7 - Store Room 8 - Visiting Room | | 9 - Reception Office 10 - Document Room | | 11 - Examination Room 12 - Doctor 's Lounge | | 13 - Examining Room 1 14 - Elevator | | 15 - Director 's Room 16 - Meeting Room | | 17 - Men's Washroom 18 - Women 's Washroom | | 19 - Cafeteria 20 - Kitchen | | 21 - Electrical Room 22 - Store Room | | 23 - Elevator 24 - Store Room | | 25 - Boiler Room 26 - Pump Room | | 27 - Elevator 28 - Shower Room | | 29 - Bath 3 30 - Examining Room 4 | | 31 - Rest Room 32 - Special Treatment Room | | 33 - Store Room 34 - Elevator | | 35 - Elevator Control Room 36 - Elevator | | 37 - Bath 2 38 - Examining Room 3 | | 39 - Rest Room 40 - Women 's Locker Room | | 41 - Nurse 's Station 42 - Men's Locker Room | | 43 - Linen Room 44 - Elevator | | | | ITEMS | | | | A - Map of Hospital B - Health Drink | | C -
#
# -----
#
# Kit | | Q - Roof Key R - Health Drink | | S - Piece of Hair T - Elevator Key | | U - Handgun Bullets V - Shotgun Shells | | $ - Save Point | | | | NIGHTMARE HOSPITAL ITEMS | | | | AA - Shotgun Shells BB - First - Aid Kit | | CC - Handgun Bullets DD - Health Drink | | EE - Handgun Bullets FF - Health Drink | | GG - Dry Cell Battery HH - Basement Storeroom
#
# -----
#
# Key | | II - Ampoule JJ - Handgun Bullets | | KK - Handgun Bullets LL - First - Aid Kit | | MM - Shotgun Shells NN - Shotgun Shells | | ?? - Copper Ring OO - Lead Ring | | PP - Hospital Lobby Key %
#
# -----
#
# o----------------------------------------------------------------------------o | _________________________________ | | | | | | ___________________ | 1 F | | |____| | | | | | | | | | | | | || | | | | |____||_|_|_|_|_|_|_|_|_|_|| | | |____| | | | | | | K | | | | | | ||____________________________________ | | | | | ||_|_|_|_|_|_|_|_|_|_|| | | | |____| |____|E___________________ | | | | | RSTU | | N M || || | | | |____| |____||_______ || | | | | | |____|| _____| || | | | | O | | | | | | | | | | | | | | QP | |____|| |_|_| | _____|| | | | |__ | | $ || | | | | | | | | | | | |__|_| |____|| | | | F | |_ | | | | | | |____ | || |_|_|_| | | || L | | | | | |____|| | | | | |_ | | | | | | | | | | | | | | | | | J | | | | | | |_| || |_|_|_| |___|_ || | | | | |_| | | | | | | | | | | | | |_| || |_|_|_| || | | | _|____|_|____||_______| || | | | | || I | | | | | ||___________________|| | | | |_____________|D___________________ | | | | | | | | | | | G | | | | H | ||____________________________________| | | | $ ||_|_|_|_|_|_|_|_|_|_|| | | | C || | | | | | | | | | || | | | B A ||_|_|_|_|_|_|_|_|_|_|| | | |_____________|_____________________| | | | | B1 F | | ____________ | | | || | | | |_____||_____| | | | | | | | | |_____||_____| TOLUCA PRISON | | |__| | | |__| | o----------------------------------------------------------------------------o
#
# -----
#
# -------------------------------------------------------------------o | | | ITEMS | | | | A - Health Drink B - Health Drink | | C - Gluttonous Pig D - Handgun Bullets | | E - Map of Prison F - The Seductress | | G - Handgun Bullets H - Wax Doll | | I - Handgun Bullets J -
#
# -----
#
# o----------------------------------------------------------------------------o | | | LABYRINTH | | _____ | | | | || | | |_ _| _______|| | | | $ | | ______ | | | |_____| || || _____ ______ | | ||_____________|| || | | | | | | | ______ _____ | | |__| |__ | | | | | | | | | __ | || | | | || ||_____||_______ | | | D |-- | | || |______|_______ | |_____| |______| | | || | | | | | | | | | | | | || | | || | |__ | | | | | | | | _|__ | | | ____||___|| | | | | | | | | _________| __||__ | | | | | | | | | | | | | | | | | | |____|| | | | | | | | ____| | | | | | | | | | ___ |______| || | | | |__ | _______________|| H | | | || || |_$______________|____| | | || | | | | | | ||______|| |_____| | | |_______ | | | ||___ | | | | _ _| | | || | | | | | ||______||| | | |_________| | | ___ ______________ | | | FG_| |_E____________| | | | o----------------------------------------------------------------------------o
#
# -----
#
# o----------------------------------------------------------------------------o | | | __________ LABYRINTH | | / _________ \ _______________ | | / / || \ \ | | | | | | | | | M | | | | | _____ | | | J | | | | |__| ABC | | | | $ | | | | __ | | | | | | | | | |_____| | | | | | | | | | | | L K | | | | | | | |_______ ______| | | \ \____||___/ / || | | \___________/ _____ || | | ________ __| | | | | | | | _______| | ||| | | ||___ | | || ___|| --|_|___| |_ I_ | | | || |____| || | | ||______________ || | | |
#
# -----
#
# o----------------------------------------------------------------------------o | | | LAKEVIEW HOTEL B1 F | | | | | | | | | | | | | | | | | | | | | | | | | | | | _________________ | | |_______________ | _ _________ | | | 1 | 2 |_____| | | ||||||||||| | | | | |_____| | | ||||||||||| | | |____|____|_____| | | |_________| | | | | ____| | 8 | | | | |__________|6|7 | | | | | _|____________|+|_|
#
# -----
#
# _________|________________________| | | | || 13 |14 | | | |15 |16 | | | | || | | | | | | | | | | | | 110 | | | | | | | | Restaurant | | | | | | | | | | | | | | " Lake Shore " | | | | | |__________||____||____| | | | | |_____| | | | || | | | | | | | |17 | | | | || | | |___| | | B | | | | | | 111 || CD || | Cafe | | | | | | | | || EF || | " Toluca " | A | | | | | | |__________||____||____|___________|_|_________________|__________|_____| | | | o----------------------------------------------------------------------------o
#
# -----
#
# ____________________________ _________| | | | | |38 ||40 | | 41 || 43 | | | | | | || GH | | | | | | | | | | || IJ | | | | | | | | | |_______|| KL | |____||_ | | | | | 210 |39 ||_____| Hall | 42 | | 211 | | | | | || | | |_| | | | | | O || | |____ | | | | | | || | | | | | | | | | Q P | M | | | | | | | |___________|_______|N_____|_________________|____|____|________________| | | | o----------------------------------------------------------------------------o
#
# -----
#
# 4 - Kitchen | | 5 - Electrical Room 6 - Elevator | | 7 - Elevator 8 - Store Room | | 9 - Pump Room 10 - Boiler Room | | 11 - Women 's Washroom 12 - Men's Washroom | | 13 - Store room 14 - Kitchen | | 15 - Kitchen 16 - Employee Cafeteria | | 17 - Dishroom 18 - Elevator | | 19 - Refrigerator Room 20 - Freezer Room | | 21 - Pantry 22 - Elevator | | 23 - Gift Shop 24 - Reception | | 25 - Office 26 - Telephone Operator 's Room | | 27 - Employee Lounge 28 - Manager 's Residence | | 29 - Men's Locker Room 30 - Women 's Locker Room | | 31 - Security Office 32 - Laundry Room | | 33 - Manager 's Office 34 - Women 's Washroom | | 35 - Men's Washroom 36 - Women 's Washroom | | 37 - Men's Washroom 38 - Lounge | | 39 - Reading Room 40 - Cloak Room | | 41 - Hall Anteroom 42 - Service Room | | 43 - Store Room 44 - Elevator | | 45 - Elevator 46 - Women 's Washroom | | 47 - Men's Washroom 48 - Observation Room | | 49 - Elevator 50 - Elevator | | | | ITEMS | | | | A - Hotel Map ( Guests ) B -
#
# -----
#
# Shotgun Shells | | I - Shotgun Shells J - Handgun Bullets | | K - Handgun Bullets L - Key to Room 204 | | M - Handgun Bullets N - Handgun Bullets | | O - Shotgun Shells P - Shotgun Shells | | Q - Health Drink R - Employee Elevator Key | | S -
#
# -----
#
# Rifle Shells V - Health Drink | | W - Health Drink X - Hotel Map ( Employees ) | | Y - Videotape Z - Can Opener | | ! - Rifle Shells @ - Rifle Shells | | # - Snow White % - Bar Key | | ^ - First - Aid Kit & - Health Drink | | * - Health Drink ( - Health Drink | | ) - Lightbulb = - Hotel Stairway Key | | + - Thinner $ - Save Point | | | o----------------------------------------------------------------------------o

# %%
get_sentences_of_length_alpha_required(CV_PAPER_DIR, 2, 5)
# Out:
# -----
#
# First - order correlation
#
# -----
#
# Second - order correlation
#
# -----
#
# t t t I
#
# -----
#
# t t t
#
# -----
#
# Common input loop
#
# -----
#
# f f dxl
#
# -----
#
# f f d XI
#
# -----
#
# Training Data Required
#
# -----
#
# Estimating the Entropy
#
# -----
#
# We generate many
#
# -----
#
# squares sense is
#
# -----
#
# 0 Pi xe Is
#
# -----
#
# REFERENCES AND NOTES
#
# -----
#
# METHODS / PRELIMINARY RESULTS
#
# -----
#
# THE NEUROCOMPUTING MODEL
#
# -----
#
# r I I
#
# -----
#
# Central Nervous System
#
# -----
#
# Central Nervous System
#
# -----
#
# PORTABLE PARALLEL NEUROCOMpuTER
#
# -----
#
# EXTERNAL USER CONTROLLED PARAMETERS
#
# -----
#
# EXTERNALLY CONTROLLED AMPUFICATION
#
# -----
#
# OF N SIGNALS
#
# -----
#
# I --~ RESET SCANNING
#
# -----
#
# I j max
#
# -----
#
# OUTPUT SIGNAL In
#
# -----
#
# USER CONTROLLED PARAMETERS
#
# -----
#
# SINGLE NEURON PROCESSING
#
# -----
#
# where the mean field
#
# -----
#
# Afferent Signals d
#
# -----
#
# I - L J
#
# -----
#
# Why is this ?
#
# -----
#
# Sum of Products
#
# -----
#
# Input lines Feature 4
#
# -----
#
# Feedback connections may be
#
# -----
#
# Adaptive Connection Matrix
#
# -----
#
# Output through external amplifiers
#
# -----
#
# Features stored in
#
# -----
#
# ring shift register
#
# -----
#
# Best match list pipeline
#
# -----
#
# 1 A recurrent network
#
# -----
#
# L L w'fi i
#
# -----
#
# The General Network
#
# -----
#
# Since the condition
#
# -----
#
# Thus , the matrix
#
# -----
#
# three output neurons .
#
# -----
#
# z z z z
#
# -----
#
# z z z
#
# -----
#
# We can write
#
# -----
#
# component is given by
#
# -----
#
# We get similarly
#
# -----
#
# Be a By ;'
#
# -----
#
# MATERIALS AND METI- IODS
#
# -----
#
# Ralph Linsker IBM
#
# -----
#
# s Maximum Information Preservation
#
# -----
#
# A Simple Geometric Model
#
# -----
#
# UNORIENTED RECEPTIVE FIELDS
#
# -----
#
# Constrained Differential Optimization
#
# -----
#
# The Penalty Method
#
# -----
#
# which yields differential equations
#
# -----
#
# Why the algorithm works
#
# -----
#
# path of algorithm
#
# -----
#
# subject to constraints
#
# -----
#
# THE CONCENTRATOR ASSIGNMENT PROBLEM
#
# -----
#
# Site / concentrator map
#
# -----
#
# THE NEURAL NETWORK SOLUTION
#
# -----
#
# THE ENERGY FUNCTION
#
# -----
#
# OPTICAL ASSOCIATIVE LOOP
#
# -----
#
# LCL V TV
#
# -----
#
# To lowest order in
#
# -----
#
# denotes the weight associated
#
# -----
#
# Thus assume the
#
# -----
#
# What we mean by
#
# -----
#
# Thus if I is
#
# -----
#
# In this paper .
#
# -----
#
# THE KANERVA ASSOCIATIVE MEMORY
#
# -----
#
# Define the quantity
#
# -----
#
# Y be given .
#
# -----
#
# Recursi ve Type
#
# -----
#
# Number of samples
#
# -----
#
# NUAlber of sampl es
#
# -----
#
# OBSTACLE AVOIDING MOVEMENT
#
# -----
#
# Stationary uni t
#
# -----
#
# Course suggest io n
#
# -----
#
# WiZ ... wi Lf
#
# -----
#
# defined corresponding functions
#
# -----
#
# with associated E function
#
# -----
#
# PERSPECTIVES OF RECENT WORK
#
# -----
#
# In the following .
#
# -----
#
# We note that
#
# -----
#
# S is symmetric .
#
# -----
#
# Vy gives network equations
#
# -----
#
# Operator D was D
#
# -----
#
# ~ all bits b
#
# -----
#
# relative path initial
#
# -----
#
# Computational significant benefit .
#
# -----
#
# To understand this .
#
# -----
#
# In this study .
#
# -----
#
# d ET dt
#
# -----
#
# FROM NEURON OUTPUTS
#
# -----
#
# TO NEURON INPUTS
#
# -----
#
# Since the current normally
#
# -----
#
# THIN FILM RESISTOR CONNECTIONS

# %%
get_sentences_of_length_alpha_required(GAME_DIR, 0, 10)
# Out:
# -----
#
# | ITEM CHECKLIST | None ...........................................N/A | |_______________________|____________________________________________________|
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# This is where the game begins .
#
# -----
#
# From here there is no turning back .
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# With that he gets ready to go .
#
# -----
#
# The alley where you chased
#
# -----
#
# There are a couple things you should know .
#
# -----
#
# Head back through the gate and go north .
#
# -----
#
# The door is open so go inside .
#
# -----
#
# The Steel Pipe is a new melee weapon .
#
# -----
#
# Turn around and head back north .
#
# -----
#
# Head back up to Matheson and continue west .
#
# -----
#
# That saves a little time .
#
# -----
#
# Harry automatically turns on his flashlight .
#
# -----
#
# Examine the bloody notes behind the counter here .
#
# -----
#
# This is the infirmary .
#
# -----
#
# Save and leave here .
#
# -----
#
# Babies to be found in this hallway .
#
# -----
#
# Turn around and return to the previous room .
#
# -----
#
# Check out the room marked Lab Equipment Room .
#
# -----
#
# Grab the FIRST AID KIT off the table .
#
# -----
#
# Go into the Locker Room first .
#
# -----
#
# Find the noisy locker and examine it .
#
# -----
#
# From here head north to the courtyard .
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# Be careful of Demon Babies when you do .
#
# -----
#
# Head east and go up into the hall .
#
# -----
#
# Proceed through the western double doors .
#
# -----
#
# Start by checking out the evil Infirmary .
#
# -----
#
# Now this is where things get weird .
#
# -----
#
# Pick up the Shotgun and leave the washroom .
#
# -----
#
# Suddenly it says " 2F . "
#
# -----
#
# Demon Babies and Cockroaches populate this room .
#
# -----
#
# As you do ...
#
# -----
#
# Proceed through the double doors leading east here .
#
# -----
#
# Proceed through the double doors leading east .
#
# -----
#
# Go over and find the drainage valve .
#
# -----
#
# Choose to turn it on when Harry asks .
#
# -----
#
# Open it up by using your Classroom Key .
#
# -----
#
# There is your solution .
#
# -----
#
# The boss awaits .
#
# -----
#
# || || Fortunately there 's an easy solution .
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# When you reach it do n't go inside .
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# Save your game and exit the church .
#
# -----
#
# The control tower is on the south side .
#
# -----
#
# Our next destination is quite a distance away .
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# Michael wishes him good luck and exits .
#
# -----
#
# Leave this small room to reach a hallway .
#
# -----
#
# Make sure you do n't miss it .
#
# -----
#
# Press that button to ride up .
#
# -----
#
# Watch out for more Nurses !
#
# -----
#
# Your first destination here is Room 201 .
#
# -----
#
# Approach the monster and open your inventory .
#
# -----
#
# They fight in pretty much the same way .
#
# -----
#
# Proceed through the door to the basement .
#
# -----
#
# From here go into the Nurse Center .
#
# -----
#
# It 's time to solve this damn puzzle .
#
# -----
#
# Proceed down into the sub-basement .
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# Now he unlocks this door and walks inside .
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# Rinse and repeat until it 's dead .
#
# -----
#
# Your next destination ?
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# | ITEM CHECKLIST | None ...........................................N/A | |_______________________|____________________________________________________|
#
# -----
#
# Examine the blood to get SEWER EXIT KEY .
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# Before Kaufman leaves
#
# -----
#
# Inside is the KAUFMAN KEY and the RECEIPT .
#
# -----
#
# There 's also a Notepad there as well .
#
# -----
#
# That 's going to be your next destination .
#
# -----
#
# This number opens up the lock for you .
#
# -----
#
# Use the safe key to unlock the safe .
#
# -----
#
# Inside you 'll find drugs .
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# His daughter Cheryl is more important .
#
# -----
#
# Thus the Michael Kaufmann sidequest has been completed .
#
# -----
#
# Time to move onward .
#
# -----
#
# Proceed through the door for a scene .
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# Harry must go there now .
#
# -----
#
# Head north again toward Sanford Street .
#
# -----
#
# At the third fork in the road .
#
# -----
#
# | ITEM CHECKLIST | None ...........................................N/A | |_______________________|____________________________________________________|
#
# -----
#
# The parasite will crawl out of her ...
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# Harry intends to save her no matter what .
#
# -----
#
# Alessa stands before Harry .
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# A very odd and creepy place all around .
#
# -----
#
# Leave this room and continue down the hall .
#
# -----
#
# On your right is a new puzzle .
#
# -----
#
# 18 is Albert , so A .
#
# -----
#
# Through the door is an empty storage room .
#
# -----
#
# THE STORY SO FAR : Lisa tells
#
# -----
#
# It ends with " Need drug . "
#
# -----
#
# Doing so will release the STONE OF TIME .
#
# -----
#
# The camera will reveal three shapes .
#
# -----
#
# Examine the generator and cut the power .
#
# -----
#
# What does this do you might ask ?
#
# -----
#
# Remember the electrified key ?
#
# -----
#
# THE STORY SO FAR :
#
# -----
#
# The people and images fade away ....
#
# -----
#
# Following these you fight the final boss .
#
# -----
#
# Here 's how it works :
#
# -----
#
# Congratulations , you have completed the game .
#
# -----
#
# Enjoy your ending !
#
# -----
#
# || || Fortunately there 's an easy solution .
#
# -----
#
# Rinse and repeat until it 's dead .
#
# -----
#
# The parasite will crawl out of her ...
#
# -----
#
# Here 's how it works :
#
# -----
#
# East end of Finney
#
# -----
#
# East end of Finney
#
# -----
#
# On the path || | _ | | |
#
# -----
#
# Must wash it down from roof . |
#
# -----
#
# ( | o| Bullets for the Handgun .
#
# -----
#
# It can be turned off . |
#
# -----
#
# Found all over the place . |
#
# -----
#
# Written by Childof Valhalla / TheSnake
#
# -----
#
# the_bloodredsky ( at ) yahoo ( dot ) com
#
# -----
#
# With notes and additional writing by Wandering One
#
# -----
#
# THIS IS A PLOT ANALYSIS .
#
# -----
#
# IT CONTAINS SPOILERS .
#
# -----
#
# This is NOT the FINAL version .
#
# -----
#
# I will continue to update it as needed .
#
# -----
#
# THIS IS WHAT I THINK .
#
# -----
#
# TABLE OF CONTENTS
#
# -----
#
# Travis ' Mental State / Overview
#
# -----
#
# The symptoms of C - PTSD include :
#
# -----
#
# ++++++++++++++++ 2 . ) TRAVIS AS THE BUTCHER ++++++++++++++++
#
# -----
#
# Both possibilities hold very plausible arguments .
#
# -----
#
# 2.1 ) PYRAMID HEAD / THE BUTCHER ===
#
# -----
#
# Well , they were right .
#
# -----
#
# Silent Hill Origins follows this formula entirely .
#
# -----
#
# Another interesting thing to note is their headwear :
#
# -----
#
# " Repression and Coercion " states the following :
#
# -----
#
# 2.3 ) TRAVIS GRADY : SERIAL KILLER ===
#
# -----
#
# About the photos found in the motel :
#
# -----
#
# Also consider the photo of his father .
#
# -----
#
# Alex perhaps believe he is responsible ?
#
# -----
#
# 2.4 ) TRAVIS GRADY : INNOCENT MAN ===
#
# -----
#
# -- 2.41 ) WOMEN AND MIRRORS --
#
# -----
#
# " Since what happened to Tony .
#
# -----
#
# I 've dreamt about HIM more and more !
#
# -----
#
# He 's at my motel !
#
# -----
#
# It 's HIM I swear it ! "
#
# -----
#
# a ) real time explanation :
#
# -----
#
# b ) flashback explanation :
#
# -----
#
# -- 2.44 ) THE FIRST ENDING --
#
# -----
#
# ++++++++++++++++ 3 . ) TRAVEL THROUGH SILENT HILL ++++++++++++++++
#
# -----
#
# Note that I said " possibly . "
#
# -----
#
# Because Travis wants them to be there .
#
# -----
#
# Why does he hate them ?
#
# -----
#
# Why is it so demonic ?
#
# -----
#
# 5.09 ) Memory of Helen Grady ===
#
# -----
#
# This was obviously traumatizing for the young Travis .
#
# -----
#
# Is not concrete .
#
# -----
#
# Well , not yet ...
#
# -----
#
# I will always reply .
#
# -----
#
# I 'm on it .
#
# -----
#
# It 's been a while !
#
# -----
#
# Added a new host .
#
# -----
#
# Let 's make this thing awesome !
#
# -----
#
# Added more theories and support !
#
# -----
#
# I 'd like to thank :
#
# -----
#
# Keep 'em coming guys !
#
# -----
#
# For reading it .
#
# -----
#
# =+= End of Document .=+=
#
# -----
#
# SILENT HILL 4 : THE ROOM MEMO ANALYSIS
#
# -----
#
# Copyright 2007 by Sean " Mephianse " Dickinson
#
# -----
#
# WARNING WARNING WARNING :
#
# -----
#
# There are spoilers past this point .
#
# -----
#
# You have been warned .
#
# -----
#
# -- TABLE OF CONTENTS --
#
# -----
#
# A few notes on the red diaries .
#
# -----
#
# When you 're done / Mini -
#
# -----
#
# Cleaned up and spellchecked , submitted .
#
# -----
#
# ( Thanks GameFAQs boilerplate ! )
#
# -----
#
# AOL Instant Messenger : Mephianse .
#
# -----
#
# Go on , hurry up .
#
# -----
#
# This is not a plot guide .
#
# -----
#
# [ 15 ] Mike 's Diary : July 2
#
# -----
#
# [ 17 ] Mike 's Love Letter
#
# -----
#
# They will haunt that realm as a spirit .
#
# -----
#
# How can our Lord forgive such an abomination ...?
#
# -----
#
# But it seems
#
# -----
#
# Distinctly Christian stuff here .
#
# -----
#
# The lake is northwest .
#
# -----
#
# So the opposite is southeast . '
#
# -----
#
# [ 4 ] -- HOLY SCRIPTURE SCRAP --
#
# -----
#
# I finally escaped from the cell .
#
# -----
#
# The scariest place was the 1st floor basement .
#
# -----
#
# Who could forget something that harrowing ?
#
# -----
#
# [ 7 ] -- WATERWHEEL ROOM PLATE MESSAGE --
#
# -----
#
# This memo is a puzzle clue .
#
# -----
#
# " We had beef stew yesterday .
#
# -----
#
# That really scared me . "
#
# -----
#
# That 's a big thing to hold back .
#
# -----
#
# [ 9 ] -- 1F SURVEILLANCE ROOM REPORT --
#
# -----
#
# " This place continues to deteriorate .
#
# -----
#
# There are three rooms with bloody beds .
#
# -----
#
# [ 10 ] -- 2F SURVEILLANCE ROOM REPORT --
#
# -----
#
# There 's a hydroelectric generator in the basement .
#
# -----
#
# Give it a try .
#
# -----
#
# Much appreciated , Chief ! "
#
# -----
#
# [ 11 ] -- SECRET NUMBER MEMO --
#
# -----
#
# Thanks for your cooperation . "
#
# -----
#
# Anybody could see it from South Ashfield Street .
#
# -----
#
# Is that really okay ? "
#
# -----
#
# This memo is a puzzle clue .
#
# -----
#
# You 'd look worn - out too .
#
# -----
#
# Walter 's influence is far - reaching indeed .
#
# -----
#
# " Oh my beautiful Rachael ,
#
# -----
#
# But I guess maybe it was somewhere else ...
#
# -----
#
# He took it along with my clothes .
#
# -----
#
# Those were my best clothes . "
#
# -----
#
# Mike 's obviously obsessed with Rachel .
#
# -----
#
# No dice , stalker .
#
# -----
#
# Rachel is n't too find of Mike .
#
# -----
#
# " He took it along with my clothes .
#
# -----
#
# Those were my best clothes . "
#
# -----
#
# " He " is Richard Braintree .
#
# -----
#
# Still , that 's not cool , Richard .
#
# -----
#
# " The red box seems even stranger today .
#
# -----
#
# It 's giving off a terrible smell .
#
# -----
#
# It must have been around 30 years ago .
#
# -----
#
# Ran off just like thieves in the night .
#
# -----
#
# I do n't know why .
#
# -----
#
# The problem came after that .
#
# -----
#
# I even found the umbilical cord .
#
# -----
#
# One day he just stopped coming by .
#
# -----
#
# It 's a horrible story .
#
# -----
#
# Abandoning a newborn baby ...
#
# -----
#
# That all happened in Room 302 ...
#
# -----
#
# And the umbilical cord I found there ...
#
# -----
#
# It 's giving off a terrible smell .
#
# -----
#
# It 's no wonder the box seems strange .
#
# -----
#
# - " I do n't know why .
#
# -----
#
# - " The problem came after that .
#
# -----
#
# I even found the umbilical cord . "
#
# -----
#
# Seems pretty gruesome , does n't it ?
#
# -----
#
# No wonder Walter 's messed up .
#
# -----
#
# One day he just stopped coming by . "
#
# -----
#
# Gee , you think ?
#
# -----
#
# You 're a swift one , Frank .
#
# -----
#
# - " It 's a horrible story .
#
# -----
#
# Abandoning a newborn baby ...
#
# -----
#
# That all happened in Room 302 ...
#
# -----
#
# And the umbilical cord I found there ...
#
# -----
#
# His love is unrequited .
#
# -----
#
# Probably because he 's a freakin ' stalker .
#
# -----
#
# I really hope not ... "
#
# -----
#
# It 's inside my toy train . "
#
# -----
#
# Henry out of some misguided benevolence ?
#
# -----
#
# " Something 's here but nothing 's here .
#
# -----
#
# I feel something from the well .
#
# -----
#
# It has begun !!!
#
# -----
#
# The actual physical world , perhaps ?
#
# -----
#
# A sense of reason and coherence ?
#
# -----
#
# The ability to leave of your own will ?
#
# -----
#
# It has begun !!! "
#
# -----
#
# But he probably is n't .
#
# -----
#
# [ 21 ] -- WHEELCHAIR DOLL TEXT --
#
# -----
#
# To prepare for the Receiver of Wisdom ...
#
# -----
#
# The ritual has begun ... "
#
# -----
#
# That 'd be you , Henry .
#
# -----
#
# Dig out those ears and listen up !
#
# -----
#
# The ritual has begun ... "
#
# -----
#
# We 're nearing the climax .
#
# -----
#
# Prepare for the Ritual of the Holy Assumption .
#
# -----
#
# - " Time of Fullness . "
#
# -----
#
# Probably to the cult 's god .
#
# -----
#
# Abandon your physical body .
#
# -----
#
# Two more murder themes , Source and Temptation .
#
# -----
#
# He pops up wherever he feels like .
#
# -----
#
# He ca n't be killed .
#
# -----
#
# He is alone .
#
# -----
#
# The cult 's ultimate goal :
#
# -----
#
# Revive their god .
#
# -----
#
# DeSalvo 's a sick puppy , alright .
#
# -----
#
# Again , he 's talking about DeSalvo .
#
# -----
#
# Things were so good then ...
#
# -----
#
# The day of my birthday ...
#
# -----
#
# The cute cat in the pet store ...
#
# -----
#
# All those balls in the basket ...
#
# -----
#
# Playing pool was fun too ...
#
# -----
#
# The door of time was wide open ...
#
# -----
#
# Nostalgia aside , it 's a puzzle clue .
#
# -----
#
# [ 25 ] -- LATER BARTENDE R'S MEMO --
#
# -----
#
# What a pain .
#
# -----
#
# Not too smart if you ask me ... "
#
# -----
#
# " I had that weird dream today .
#
# -----
#
# I never saw him again after that .
#
# -----
#
# But that 's when it all started .
#
# -----
#
# So why could Walter be crying ?
#
# -----
#
# That 's a point of contention .
#
# -----
#
# This is just a memo analysis .
#
# -----
#
# Do n't feel too bad , Frank .
#
# -----
#
# No one did .
#
# -----
#
# It obviously does that from time to time .
#
# -----
#
# There are a few interesting points , though .
#
# -----
#
# But where does it come from ?
#
# -----
#
# It would make sense , would n't it ?
#
# -----
#
# The " grace of our Lord ? "
#
# -----
#
# It 's a head job , alright .
#
# -----
#
# [ 28 ] -- OLD PICTURE BOOK --
#
# -----
#
# The baby was left all alone .
#
# -----
#
# The baby was happy .
#
# -----
#
# But the mother would n't wake up .
#
# -----
#
# The baby has been deceived .
#
# -----
#
# The baby cried and cried and cried .
#
# -----
#
# The baby was left all alone . "
#
# -----
#
# The baby has been deceived . "
#
# -----
#
# Ah ha , now THIS is interesting .
#
# -----
#
# Ding ding ding !
#
# -----
#
# Some " friends " they are .
#
# -----
#
# The baby cried and cried and cried . "
#
# -----
#
# A few notes on the red diaries .
#
# -----
#
# His name was ... Walter Sullivan . "
#
# -----
#
# I 'm investigating two people .
#
# -----
#
# Or maybe I should say just one .
#
# -----
#
# Joseph contradicts himself .
#
# -----
#
# - " I 'm investigating two people .
#
# -----
#
# Or maybe I should say just one .
#
# -----
#
# In other words , 1 out of 21 .
#
# -----
#
# So Walter was planning to kill 21 people ...?
#
# -----
#
# But he never finished the job .
#
# -----
#
# There are two big puzzles here .
#
# -----
#
# Was he simply insane ...? "
#
# -----
#
# Though it could just be a simple oversight .
#
# -----
#
# The rest of this note explains itself .
#
# -----
#
# But something about it bothered me ... "
#
# -----
#
# Personally , I like the first theory .
#
# -----
#
# This memo is a puzzle clue .
#
# -----
#
# [ 34 ] -- RED DIARY SCRAP --
#
# -----
#
# Let me think ...
#
# -----
#
# The last place I saw it was ...
#
# -----
#
# This memo is a puzzle clue .
#
# -----
#
# I get headaches every day now .
#
# -----
#
# What am I going to do ? "
#
# -----
#
# " I get headaches every day now .
#
# -----
#
# What am I going to do ? "
#
# -----
#
# " Walter Sullivan did kill himself .
#
# -----
#
# The corpse was from 6 months earlier .
#
# -----
#
# Except for one thing .
#
# -----
#
# This corpse also had their heart intact .
#
# -----
#
# The police still have n't identified a suspect .
#
# -----
#
# I 've got a working hypothesis .
#
# -----
#
# First I 'll head to Silent Hill .
#
# -----
#
# To the graveyard near that beautiful little lake .
#
# -----
#
# Maybe I 'll find the answer there . "
#
# -----
#
# - " Walter Sullivan did kill himself .
#
# -----
#
# Oh God , PROBLEMS PROBLEMS PROBLEMS .
#
# -----
#
# Here you go .
#
# -----
#
# " The weather that day was very strange .
#
# -----
#
# But I was wrong .
#
# -----
#
# I should have come sooner .
#
# -----
#
# The storm must have raised the sea level .
#
# -----
#
# I 'm still in shock ...
#
# -----
#
# There was no body in the grave ...
#
# -----
#
# But to what end ?
#
# -----
#
# - " I 'm still in shock ...
#
# -----
#
# There was no body in the grave ...
#
# -----
#
# Obviously , Walter was his own 11th victim .
#
# -----
#
# He 's truly insane .
#
# -----
#
# I ca n't hold on any longer .
#
# -----
#
# His power ca n't be measured .
#
# -----
# I wonder if Eileen Galvin is okay .
#
# -----
#
# She has no idea what 's going on ...
#
# -----
#
# But she 's in danger nevertheless . "
#
# -----
#
# Maybe he had some cement handy ?
#
# -----
#
# She has no idea what 's going on ...
#
# -----
#
# But she 's in danger nevertheless . "
#
# -----
#
# You 're on your own on this one .
#
# -----
#
# " You 've seen that world as well ...
#
# -----
#
# That horrible nightmare .
#
# -----
#
# Do n't get lost in there .
#
# -----
#
# But there 's still hope .
#
# -----
#
# Then keep going down .
#
# -----
#
# To the deepest part of him .
#
# -----
#
# And look for the ultimate Truth . "
#
# -----
#
# That horrible nightmare . "
#
# -----
#
# Do n't get lost in there .
#
# -----
#
# He just wanted to let you know .
#
# -----
#
# Remember those doors you saw in each world ?
#
# -----
#
# - " Then keep going down .
#
# -----
#
# To the deepest part of him .
#
# -----
#
# And look for the ultimate Truth . "
#
# -----
#
# How innocent is Joseph , really ?
#
# -----
#
# It saved my life .
#
# -----
#
# Strike when the sword is energized !
#
# -----
#
# It 's extremely valuable . "
#
# -----
#
# I 'm starting to gain some hope . "
#
# -----
#
# Again , this one explains itself .
#
# -----
#
# Holy Candles and Saint Medallions are good !
#
# -----
#
# My headache is already killing me .
#
# -----
#
# I 'll write more tomorrow . "
#
# -----
#
# What a nutcase .
#
# -----
#
# " What 's with this room ?
#
# -----
#
# It 's covered in blood and rust ...
#
# -----
#
# This is my room ...
#
# -----
#
# But what the hell has happened to it ...?
#
# -----
#
# Is it really my room ...?
#
# -----
#
# It 's in terrible shape ...
#
# -----
#
# The air is so heavy ...
#
# -----
#
# My head hurts ...
#
# -----
#
# It looks like a face .
#
# -----
#
# What the hell am I writing ...? "
#
# -----
#
# Eileen is victim 20 , the Mother Reborn .
#
# -----
#
# [ 49 ] -- RED DIARY - AUGUST 5
#
# -----
#
# Ten hearts Steve Garl ... No. 5 ...
#
# -----
#
# Ten hearts Billy Locane No. 8 ...
#
# -----
#
# Ten hearts Miriam Locane No. 9 ...
#
# -----
#
# Joseph is leaving things out , obviously .
#
# -----
#
# Here 's what it should really look like .
#
# -----
#
# Ten hearts Jimmy Stone No. 2 ...
#
# -----
#
# Ten hearts Bobby Randolph No. 3 ...
#
# -----
#
# Ten hearts Sein Martin No. 4 ...
#
# -----
#
# Ten hearts Steve Garland No. 5 ...
#
# -----
#
# Ten hearts Rick Albert No. 6 ...
#
# -----
#
# Ten hearts George Rosten No. 7 ...
#
# -----
#
# Ten hearts Billy Locane No. 8 ...
#
# -----
#
# Ten hearts Miriam Locane No. 9 ...
#
# -----
#
# Ten hearts William Gregory No. 10 ...
#
# -----
#
# Void Peter Walls No. 13 ...
#
# -----
#
# Darkness Sharon Blake No. 14 ...
#
# -----
#
# Gloom Tony Archbolt No. 15 ...
#
# -----
#
# I 've been having hallucinations lately .
#
# -----
#
# I think I 'm losing my mind . "
#
# -----
#
# Joseph obviously knows he 's next .
#
# -----
#
# Man , that has GOTTA suck .
#
# -----
#
# - " I 've been having hallucinations lately .
#
# -----
#
# I think I 'm losing my mind . "
#
# -----
#
# You can hardly blame the poor guy .
#
# -----
#
# My eyes are starting to go blind ...
#
# -----
#
# I can feel my body starting to die ...
#
# -----
#
# But ... things are taken care of ...
#
# -----
#
# Whoever lives here after me ...
#
# -----
#
# I leave it up to you ...
#
# -----
#
# When the bell tolls , the ritual begins .
#
# -----
#
# Eileen = mother 's body , blood .
#
# -----
#
# " Teaching Despair : ' Wish House
#
# -----
#
# Good on you ,
#
# -----
#
# Joseph , you find the truth !
#
# -----
#
# When you 're done / Mini -
#
# -----
#
# You may be feeling a few things .
#
# -----
#
# Being a jerk wo n't get you anywhere .
#
# -----
#
# Please please PLEASE let me know about it .
#
# -----
#
# " Can you back this crap up ? "
#
# -----
#
# To my mom , for being my mom .
#
# -----
#
# Keep it up .
#
# -----
#
# You have no idea how helpful that was .
#
# -----
#
# Sean " Mephianse " Dickinson
#
# -----
#
# Silent Hill : Shattered Memories
#
# -----
#
# Genre : Psychological Horror ESRB Rating : Mature
#
# -----
#
# + Table of Contents +
#
# -----
#
# 5 . Midwich High School [ III .5 ]
#
# -----
#
# 6 . Nightmare - School [ III .6 ]
#
# -----
#
# IV - Therapy Sessions
#
# -----
#
# VIV - Echo Messages .
#
# -----
#
# After being very unsatisfied with Silent Hill :
#
# -----
#
# Silent Hill : Origins was rather disastrous .
#
# -----
#
# Origins as well as the series ' future .
#
# -----
#
# Controls ( nunchuk required )
#
# -----
#
# Analog Down & Z : Quick Turn
#
# -----
#
# --- " Fighting " - Nightmare Tips
#
# -----
#
# Throughout the game there is no combat .
#
# -----
#
# Outside , they 're in the distance .
#
# -----
#
# Hiding is never useful .
#
# -----
#
# Turning your flashlight off can help sometimes .
#
# -----
#
# --- Personality Inventory ( PI )
#
# -----
#
# Only influences the ending
#
# -----
#
# ( See the endings for more info ) .
#
# -----
#
# Therapy - The Test -+o
#
# -----
#
# The profiling influences various aspects of the game .
#
# -----
#
# Just choose whatever you like .
#
# -----
#
# Question Primary Influence
#
# -----
#
# I prefer abstract ideas Fake PI
#
# -----
#
# I have never cheated on a Sexual PI partner
#
# -----
#
# There 's a binder on the ground here .
#
# -----
#
# Very straight forward .
#
# -----
#
# Follow the door to a shop .
#
# -----
#
# Go through the employee door .
#
# -----
#
# Turn left and head down the street .
#
# -----
#
# There 's nothing significant on the street .
#
# -----
#
# Clear Picture - TV Shop
#
# -----
#
# Go down the steps and through the door .
#
# -----
#
# Go through the " Staff Only " door .
#
# -----
#
# Go through the door ahead of you .
#
# -----
#
# 2 . Theresa 's - Dress Store
#
# -----
#
# Go through the door behind the counter .
#
# -----
#
# Head out that door and through the alley .
#
# -----
#
# Significant Objects : Sexual PI ***
#
# -----
#
# Climb the wooden fence .
#
# -----
#
# Interact with the cans .
#
# -----
#
# Just rotate the wiimote to turn it over .
#
# -----
#
# Grab the key and head for the door .
#
# -----
#
# Which one you choose may be restricted .
#
# -----
#
# - Appearance : Irish Pub -
#
# -----
#
# True to drinks relaxing you - Appearance :
#
# -----
#
# False to drinks relaxing you
#
# -----
#
# Otherwise , she 'll be stacking cups .
#
# -----
#
# That 's the only difference .
#
# -----
#
# Go behind the counter and find the cabinet .
#
# -----
#
# Exit the building now .
#
# -----
#
# You can now use your phone .
#
# -----
#
# The phone number to call is 555-3825
#
# -----
#
# Head back the way you came .
#
# -----
#
# Significant Objects : Ghost ( Swingset ) ***
#
# -----
#
# Continue back the way you came .
#
# -----
#
# It 's near a street light .
#
# -----
#
# Snap a photo of that .
#
# -----
#
# So ... answer it .
#
# -----
#
# This will begin the first nightmare sequence .
#
# -----
#
# The path in this nightmare is fairly straightforward .
#
# -----
#
# Do n't bother hiding in the cabinet .
#
# -----
#
# This is where the separate paths collide .
#
# -----
#
# Continue along the straightforward path .
#
# -----
#
# Therapy - Happy Family -+o
#
# -----
#
# Question Primary Influence
#
# -----
#
# This has no bearing on anything else .
#
# -----
#
# Coloring the trees does nothing .
#
# -----
#
# Cybil 's conversation will similarly reflect your hostility .
#
# -----
#
# Otherwise , she 'll mention you seem quiet .
#
# -----
#
# Hop on up to the front seat .
#
# -----
#
# In the glove compartment is a memento .
#
# -----
#
# Significant Objects : Memento ( Hidden Fire ) ***
#
# -----
#
# Approach to get the echo message .
#
# -----
#
# Inside it is a key .
#
# -----
#
# Run up to the water tower .
#
# -----
#
# Nearby is a barrel in the snow .
#
# -----
#
# You 'll find yourself at a fishing lodge .
#
# -----
#
# Continue through the door .
#
# -----
#
# Climb up it .
#
# -----
#
# Significant Objects : Echo ***
#
# -----
#
# The ghost is behind the bars here .
#
# -----
#
# Significant Objects : Ghost ( Drowning Boy ) ***
#
# -----
#
# There is a canoe and a few barrels .
#
# -----
#
# Turning off your light makes it more noticeable .
#
# -----
#
# --- III.3 Forest Path ; continued pt.2
#
# -----
#
# Significant Objects : Echo ***
#
# -----
#
# Turn around and head out the door .
#
# -----
#
# There 's a flare up there .
#
# -----
#
# There 's a cabin there .
#
# -----
#
# o+- Puzzle - Music Box -+o
#
# -----
#
# So any of these instructions should help you :
#
# -----
#
# You 'll notice an airplane .
#
# -----
#
# Just light your flare and carry on .
#
# -----
#
# Knock over the movable object for good measure .
#
# -----
#
# You 'll end up outside again .
#
# -----
#
# Head on up there and through the door .
#
# -----
#
# This phrase appears in :
#
# -----
#
# - The Bible - Isaiah
#
# -----
#
# 63:1 - Kudos to Byakuya Truelight
#
# -----
#
# - Kudos to Steve P. and Wolfgar L.
#
# -----
#
# Continue along the road to a small cabin .
#
# -----
#
# Hop the counter and go through the door .
#
# -----
#
# Therapy - Halcyon Days of High School
#
# -----
#
# The doctor will say a list of titles .
#
# -----
#
# Unfriendly PI Slacker None
#
# -----
#
# Run in the direction you 're facing .
#
# -----
#
# You 'll find a door that 's locked .
#
# -----
#
# Insignificant Objects : Chemicals Cupboard ***
#
# -----
#
# Harry might comment on it .
#
# -----
#
# The number is 555-7588 .
#
# -----
#
# Significant Objects : Sexual PI ***
#
# -----
#
# The name of this place will vary .
#
# -----
#
# Significant Objects : Sexual PI ***
#
# -----
#
# The echo is associated with the car .
#
# -----
#
# Significant Objects : Echo ***
#
# -----
#
# In this direction is also a trophy case .
#
# -----
#
# Significant Objects : Echo ; Jock Outfit Influence ***
#
# -----
#
# There 's nothing significant in the classroom .
#
# -----
#
# There 's an echo in this area .
#
# -----
#
# Significant Objects : Echo ***
#
# -----
#
# This one 's obviously for biology .
#
# -----
#
# The other door leads back outside .
#
# -----
#
# Quick Solution : Call 555-8465
#
# -----
#
# This forms a 5 .
#
# -----
#
# So the number is 555-8465 .
#
# -----
#
# Head behind the curtain and through the door .
#
# -----
#
# Quick Solution : Call 555-2327
#
# -----
#
# The message says to call 555-2327 .
#
# -----
#
# --- III.5 Hall to Gym
#
# -----
#
# This is an indicator of your current PI .
#
# -----
#
# o+- Puzzle - Gym Keycode
#
# -----
#
# The keycode is : 1031
#
# -----
#
# It 'll always be 1053 .
#
# -----
#
# You 'll be outside again .
#
# -----
#
# Get it , then go into the gym .
#
# -----
#
# Significant Objects : Echo ***
#
# -----
#
# o+- Puzzle - PC Password -+o
#
# -----
#
# Click on the " forgotten password " link .
#
# -----
#
# The greatest baseball team , without question ?
#
# -----
#
# - " Racquetball " - Trophy mounted on wall
#
# -----
#
# My bitch of an ex-wife 's name ?
#
# -----
#
# Take a look at your map .
#
# -----
#
# F block - Snap photo - Gym -
#
# -----
#
# Just follow Michelle as normal .
#
# -----
#
# You 'll eventaully come to the Balkan Club .
#
# -----
#
# They both lead to the same room .
#
# -----
#
# Significant Objects : Sexual PI ***
#
# -----
#
# --- III.5 Traveling With Dahlia
#
# -----
#
# Or you can just continue reading :-)
#
# -----
#
# o+- Puzzle - Bridge Control -+o
#
# -----
#
# The lights are as follows :
#
# -----
#
# Left lever - Yellow : Right lever
#
# -----
#
# Head back to the car to continue .
#
# -----
#
# Move over to it and grab it .
#
# -----
#
# Now , you 'll be able to escape .
#
# -----
#
# Either will let you get out .
#
# -----
#
# It does n't end the game .
#
# -----
#
# It takes about 60 seconds .
#
# -----
#
# Significant Objects : Fake PI ***
#
# -----
#
# You 'll be in therapy again .
#
# -----
#
# This is an obvious indicator of your PI .
#
# -----
#
# That is where you want to head .
#
# -----
#
# DON'T go in those .
#
# -----
#
# Doors , they loop backwards .
#
# -----
#
# o+- Puzzle - Radio Request
#
# -----
#
# Turn on the radio .
#
# -----
#
# Head through the door .
#
# -----
#
# This will lead to a cutscene .
#
# -----
#
# --- III.8 Time With Lisa
#
# -----
#
# Then open the cupboard and get the pill .
#
# -----
#
# Therapy - Guilty Conscience
#
# -----
#
# " You could n't ignore the facts .
#
# -----
#
# He was the one who killed her . "
#
# -----
#
# --- III.8 After Meeting Lisa
#
# -----
#
# Head out of Lisa 's apartment .
#
# -----
#
# It 's the only container that 'sby itself .
#
# -----
#
# In here are two photocopiers .
#
# -----
#
# Significant Objects : Memento ( Synthetic Femur ) ***
#
# -----
#
# waiting for her boyfriend to show up .
#
# -----
#
# For friendly , call her .
#
# -----
#
# Significant Objects : Friendliness PI ***
#
# -----
#
# Nothing 's around though .
#
# -----
#
# For friendly , call her .
#
# -----
#
# Significant Objects : Friendliness PI ***
#
# -----
#
# --- III.8 Nurse In Distress
#
# -----
#
# So head back to Lisa 's .
#
# -----
#
# The end result is the same .
#
# -----
#
# Head outside and get out your map .
#
# -----
#
# o+- Puzzle - Gumball Machine
#
# -----
#
# Purple , pink , red , yellow
#
# -----
#
# Try not to mistake the black for purple .
#
# -----
#
# Head through the door .
#
# -----
#
# Near it is a garbage can .
#
# -----
#
# This garbage can has an echo on it .
#
# -----
#
# Significant Objects : Echo ***
#
# -----
#
# In here is both a memento and echo .
#
# -----
#
# That should make it easier to see .
#
# -----
#
# You 'll be in a back hall .
#
# -----
#
# Just walk through .
#
# -----
#
# Then pull the handle and grab the memento .
#
# -----
#
# Then it 'll crash .
#
# -----
#
# A key falls out when it crashes .
#
# -----
#
# Grab it and head out of the store .
#
# -----
#
# Significant Objects : Sexual PI ***
#
# -----
#
# Significant Objects : Echo ***
#
# -----
#
# Neither holds anything significantly different .
#
# -----
#
# I laughed at the one message .
#
# -----
#
# 2 . Celebration Time Gift Shop
#
# -----
#
# o+- Celebration Time Code
#
# -----
#
# The code is 2050
#
# -----
#
# Listen to the message .
#
# -----
#
# There will be two sound clips played .
#
# -----
#
# The first card is for a 20th anniversary .
#
# -----
#
# The second card is for a 50th birthday .
#
# -----
#
# Note the numbers : 20 and 50 .
#
# -----
#
# Significant Objects : Echo ***
#
# -----
#
# Significant Objects : Echo ; Friendly PI ***
#
# -----
#
# --- III.9 Cinereal Movie Theater
#
# -----
#
# Did I miss them ? "
#
# -----
#
# Nope , but there 's one here .
#
# -----
#
# Wait ... it 's broken ?!?!
#
# -----
#
# Anyway ... there 's a toy machine against
#
# -----
#
# The wall across the lobby .
#
# -----
#
# Inside is a memento .
#
# -----
# Head down the hall to the auditorium .
#
# -----
#
# Go out the door with an exit sign .
#
# -----
#
# --- III.9 Streets Outside Toluca Mall
#
# -----
#
# Scale the fence and turn to your right .
#
# -----
#
# Snap a photo of it before you continue .
#
# -----
#
# Significant Objects : Ghost ( Dead Dog ) ***
#
# -----
#
# There 's a graphical glitch here too .
#
# -----
#
# --- III.9 Green Lion Pawn Shop
#
# -----
#
# Snap a photo of it .
#
# -----
#
# Approach the counter and interact with it .
#
# -----
#
# Turn around and walk out the door .
#
# -----
#
# Pick a door and go down the stairs .
#
# -----
#
# As you approach it you 'll transition again .
#
# -----
#
# This is the exit .
#
# -----
#
# This is the shortest path possible .
#
# -----
#
# It has a lamp above it .
#
# -----
#
# The door you came through vanishes .
#
# -----
#
# --- III.10 Hall of Glass
#
# -----
#
# However , the walls are invisible .
#
# -----
#
# This is the most difficult nightmare sequence .
#
# -----
#
# Here 's a diagram of the final corridor :
#
# -----
#
# SAVE YOUR GAME HERE .
#
# -----
#
# THIS SECTION CONTAINS MILD SPOILERS ***
#
# -----
#
# These are the questions he asks :
#
# -----
#
# You think marriage can really last ?
#
# -----
#
# Should a couple stay together for the kids ?
#
# -----
#
# Do you think sex becomes stale after marriage ?
#
# -----
#
# Otherwise , he wo n't be very interested .
#
# -----
#
# You can pair them as follows :
#
# -----
#
# Or you can just scramble them .
#
# -----
#
# Otherwise , he 'll seem upset .
#
# -----
#
# Make your way down into the underground tunnels .
#
# -----
#
# In it s vomit is a memento .
#
# -----
#
# PI Variations : - " Go away ! "
#
# -----
#
# To the right are some bars .
#
# -----
#
# Through these bars is another UFO .
#
# -----
#
# Climb the ladder .
#
# -----
#
# Also in the box is a memento .
#
# -----
#
# Significant Objects : Memento ( Memories Untaken ) ***
#
# -----
#
# Significant Objects : Echo ***
#
# -----
#
# Open the curtain to reveal a door .
#
# -----
#
# You 'll be outside again .
#
# -----
#
# Jump the fence and turn right .
#
# -----
#
# Do n't go into the bar yet .
#
# -----
#
# Up ahead you 'll find a telescope .
#
# -----
#
# A cutscene will ensue .
#
# -----
#
# Therapy - Sex Evaluation
#
# -----
#
# Otherwise , nothing really changes .
#
# -----
#
# You 'll find yourself in a short hall .
#
# -----
#
# On the wall is a sexual poster .
#
# -----
#
# Head out the door .
#
# -----
#
# Follow the road to the end .
#
# -----
#
# Inside the box is a memento .
#
# -----
#
# Jump over the counter .
#
# -----
#
# Open the yellow jacket .
#
# -----
#
# Significant Objects : Ghost ( Dragon Slayer ) ***
#
# -----
#
# Significant Objects : Memento ( Eve ) ***
#
# -----
#
# Then it 'll be back up the ladder .
#
# -----
#
# Then it 'll be on the foremost swan .
#
# -----
#
# You 'll find yourself outside again .
#
# -----
#
# There are two docks .
#
# -----
#
# Ca n't fool us !
#
# -----
#
# We have walkthroughs !
#
# -----
#
# Walk down the dock and board The Opheus .
#
# -----
#
# --- III.12 Into The Light
#
# -----
#
# Dahlia will call you .
#
# -----
#
# Ignore her request and press onwards .
#
# -----
#
# Creatures will start to pursue you .
#
# -----
#
# Look down into the water by pressing B .
#
# -----
#
# Once you walk up to the lighthouse .
#
# -----
#
# Inside the statue 's head is a memento .
#
# -----
#
# Significant Objects : Memento ( Adam ) ***
#
# -----
#
# Congrats , you 've beaten the game !
#
# -----
#
# Hope you like the ending .
#
# -----
#
# I know I did .
#
# -----
#
# The profiling influences various aspects of the game .
#
# -----
#
# Just choose whatever you like .
#
# -----
#
# Question Primary Influence
#
# -----
#
# I make friends easily Friendliness PI
#
# -----
#
# I prefer abstract ideas Fake PI
#
# -----
#
# I have never cheated on a Sexual PI partner
#
# -----
#
# Question Primary Influence
#
# -----
#
# This has no bearing on anything else .
#
# -----
#
# Coloring the trees does nothing .
#
# -----
#
# The doctor will say a list of titles .
#
# -----
#
# Unfriendly PI Slacker None
#
# -----
#
# You 'll be in therapy again .
#
# -----
#
# This is an obvious indicator of your PI .
#
# -----
#
# " You could n't ignore the facts .
#
# -----
#
# He was the one who killed her . "
#
# -----
#
# *** THIS SECTION CONTAINS MILD SPOILERS ***
#
# -----
#
# These are the questions he asks :
#
# -----
#
# 1 . You think marriage can really last ?
#
# -----
#
# You can pair them as follows :
#
# -----
#
# Or you can just scramble them .
#
# -----
#
# Otherwise , nothing really changes .
#
# -----
#
# THIS SECTION CONTAINS SPOILERS ***
#
# -----
#
# The ending you get has two parts .
#
# -----
#
# There are three different versions you can get .
#
# -----
#
# - Broken - Bearer of Guilt - Hero Forever
#
# -----
#
# How To Get It :
#
# -----
#
# Answer questions as an honest family man would .
#
# -----
#
# Harry kneels before Cheryl .
#
# -----
#
# Bearer of Guilt -+o
#
# -----
#
# How To Get It :
#
# -----
#
# Build up as much Unfriendly PI as possible .
#
# -----
#
# Harry stands before his daughter .
#
# -----
#
# He knows she ca n't forgive him .
#
# -----
#
# Nor does he want to be forgiven .
#
# -----
#
# Cheryl stands up and confronts her guilt .
#
# -----
#
# They both feel cold to each other .
#
# -----
#
# His body freezes as he steps back .
#
# -----
#
# How To Get It :
#
# -----
#
# Build up any Fake PI that you can .
#
# -----
#
# Whenever you can , try to contradict yourself .
#
# -----
#
# Harry kneels down before her .
#
# -----
#
# " You are a hero . "
#
# -----
#
# She pauses , taking a breath .
#
# -----
#
# Her eyes begin to water .
#
# -----
#
# " That is n't who I remember .
#
# -----
#
# Those memories are all I have .
#
# -----
#
# You 're all I have . "
#
# -----
#
# He turns from her .
#
# -----
#
# They hold each other closely .
#
# -----
#
# For once , Cheryl feels warm ...
#
# -----
#
# How To Get It :
#
# -----
#
# Same criteria as Broken .
#
# -----
#
# " You be careful ? "
#
# -----
#
# Dahlia softly requests .
#
# -----
#
# " Harry ... " Dahlia tries to explain .
#
# -----
#
# Harry holds up his hand .
#
# -----
#
# " We 've said enough .
#
# -----
#
# " Sweetie , do n't film this . "
#
# -----
#
# He approaches Cheryl and kneels before her .
#
# -----
#
# And we always will . "
#
# -----
#
# Cheryl lowers the camera and turns it off .
#
# -----
#
# o+- Sleaze and Sirens -+o
#
# -----
#
# How To Get It :
#
# -----
#
# Gain as much Sexual PI as possible .
#
# -----
#
# Michelle bows before the camera .
#
# -----
#
# " And our next star ... "
#
# -----
#
# Lisa hurries over to Harry 's other side .
#
# -----
#
# Michelle innocently requests .
#
# -----
#
# " Can you dedicate it to us ? "
#
# -----
#
# It 's only fair . "
#
# -----
#
# o+- Wicked and Weak -+o
#
# -----
#
# How To Get It :
#
# -----
#
# " You piece of shit ! "
#
# -----
#
# She slaps him .
#
# -----
#
# Harry raises his hand to his face .
#
# -----
#
# He says nothing .
#
# -----
#
# Nothing will satisfy this demon of rage .
#
# -----
#
# " You think your crap is Shakespeare ?
#
# -----
#
# She strikes him again in fury .
#
# -----
#
# Harry collapses to the floor .
#
# -----
#
# He yet remains silent .
#
# -----
#
# " Be a man ! "
#
# -----
#
# Dahlia screams " Come on !
#
# -----
#
# Harry does nothing .
#
# -----
#
# She strikes him again .
#
# -----
#
# Harry 's glasses clack against the wooden floor .
#
# -----
#
# He notices Cheryl with her camera .
#
# -----
#
# He remains silent .
#
# -----
#
# How To Get It :
#
# -----
#
# - " True " to question
#
# -----
#
# It 's late at night .
#
# -----
#
# " The hell you filmin ' me for ?
#
# -----
#
# Am I supposed to dance for ya ? "
#
# -----
#
# His beer spills on the ground .
#
# -----
#
# Cheryl stares at her fallen father .
#
# -----
#
# Get me a damn beer ! "
#
# -----
#
# This is the usual joke ending .
#
# -----
#
# The number you need to call is 555-3825 .
#
# -----
#
# Through a hole in the fishing lodge roof
#
# -----
#
# Ca n't miss it
#
# -----
#
# 7 - III.5 Hall to Gym -
#
# -----
#
# 8 - III.8 Nurse In Distress -
#
# -----
#
# Inside a fish tank .
#
# -----
#
# Easy to spot with your light off
#
# -----
#
# 10 - III.9 Green Lion Pawn
#
# -----
#
# On top of a shelf in the pawn shop
#
# -----
#
# Just before the exit
#
# -----
#
# So any of these instructions should help you :
#
# -----
#
# Quick Solution : Call 555-8465
#
# -----
#
# This forms a 5 .
#
# -----
#
# Quick Solution : Call 555-2327
#
# -----
#
# The message says to call 555-2327 .
#
# -----
#
# The keycode is : 1031
#
# -----
#
# One is 10 and the other is 31 .
#
# -----
#
# This is the keycode .
#
# -----
#
# Click on the " forgotten password " link .
#
# -----
#
# The greatest baseball team , without question ?
#
# -----
#
# - " Racquetball " - Trophy mounted on wall
#
# -----
#
# My bitch of an ex-wife 's name ?
#
# -----
#
# The lights are as follows :
#
# -----
#
# Left lever - Yellow : Right lever
#
# -----
#
# Purple , pink , red , yellow
#
# -----
#
# Try not to mistake the black for purple .
#
# -----
#
# The code is 2050
#
# -----
#
# Listen to the message .
#
# -----
#
# There will be two sound clips played .
#
# -----
#
# The first card is for a 20th anniversary .
#
# -----
#
# The second card is for a 50th birthday .
#
# -----
#
# Note the numbers : 20 and 50 .
#
# -----
#
# - From III.2 Car Ride -
#
# -----
#
# - From III.3 Forest Path -
#
# -----
#
# *** EASY TO MISS ***
#
# -----
#
# A Broken Ward
#
# -----
#
# - From III.3 Hunter 's Cabin -
#
# -----
#
# - Xerces Blue ; an extinct species of butterfly
#
# -----
#
# A Frigid Jewel
#
# -----
#
# *** EASY TO MISS ***
#
# -----
#
# An Eternal Rose
#
# -----
#
# - From III.5 Hall to Gym -
#
# -----
#
# - From III.9 Family Pet -
#
# -----
#
# My Flyind lizard
#
# -----
#
# Poetry as Precise as Geometry
#
# -----
#
# A Happy Bond
#
# -----
#
# Memories to keep forever ! "
#
# -----
#
# A Beacon , a Key - From III.11
#
# -----
#
# Your Diamond Heart
#
# -----
#
# - From III.3 Hunter 's Cabin -
#
# -----
#
# Hot and Bothered
#
# -----
#
# Choker - From III.5 School
#
# -----
#
# - From III.9 Streets Outside toluca
#
# -----
#
# County Weather Service 555-7659 Cybil 555-2925 Dahlia 555-7399
#
# -----
#
# Dixon Bridge Maintenance 555-3411
#
# -----
#
# Home / Cheryl 555-4663 How Am I Driving 555-7243
#
# -----
#
# Konami Customer Support Line 220-8330
#
# -----
#
# Lakeside Amusement Park 555-3253 Lakeview Hotel 555-2502 Lisa 555-3323
#
# -----
#
# State Forestry Dept 555-8733
#
# -----
#
# - Metal Riffs - Sergey - Ruf_Gekko
#
# -----
#
# Silent Hill : Shattered Memories Copyright 2009
#
# -----
#
# Konami Digital Entertainment
# -----
#
# ( Covers Xbox 360 release )
#
# -----
#
# Silent Hill : Homecoming FAQ / Walkthrough
#
# -----
#
# Version 1.3 Last updated :
#
# -----
#
# Authored by : Berserker Email : berserker_kev(at) yahoo.com
#
# -----
#
# This document Copyright 2008 - 2009
#
# -----
#
# Kevin Hall ( Berserker ) --------- --
#
# -----
#
# TABLE OF CONTENTS
#
# -----
#
# Alex has finally returned home from the service .
#
# -----
#
# " I miss your brother , Alex ... "
#
# -----
#
# Alex tells his mother ...
#
# -----
#
# RB - Weapon Wheel menu Left Analog
#
# -----
#
# FLASHLIGHT AND RADIO ********************
#
# -----
#
# The radio should stay on at all times .
#
# -----
#
# There is no reason to turn it off .
#
# -----
#
# o----------------------------------o | HEALING ITEM | HEALTH REPLENISH | |==================================|
#
# -----
#
# USING KEY ITEMS ***************
#
# -----
#
# This is usually the case for locked doors .
#
# -----
#
# BUTTON TAP SEQUENCES ********************
#
# -----
#
# Alex 's flashlight will highlight the closest enemy .
#
# -----
#
# Press the B button to perform a dodge .
#
# -----
#
# Quick Recover from Knockdown
#
# -----
#
# Melee Combat Moves
#
# -----
#
# ( [ ] = press and hold button )
#
# -----
#
# Combat Knife / Ceremonial Dagger
#
# -----
#
# A - Slash to left
#
# -----
#
# [ X ] - Forward Stab
#
# -----
#
# Steel Pipe / Crowbar
#
# -----
#
# A - Swing to left
#
# -----
#
# [ X ] - Homerun swing to left
#
# -----
#
# Fire Axe / Pulaski Axe
#
# -----
#
# The X swing is very powerful but it leaves
#
# -----
#
# A - Chop to left
#
# -----
#
# [ X ] - Overhead chop
#
# -----
#
# Circular Saw ( secret weapon )
#
# -----
#
# This move can kill many normal enemies instantly .
#
# -----
#
# A - Swing to left
#
# -----
#
# Mk. 23 Handgun / ' Chrome Hammer ' Pistol
#
# -----
#
# The ammo capacity is probably its best aspect .
#
# -----
#
# A - Overhead swing / Pistol whip
#
# -----
#
# Capacity and Pickups
#
# -----
#
# Mk. 23 Handgun Chrome Hammer Pistol
#
# -----
#
# Shotgun / ' Bluesteel ' Shotgun
#
# -----
#
# A - Handle Ram or Handle Swing to left
#
# -----
#
# Capacity and Pickups
#
# -----
#
# M14 Assault Rifle / Police Marksman Rifle
#
# -----
#
# A - Handle Ram or Handle Swing to left
#
# -----
#
# Capacity and Pickups
#
# -----
#
# M 14 Assault Rifle Police Marksman Rifle
#
# -----
#
# Laser Pistol ( secret weapon )
#
# -----
#
# It defeats bosses with only a few hits .
#
# -----
#
# A - Overhead swing / Pistol whip
#
# -----
#
# Capacity and Pickups
#
# -----
#
# - Boss sections have boss attacks listed .
#
# -----
#
# [ ] Escape from the hospital .
#
# -----
#
# GOT TO GET FREE !
#
# -----
#
# Press the B button to cancel the menu .
#
# -----
#
# His name is Alex Shepherd .
#
# -----
#
# Open the door that it leads to .
#
# -----
#
# == Hallway Outside Operating Room ==
#
# -----
#
# Directly ahead are two doors .
#
# -----
#
# Walk over to the gate .
#
# -----
#
# We 'll have to return to Josh later .
#
# -----
#
# == Hallway South of Nurse Center ==
#
# -----
#
# Examine the middle baby incubator .
#
# -----
#
# Hop into the Room 204 .
#
# -----
#
# == Hallway South of Nurse Center ==
#
# -----
#
# == Hallway Outside of Operating Room ==
#
# -----
#
# The door will unlock .
#
# -----
#
# Now let 's talk about opening doors .
#
# -----
#
# Open the first stall for a gruesome sight .
#
# -----
#
# Stall 2 seems to be empty .
#
# -----
#
# and save your game .
#
# -----
#
# Alright , let 's check the stalls .
#
# -----
#
# Stall 1 is locked .
#
# -----
#
# Stall 2 has nothing in it .
#
# -----
#
# Stall 3 has nothing in it either .
#
# -----
#
# Oho , real - time
#
# -----
#
# Otherworld changes , how nice !
#
# -----
#
# Defeat her to bag your first achievement .
#
# -----
#
# == Men 's Restroom ( OW ) ==
#
# -----
#
# == Hallway Outside Restrooms ( OW ) ==
#
# -----
#
# == South Staircase ( OW ) ==
#
# -----
#
# Ah , the damn out of control wheelchairs !
#
# -----
#
# Examine the PATIENT NOTE on the window .
#
# -----
#
# == Day Room ( OW ) ==
#
# -----
#
# is directly ahead , so save your game .
#
# -----
#
# Examine the NOTE on the bed .
#
# -----
#
# Move down the east side of the hall .
#
# -----
#
# Prepare for a cutscene .
#
# -----
#
# Open the door to the Linen Room .
#
# -----
#
# == Linen Room ( OW ) ==
#
# -----
#
# == Hallway Outside Operating Room ( OW ) ==
#
# -----
#
# Run to the south side of the hallway .
#
# -----
#
# Collecting this will give you an achievement .
#
# -----
#
# == Operation Theatre Balcony ( OW ) ==
#
# -----
#
# == Operation Theatre ( OW ) ==
#
# -----
#
# == East Staircase ( OW ) ==
#
# -----
#
# Move up the stairs .
#
# -----
#
# == Operating Theatre ( OW ) ==
#
# -----
#
# Open either door and step inside .
#
# -----
#
# == Operating Room ( OW ) ==
#
# -----
#
# Open the door to the hallway .
#
# -----
#
# == Hallway Outside Operating Room ( OW ) ==
#
# -----
#
# A cutscene will play .
#
# -----
#
# Y - How did you get here ?
#
# -----
#
# X - Are you afraid ?
#
# -----
#
# Y - I want to help you .
#
# -----
#
# Find Joshua 's Toy
#
# -----
#
# == Nurse Center ( OW ) ==
#
# -----
#
# Something else beyond that hole in the glass likes
#
# -----
#
# Robbie the rabbit also !
#
# -----
#
# Walk toward the bloody mirror and examine it .
#
# -----
#
# Return the toy to Joshua .
#
# -----
#
# Save your game along the way .
#
# -----
#
# == Hallway Outside Operating Room ( OW ) ==
#
# -----
#
# A cutscene will play .
#
# -----
#
# Just what the hell is in there anyway ?
#
# -----
#
# I need to go home .
#
# -----
#
# Open the doors to the Town Hall .
#
# -----
#
# This will be used much , much later .
#
# -----
#
# except there are only three paintings ...?
#
# -----
#
# Exit out into the right hallway .
#
# -----
#
# == Judge Holloway 's Office ==
#
# -----
#
# Y - Why is the town empty ?
#
# -----
#
# X - Town anniversary ?
#
# -----
#
# X - Town anniversary ?
#
# -----
#
# A - How 's Elle ?
#
# -----
#
# X - Was that when everything shut down ?
#
# -----
#
# Y - What happened ?
#
# -----
#
# X - Does she ask about me ?
#
# -----
#
# A - Is my mom OK ?
#
# -----
#
# on the wall across from the fireplace .
#
# -----
#
# _ STREETS OF SHEPHER D'S GLEN _ _______________________
#
# -----
#
# Enter the Shepherd House through the front door .
#
# -----
#
# Explore the house .
#
# -----
#
# Move up the stairs .
#
# -----
#
# There is another photo on the right cabinet .
#
# -----
#
# Exit the room .
#
# -----
#
# Well get to that feisty door later .
#
# -----
#
# Found Laser Pistol -----
#
# -----
#
# Be sure to examine the bookshelf .
#
# -----
#
# A puzzle will appear as you investigate it .
#
# -----
#
# Investigate the basement .
#
# -----
#
# Lurk No More ( 10G )
#
# -----
#
# I 'm only kidding ... or am I ?
#
# -----
#
# Squeeze through the narrow opening .
#
# -----
#
# A note is left up under the remote .
#
# -----
#
# [ ] Drain the water in the basement .
#
# -----
#
# Find some gas to power the pump .
#
# -----
#
# Tap the A button to pry it open .
#
# -----
#
# You 'll receive an achievement for collecting it .
#
# -----
#
# They crawl out of the gutters .
#
# -----
#
# Walk back down into the basement .
#
# -----
#
# The water pump will start after the cutscene .
#
# -----
#
# Open the door to continue .
#
# -----
#
# A doghouse without a dog .
#
# -----
#
# _ ROSE HEIGHTS CEMETERY _ __________________________
#
# -----
#
# [ ] Joshua is n't at home .
#
# -----
#
# Search the rest of the town .
#
# -----
#
# Find someone who knows something about fixing guns .
#
# -----
#
# Step onto the walkway behind the open gate .
#
# -----
#
# Move through the doorway ahead .
#
# -----
#
# You can examine the coffins inside .
#
# -----
#
# Step through the next doorway .
#
# -----
#
# You 'll eventually exit to the East Garden .
#
# -----
#
# Do so to trigger a cutscene .
#
# -----
#
# == Family Crypts North ==
#
# -----
#
# Family Crypts Mid ==
#
# -----
#
# Move to the south .
#
# -----
#
# May the bugs lead the way !
#
# -----
#
# Once whole but now split in twain
#
# -----
#
# Walk along the path to the north .
#
# -----
#
# It will unlock and open for Alex .
#
# -----
#
# _ STREETS OF SHEPHER D'S GLEN _ _______________________
#
# -----
#
# A van will come into view soon .
#
# -----
#
# == Outside Curtis ' Shop ==
#
# -----
#
# Move beyond the fences with gasoline barrels .
#
# -----
#
# You can step into Curtis '
#
# -----
#
# Continue around the side of the building .
#
# -----
#
# Enter the building by opening the front door .
#
# -----
#
# Alex will enter an interactive cutscene .
#
# -----
#
# X - You 're Curtis ?
#
# -----
#
# A - How 's it going ?
#
# -----
#
# [ All choices must be used .
#
# -----
#
# Let 's go over the basics of firearms .
#
# -----
#
# All firearms have some sort of melee attack .
#
# -----
#
# Too bad the hit is so weak though .
#
# -----
#
# Y - Can I have the shotgun ?
#
# -----
#
# X - Why are you still here ?
#
# -----
#
# What 's with all the clocks ?
#
# -----
#
# X - Can you fix them ?
#
# -----
#
# [ ] Find Mayor Bartlett .
#
# -----
#
# He was digging graves in the cemetery .
#
# -----
#
# Save your game at the !!
#
# -----
#
# _ STREETS OF SHEPHER D'S GLEN _ _______________________
#
# -----
#
# You 'll receive an achievement after defeating it .
#
# -----
#
# Clear the Air ( 10G )
#
# -----
#
# _ ROSE HEIGHTS CEMETERY _ _________________________
#
# -----
#
# Push through the gate .
#
# -----
#
# Family Crypts Mid ==
#
# -----
#
# == Family Crypts North ==
#
# -----
#
# The Bartlett Mausoleum gate is now open !
#
# -----
#
# Open the door to the Bartlett Mausoleum .
#
# -----
#
# Examine the coffin directly ahead .
#
# -----
#
# This one is not that bad though .
#
# -----
#
# Really you could just go by the pictures .
#
# -----
#
# _ STREETS OF SILENT HILL _
#
# -----
#
# Now we need to chase after Cheryl ...
#
# -----
#
# I mean Josh .
#
# -----
#
# Catch up to Joshua .
#
# -----
#
# The street will end halfway down .
#
# -----
#
# Go ahead and equip the Fire Axe .
#
# -----
#
# Tap the A button to perform each chop .
#
# -----
# Open the double doors ahead .
#
# -----
#
# Damn this hotel is dark .
#
# -----
#
# Return to the main corridor .
#
# -----
#
# What the hell is it with this kid ?
#
# -----
#
# _ STREETS OF SILENT HILL _
#
# -----
#
# Connect the cables as follows .
#
# -----
#
# Blue , R = Red ,
#
# -----
#
# [ ] Power has been restored .
#
# -----
#
# Use the elevator .
#
# -----
#
# Arm your handgun .
#
# -----
#
# A cutscene will play as the elevator rises .
#
# -----
#
# To The Point ( 10G )
#
# -----
#
# Well , ok , not really .
#
# -----
#
# A cutscene will play .
#
# -----
#
# Third Floor Hallway ==
#
# -----
#
# There seems to be something behind the painting .
#
# -----
#
# Cut it to find out what .
#
# -----
#
# Squeeze through the cut painting .
#
# -----
#
# Room 306 has a unique lock .
#
# -----
#
# Find a way to open it .
#
# -----
#
# Save your game at the !!
#
# -----
#
# on the wall .
#
# -----
#
# Y - Who are you ?
#
# -----
#
# X - How did you get here ?
#
# -----
#
# Y - Who left you here ?
#
# -----
#
# X - How did you get here ?
#
# -----
#
# Y - I ca n't help you .
#
# -----
#
# X - I want to help you .
#
# -----
#
# X - I want to help you .
#
# -----
#
# The person actually wants three photos .
#
# -----
#
# Enter Room 304 across the hall .
#
# -----
#
# Exit the room .
#
# -----
#
# ...
#
# -----
#
# Make sure you are wearing the bulletproof vest .
#
# -----
#
# Part Seven : Epilogue
#
# -----
#
# Look at section " III .
#
# -----
#
# Endings " for info on each one .
#
# -----
#
# You 've done it .
#
# -----
#
# Obviously , this section contains spoilers .
#
# -----
#
# III - a. " Normal " Ending
#
# -----
#
# Heather has a demented sense of humor .
#
# -----
#
# And that is the end .
#
# -----
#
# Well done , soldier .
#
# -----
#
# III - b. " Possessed " Ending
#
# -----
#
# Fade to black , cue music .
#
# -----
#
# III - c. " Revenge " Ending
#
# -----
#
# have to be in one game .
#
# -----
#
# You must see it for yourself .
#
# -----
#
# PUZZLES IV - a. Bookstore Puzzle
#
# -----
#
# Put these books out of order . "
#
# -----
#
# HARD Sweet Baby Jesus .
#
# -----
#
# Shakespeare Anthology 1 - Romeo and Juliet Shakespeare Anthology
#
# -----
#
# Doth lie invite truth ?
#
# -----
#
# Doth verity but wear the mask of falsehood ?
#
# -----
#
# Ah , thou pitiful , thou miserable ones .
#
# -----
#
# Will thou attend thy beloved ?
#
# -----
#
# And only the four keys remain .
#
# -----
#
# Ah but verily ...
#
# -----
#
# In here lies a tragedy .
#
# -----
#
# Art thou player or audience ?
#
# -----
#
# So here we go .
#
# -----
#
# Let 's move on to the next one .
#
# -----
#
# So far so good .
#
# -----
#
# So that explains that ) .
#
# -----
#
# Doth verity but wear the mask of falsehood ?
#
# -----
#
# Two more numbers to go .
#
# -----
#
# Will thou attend thy beloved ?
#
# -----
#
# The name of this game is Othello .
#
# -----
#
# We are on a roll .
#
# -----
#
# But we are n't done yet !
#
# -----
#
# IV - b. Hospital Second Floor Key Code Puzzle
#
# -----
#
# I want to hurt you and destroy myself
#
# -----
#
# Abruptly , decisively , like drilling a hole .
#
# -----
#
# And what would it feel like ?
#
# -----
#
# I must taste the warmth of your blood .
#
# -----
#
# How would you scream ?
#
# -----
#
# Would you shriek " It hurts !
#
# -----
#
# And how is your tender ear ?
#
# -----
#
# Do you hate me ?
#
# -----
#
# Are you afraid ?
#
# -----
#
# That was beautiful .
#
# -----
#
# They are all steel gray .
#
# -----
#
# So I guess we can ignore that part .
#
# -----
#
# Keep this in mind as we continue .
#
# -----
#
# I want to hurt you and destroy myself
#
# -----
#
# Let 's continue , shall we ?
#
# -----
#
# Okay , that is pretty Goddamned direct .
#
# -----
#
# Just like pressing a button .
#
# -----
#
# Let 's look at the next two stanzas .
#
# -----
#
# " And what would it feel like ?
#
# -----
#
# I must taste the warmth of your blood .
#
# -----
#
# How would you scream ?
#
# -----
#
# Would you shriek " It hurts !
#
# -----
#
# So we are halfway there .
#
# -----
#
# So 8 is our third digit .
#
# -----
#
# Okay , now we have cheeks .
#
# -----
#
# So this is our next number .
#
# -----
#
# " And how is your tender ear ?
#
# -----
#
# On your face , where are the ears ?
#
# -----
#
# 5 . Eating her left ear : number
#
# -----
#
# 4896 is your final answer .
#
# -----
#
# IV - c. Hospital Briefcase Puzzle
#
# -----
#
# IV - d. Hospital Mortuary Puzzle
#
# -----
#
# Go to the oven door and examine it .
#
# -----
#
# That is it .
#
# -----
#
# Take it and get the hell out .
#
# -----
#
# Each body has a number attached to it .
#
# -----
#
# " Burn the one who knows no death .
#
# -----
#
# Pure , adored by those above .
#
# -----
#
# No prayers within , just simple love .
#
# -----
#
# And now the pining hunter .
#
# -----
#
# The flames longing for his rebirth .
#
# -----
#
# A distant flame within the earth .
#
# -----
#
# Burn up that heavy body of his .
#
# -----
#
# Make it wind , dancing in the sky .
#
# -----
#
# The sweet blood on his laughing lips .
#
# -----
#
# Now calls him to the gates of hell .
#
# -----
#
# There burns evermore that soulless shell .
#
# -----
#
# Four bodies return to ashes .
#
# -----
#
# Thus the door is opened .
#
# -----
#
# Thus the door is opened . "
#
# -----
#
# Sweet shackles that tease and excite .
#
# -----
#
# Death itself would drive him wild .
#
# -----
#
# Red blood that turns milky white .
#
# -----
#
# " The Sparrow , " they said .
#
# -----
#
# " He wants them all dead .
#
# -----
#
# To him honey - sweet is their sobbing .
#
# -----
#
# Resigned to his poor earthbound state .
#
# -----
#
# Gave him sweet happiness .
#
# -----
#
# He sank ever deeper and finally fell .
#
# -----
#
# To destruction and fatal distress .
#
# -----
#
# Is ash in the oven all right .
#
# -----
#
# The place he held is empty now .
#
# -----
#
# And the doors remain shut tight .
#
# -----
#
# And walled himself up all away .
#
# -----
#
# Heart and mouth both locked up tight .
#
# -----
#
# His flapping wings fell still .
#
# -----
#
# Drenched in scarlet there he lay .
#
# -----
#
# His cheeks pale white and chill .
#
# -----
#
# Frightening her out of her wits .
#
# -----
#
# Whispering love songs in her ear .
#
# -----
#
# What cruel Linnet wants , he gets .
#
# -----
#
# Who hears the gods in the skies .
#
# -----
#
# His whispered petitions go on without end .
#
# -----
#
# And glassy and dim are his eyes .
#
# -----
#
# Makes us laugh unto his feeble lip- smacking .
#
# -----
#
# " Who killed Cock Robin ? "
#
# -----
#
# " Who saw him die ? "
#
# -----
#
# " Who caught his blood ? "
#
# -----
#
# " Who 'll make the shroud ? "
#
# -----
#
# " Who 'll dig his grave ? "
#
# -----
#
# " Who 'll be the parson ? "
#
# -----
#
# " Who 'll be the clerk ? "
#
# -----
#
# " Who 'll carry the link ? "
#
# -----
#
# " Who 'll be chief mourner ? "
#
# -----
#
# " Who 'll carry the coffin ? "
#
# -----
#
# " Who 'll bear the pall ?
#
# -----
#
# " Who 'll sing a psalm ? "
#
# -----
#
# " Who 'll toll the bell ? "
#
# -----
#
# They said " cock " .
#
# -----
#
# " Burn the one who knows no death .
#
# -----
#
# Pure , adored by those above .
#
# -----
#
# No prayers within , just simple love . "
#
# -----
#
# Let 's go on to the second stanza .
#
# -----
#
# " And now the pining hunter .
#
# -----
#
# The flames longing for his rebirth .
#
# -----
#
# A distant flame within the earth . "
#
# -----
#
# So that leaves the Kite and the Owl .
#
# -----
#
# Only two left .
#
# -----
#
# The third stanza says :
#
# -----
#
# " Burn up that heavy body of his .
#
# -----
#
# Make it wind , dancing in the sky .
#
# -----
#
# Okay , now this one just sucks .
#
# -----
#
# Here is the Song of the Linnet again :
#
# -----
#
# Frightening her out of her wits .
#
# -----
#
# Whispering love songs in her ear .
#
# -----
#
# What cruel Linnet wants , he gets . "
#
# -----
#
# Kind of a big clue .
#
# -----
#
# Here you have the Linnet 's three colors .
#
# -----
#
# " The sweet blood on his laughing lips .
#
# -----
#
# Now calls him to the gates of hell .
#
# -----
#
# There burns evermore that soulless shell . "
#
# -----
#
# This suggests even further evil , soulless murder .
#
# -----
#
# Tarot Card Puzzle
#
# -----
#
# Refer to the walkthrough for their individual locations .
#
# -----
#
# IV - e - 2 . NORMAL
#
# -----
#
# The poem reads as follows :
#
# -----
#
# Twinkling light sits like a crown
#
# -----
#
# On the head of a crazy clown .
#
# -----
#
# Your excellency praying to God most high
#
# -----
#
# Do you have it now ?
#
# -----
#
# You did n't forget ?
#
# -----
#
# One major point you must n't omit .
#
# -----
#
# Let 's again analyze it part by part :
#
# -----
#
# So there you have it .
#
# -----
#
# The door will then unlock .
#
# -----
#
# " I had a dream .
#
# -----
#
# In my dream , I opened a door .
#
# -----
#
# But was that really me ?
#
# -----
#
# I had a different name .
#
# -----
#
# ING WXX NXA OEI IFI VII
#
# -----
#
# MOX NOT XVH XON HNG III
#
# -----
#
# XAA CXX CCX JII IEI IHT
#
# -----
#
# What do they have in common ?
#
# -----
#
# I XX X OI II VII
#
# -----
#
# OX O XV XO III
#
# -----
#
# X CXX CCX II II I
#
# -----
#
# IOI XXII XVII
#
# -----
#
# OXXO O XVIII
#
# -----
#
# XII CXXII CCXI
#
# -----
#
# This leaves us with :
#
# -----
#
# II XXII XVII
#
# -----
#
# XX O XVIII
#
# -----
#
# XII CXXII CCXI
#
# -----
#
# Visually , that looks like this :
#
# -----
#
# II XXII ( none )
#
# -----
#
# ( none ) O XVIII
#
# -----
#
# XII ( none ) ( none )
#
# -----
#
# V. Secrets And Mysteries V - a.
#
# -----
#
# ADDITIONAL ACTION LEVELS :
#
# -----
#
# So start shootin ' partner !
#
# -----
#
# Go ahead and throw in the Steel Pipe .
#
# -----
#
# So why bother , you ask ?
#
# -----
#
# HEATHER BEAM / SEXY BEAM :
#
# -----
#
# Transform Costume ( PrincessHeart ) :
#
# -----
#
# Heather Shirt ( HappybirthDay ) :
#
# -----
#
# Do n't Touch Shirt ( TOUCH_MY_HEART ) :
#
# -----
#
# Touch her heart ?
#
# -----
#
# Do n't mind if I do !
#
# -----
# Block Head Shirt ( PutHere2Feel Joy ) :
#
# -----
#
# This is a special shirt awarded to pacifists .
#
# -----
#
# Serial killers need not apply .
#
# -----
#
# God of Thunder Shirt ( GangsterGirl ) :
#
# -----
#
# Transience Shirt ( ShogyouMujou ) :
#
# -----
#
# And after some of those damn
#
# -----
#
# A lot of people miss that .
#
# -----
#
# Royal Flush Shirt ( 01_03_08_11_12 ) :
#
# -----
#
# Here they are :
#
# -----
#
# Each of the cats had seven kits .
#
# -----
#
# March is the third month .
#
# -----
#
# Here 's the kicker though .
#
# -----
#
# But I digress .
#
# -----
#
# Clue number seven :
#
# -----
#
# The page / knight became the Jack .
#
# -----
#
# This last clue is comparatively easy .
#
# -----
#
# So there you have it : 01_03_08_11_12 .
#
# -----
#
# Victory is mine !
#
# -----
#
# Killer Rabbit Shirt ( BlueRobbieWin ) :
#
# -----
#
# If only it were a real zipper ...
#
# -----
#
# The Light Shirt ( LightToFuture ) :
#
# -----
#
# Game Pro Shirt ( ProTip ) :
#
# -----
#
# The password came from their magazine .
#
# -----
#
# Game Informer Shirt ( gameinformer ) :
#
# -----
#
# Their exceptionally clever password came from the magazine .
#
# -----
#
# The password came from the magazine .
#
# -----
#
# The password came from the magazine .
#
# -----
#
# PS2 RO Shirt ( MATADOR ) :
#
# -----
#
# I am not Spanish either , senior .
#
# -----
#
# The password - o came from the magazine -o.
#
# -----
#
# Play Shirt ( sLmLdGhSmKfBfH ) :
#
# -----
#
# They also have a website ( www.playplaystation.com ) .
#
# -----
#
# The password came from there .
#
# -----
#
# Shirt ( iam l 33 t ) :
#
# -----
#
# The password was obtained from their website .
#
# -----
#
# IGN is another popular U.S. gaming website .
#
# -----
#
# The pickleboy is one of their mascots .
#
# -----
#
# The password came from their website .
#
# -----
#
# Game Reactor Shirt ( SH3_Wrestlarn ) :
#
# -----
#
# The password came from their website .
#
# -----
#
# GMR Shirt ( GMRownzjoo ) :
#
# -----
#
# GMR stands for German Monkey Review .
#
# -----
#
# I obtained their password from gamefaqs.com .
#
# -----
#
# So thanks for the info Thomas .
#
# -----
#
# Or this one .
#
# -----
#
# Or maybe not .
#
# -----
#
# Kind of like MTV .
#
# -----
#
# DOUGLAS - KING OF NO PANTS :
#
# -----
#
# This is an incredibly odd little secret .
#
# -----
#
# Now start the game .
#
# -----
#
# SPECIAL DEATH SCENES :
#
# -----
#
# Where does he take her ?
#
# -----
#
# The world may never know , thankfully .
#
# -----
#
# Thanks to Damien Carlisle for this tidbit .
#
# -----
#
# Besides the tattoos ,
#
# -----
#
# See the walkthrough for the exact location . -
#
# -----
#
# Maybe he is God 's daddy ?
#
# -----
#
# Update : This IS Valtiel .
#
# -----
#
# This one is a little ... disturbing .
#
# -----
#
# I feel dirty just for telling you .
#
# -----
#
# EXTRA NEW GAME WEIRDNESS :
#
# -----
#
# They are also
#
# -----
#
# SILENT HILL 2 REFERENCES :
#
# -----
#
# They are as follows :
#
# -----
#
# METAL GEAR SOLID REFERENCE :
#
# -----
#
# STEPHEN KING REFERENCE : Marc
#
# -----
#
# Think about it .
#
# -----
#
# Rachel Crosby ... cute . "
#
# -----
#
# People , keep those horror references rolling in ...
#
# -----
#
# Yet another reference to shifting between worlds .
#
# -----
#
# CAFE TURN MILL :
#
# -----
#
# A couple of weird things about Turn Mill .
#
# -----
#
# This has not been confirmed , however .
#
# -----
#
# - The God Kill Time : Kill
#
# -----
#
# - Save and Continue Number :
#
# -----
#
# - Extra Weapon Number :
#
# -----
#
# - Defeated Enemies by Shooting :
#
# -----
#
# - Defeated Enemies by Fighting :
#
# -----
#
# - Take off points :
#
# -----
#
# The Beam Saber is especially satisfying .
#
# -----
#
# Sound was also just about perfect .
#
# -----
#
# Ah , Shotgun , how I love you .
#
# -----
#
# Do people still live there ?
#
# -----
#
# Did they ever live there ?
#
# -----
#
# And what happened to Cybil ?
#
# -----
#
# But that is just my opinion .
#
# -----
#
# Now THAT my friend , is survival horror !
#
# -----
#
# Silent Hill 3 is an instant classic .
#
# -----
#
# This guide is will go first to GAMEFAQS .
#
# -----
#
# | Table of Contents |
#
# -----
#
# The only difference is her attitude and clothes .
#
# -----
#
# Enter the gate in the middle .
#
# -----
#
# Leave this are and continue down the path .
#
# -----
#
# Watch the scene .
#
# -----
#
# Follow Lindsey Street .
#
# -----
#
# Now head West on Katz Street .
#
# -----
#
# There 's also a save point there .
#
# -----
#
# Now you 're prepared .
#
# -----
#
# Wood Side Apartment | ( 00002 )
#
# -----
#
# Go back down there now .
#
# -----
#
# Blue Creek Apartment | ( 00003 )
#
# -----
#
# Now descend the stairs .
#
# -----
#
# o- Boss ( Pyramid Head )
#
# -----
#
# Exit through the first floor door .
#
# -----
#
# Proceed South from this area ,
#
# -----
#
# Examine the door and an event occurs .
#
# -----
#
# Head into the Examination Room
#
# -----
#
# You get ' Piece of Hair .
#
# -----
#
# Select the first floor and ride .
#
# -----
#
# o- Boss ( Hanging Demons )
#
# -----
#
# Enter the main stairwell and save your game .
#
# -----
#
# Examine the fridge and choose to open it .
#
# -----
#
# The Answers are as follows :
#
# -----
#
# Inside is the ' Old Bronze Key . '
#
# -----
#
# Stay on the North side of
#
# -----
#
# Silent Hill Historical Society | ( 00008 )
#
# -----
#
# Watch the scene when you land .
#
# -----
#
# Following this you 'll hear a scream .
#
# -----
#
# Pick up the lighter off the ledge .
#
# -----
#
# Proceed through the North door in this room .
#
# -----
#
# Into the door and down another hole .
#
# -----
#
# Examine it and follow these directions exactly .
#
# -----
#
# Take the only other ladder downward from here .
#
# -----
#
# Desend the ladder down .
#
# -----
#
# There 's a cemetery just beyond this hall .
#
# -----
#
# Watch the scene .
#
# -----
#
# Leave the room through the large double doors .
#
# -----
#
# Check your map and go into the o------------------------------o
#
# -----
#
# Examine the pictures spread all over the bed .
#
# -----
#
# Access your inventory and use the Thinner .
#
# -----
#
# Head to the East side of 2F .
#
# -----
#
# Take the elevator down to the first floor .
#
# -----
#
# Leave and head West to the Kitchen .
#
# -----
#
# Leave the kitchen through the West door .
#
# -----
#
# Now you can go through the West door .
#
# -----
#
# The puzzle answer is as follows :
#
# -----
#
# Now leave the room .
#
# -----
#
# Alternate Hotel | ( 0000 C )
#
# -----
#
# o- Boss ( Pyramid Heads )
#
# -----
#
# o- Boss ( Final Boss )
#
# -----
#
# Select your weapon of choice and strike .
#
# -----
#
# Now sit back and enjoy the ending .
#
# -----
#
# You beat the game .
#
# -----
#
# It reloads quickly and is quite o---------o powerful .
#
# -----
#
# Equip the weapon and start smashing .
#
# -----
#
# Shotgun bullets are scattered through the game .
#
# -----
#
# Very handy little things .
#
# -----
#
# Using a First - Aid
#
# -----
#
# Comes with 4 in a pack .
#
# -----
#
# Basically any weapon is effective against them .
#
# -----
#
# Any normal weapons should suffice to stop them .
#
# -----
#
# James wields , however slightly shorter .
#
# -----
#
# Now just go and beat the game .
#
# -----
#
# | Ampoule | Various places throughout the game |
#
# -----
#
# | Apartment Gate Key |
#
# -----
#
# In the hidden basement of evil hospital |
#
# -----
#
# In apartment room 307 , in the closet |
#
# -----
#
# In the drain of evil hospital shower room |
#
# -----
#
# | Employee Elevator Key |
#
# -----
#
# In room 204 of the hotel |
#
# -----
#
# | Fire Escape Key |
#
# -----
#
# Third floor apartment hall , on the floor |
#
# -----
#
# Various places throughout the game |
#
# -----
#
# | Fish Key | Table in hotel restaurant |
#
# -----
#
# | Hospital Lobby Key |
#
# -----
#
# Evil hospital , in Director 's Room |
#
# -----
#
# |------------------------------+---------------------------------------------| | Hotel Stairway Key |
#
# -----
#
# On the music box pedestal in the hotel |
#
# -----
#
# In room M2 of the hospital |
#
# -----
#
# In the metal can in hotel basement kitchen |
#
# -----
#
# | Lighter | Toluca Prison visiting room |
#
# -----
#
# |------------------------------+---------------------------------------------| | Lyne House Key |
#
# -----
#
# | Map of Apartment West | Inside
#
# -----
#
# West stairs of apartments |
#
# -----
#
# | Obsidian Goblet | Historical Society display case |
#
# -----
#
# | Piece of Hair |
#
# -----
#
# | Purple Bull Key |
#
# -----
#
# In hospital Document Room , by typewriter |
#
# -----
#
# | Radio | Automatically acquired near beginning |
#
# -----
#
# After defeating Pyramid , in his hand |
#
# -----
#
# After defeating Pyramid , in his hand |
#
# -----
#
# | Snow White Music Box |
#
# -----
#
# On the shelf in the hotel pantry |
#
# -----
#
# | Thinner | Inside the hotel basement elevator |
#
# -----
#
# | White Chrism | Apartment room 105 kitchen |
#
# -----
#
# | Wire Cutter | Labyrinth fuse box |
#
# -----
#
# | Wooden Plank | Acquired Automatically near beginning |
#
# -----
#
# o----------------------------------------------------------------------------o | | | Toluca Lake N |
#
# -----
#
# Wood Side Apartment | ( 00102 )
#
# -----
#
# Fire Escape Key L -
#
# -----
#
# Blue Creek Apartment | ( 00103 )
#
# -----
#
# Shotgun Shells | | K -
#
# -----
#
# Fish Key | | C -
#
# -----
#
# Cinderella T - Health Drink | | U -
